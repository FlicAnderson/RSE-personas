# %%
import datetime 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from githubanalysis.analysis.analyse_data import DataAnalyser


dataanalyser = DataAnalyser(in_notebook=True, logger=None, dataset_name="sample_45pc_notebook_cluster0")
current_date_info = datetime.datetime.now().strftime(
            "%Y-%m-%d"
        )
print(current_date_info)
# Out:
# 2025-05-18

# %%
# [2025-05-13 12:54:19,291] INFO:
#         Running Data Analysis with arguments: Namespace(data_file='subsample_45pc_cluster_0_data__2025-05-13.csv', subset_file='study-sample-repo-names_2025-05-01_x2981.txt', pc_subset_repos=100, interactions_file='merged-interactions-data-per-dev_x2946-repos_2025-05-12.csv', repo_stats_file='summarised_repo_stats_2025-05-01.csv', max_n_clusters=10, n_clusters=None, dataset_run_name='sample_45pc_cluster0');
#         data: subsample_45pc_cluster_0_data__2025-05-13.csv;
#         run name: sample_45pc_cluster0;
#         subset to: study-sample-repo-names_2025-05-01_x2981.txt;
#         percentage of subset to use: 100;
#         interactions: merged-interactions-data-per-dev_x2946-repos_2025-05-12.csv;
#         repo_stats summary data: summarised_repo_stats_2025-05-01.csv;
#         max number of clusters to eval: 10;
#         number of clusters to use: None; .

# [2025-05-13 12:54:19,307] INFO:data is df, with shape: (2357, 48).
# [2025-05-13 12:54:19,309] INFO:Before subsetting: Number of unique gh_usernames in sample is: 2060.
# [2025-05-13 12:54:19,317] INFO:Before subsetting: Number of gh_usernames appearing in more than one repository in this sample is: 173.
# [2025-05-13 12:54:19,319] INFO:Before subsetting: Number of repo-individuals (repo_name plus gh_username combos) in sample is: 2357.
# [2025-05-13 12:54:19,320] INFO:Before subsetting: Number of repositories in sample is: 1003.
# [2025-05-13 12:54:19,320] INFO:data is df, with shape: (2357, 48).
# [2025-05-13 12:54:19,321] INFO:length of subset_repos_file is: 2981 repos
# [2025-05-13 12:54:19,321] INFO:Subsetting percentage is: 100; using random seed: 42
# [2025-05-13 12:54:19,322] INFO:After applying subset percentage, length of subset_repos_file is: 2981 repos
# [2025-05-13 12:54:19,323] INFO:length of subset dataset is now: 2357
# [2025-05-13 12:54:19,373] INFO:Number of repositories in sample is: 1003.
# [2025-05-13 12:54:19,374] INFO:Number of unique gh_usernames in sample is: 2060.
# [2025-05-13 12:54:19,378] INFO:Number of gh_usernames appearing in more than one repository in this sample is: 173.
# [2025-05-13 12:54:19,381] INFO:Number of repo-individuals (repo_name plus gh_username combos) in sample is: 2357.
# [2025-05-13 12:54:20,448] INFO:Column names from cleaned_df: Index(['repo_name', 'gh_username', 'author_username', 'n_of_commit_creators',
#        'n_commits', 'pc_repo_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown',
#        'issue_author_username', 'n_issues', 'pc_repo_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', '_merge', 'issue_username',
#        'commiss_merge', '_dataset_source', 'CBRI', 'contributions_by_user',
#        'pcCDC', 'pc_n_commits', 'pc_HLs-tiny', 'pc_HLs-sml', 'pc_HLs-med',
#        'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng', 'pc_HL-corr', 'pc_HL-mgmt',
#        'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc', 'pc_V-code', 'pc_V-confg',
#        'pc_V-build', 'pc_V-dvdoc', 'pc_V-test', 'pc_V-meta', 'pc_V-img',
#        'pc_V-l10n', 'pc_V-ui', 'pc_V-media', 'pc_V-nocat'],
#       dtype='object')
# [2025-05-13 12:54:20,448] INFO:Column names from interactions file: Index(['repo_name', 'gh_username', 'commit_created', 'issue_closed',
#        'issue_created', 'pull_request_closed', 'pull_request_created',
#        'interaction_days', 'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days'],
#       dtype='object')
# [2025-05-13 12:54:20,448] INFO:cleaned_data.shape =(2357, 74)
# [2025-05-13 12:54:20,448] INFO:all_interaction_data.shape =(244561, 22)
# [2025-05-13 12:54:20,506] INFO:cleaned_data_with_interactions.shape = (2357, 94)
# [2025-05-13 12:54:20,506] INFO:Number of unique cols in cleaned_data_with_interactions is: 94.
# [2025-05-13 12:54:20,653] INFO:Combined cleaned_data_with_interaction_data df has shape: (2357, 85).
# [2025-05-13 12:54:20,747] INFO:Combined cleaned_data and interaction_data written out to data/analysis_run_sample_45pc_cluster0_2025-05-13/cleaned_data_with_interaction-data-per-dev__2025-05-13.csv
# [2025-05-13 12:54:20,748] INFO:Wrote out 1003 records to file sample_45pc_cluster0_subsample_repo_names_list_2025-05-13_x1003.txt.
# [2025-05-13 12:54:20,803] INFO:data is df, with shape: (36196, 15).
# [2025-05-13 12:54:20,803] INFO:length of subset_repos_file is: 1003 repos
# [2025-05-13 12:54:20,803] INFO:Subsetting percentage is: 100; using random seed: 42
# [2025-05-13 12:54:20,804] INFO:After applying subset percentage, length of subset_repos_file is: 1003 repos
# [2025-05-13 12:54:20,807] INFO:length of subset dataset is now: 1003
# [2025-05-13 12:54:20,812] INFO:Relevant repo_stats subset written out to data/analysis_run_sample_45pc_cluster0_2025-05-13/summarised_SAMPLE_repos_stats_2025-05-13.csv
# [2025-05-13 12:54:20,827] INFO:202 unique languages listed in dataset of 1003 unique repositories...
# [2025-05-13 12:54:20,833] INFO:Top 15 RS Repo Languages from Dataset:        repo_language  n_repos_using_language  pc_repos_using_language
# 0             Python                     775                77.268195
# 1              Shell                     502                50.049850
# 2           Makefile                     256                25.523430
# 3         Dockerfile                     240                23.928215
# 4               HTML                     235                23.429711
# 5   Jupyter Notebook                     184                18.344965
# 6                C++                     159                15.852443
# 7         JavaScript                     157                15.653041
# 8                CSS                     157                15.653041
# 9                  C                     155                15.453639
# 10               TeX                     151                15.054835
# 11             CMake                      98                 9.770688
# 12                 R                      94                 9.371884
# 13         Batchfile                      92                 9.172483
# 14              Java                      77                 7.676969
# [2025-05-13 12:54:20,833] INFO:dataset languages information written out to data/analysis_run_sample_45pc_cluster0_2025-05-13/sample_languages_info__2025-05-13.csv
# [2025-05-13 12:54:21,297] INFO:Plot saved out to file images/analysis_run_sample_45pc_cluster0_2025-05-13/sample_languages_2025-05-13.png.
# [2025-05-13 12:54:21,298] INFO:Sample repos languages info collected and written out and plotted.
# [2025-05-13 12:54:21,408] INFO:Processed sample data written out to data/analysis_run_sample_45pc_cluster0_2025-05-13/pre-processing_dataset_x1003repos_x2357project-individuals__2025-05-13.csv
# [2025-05-13 12:54:21,408] INFO:Data will be clustered on the following 10 variables: ['pc_commit_created', 'pc_issue_created', 'pc_issue_closed', 'pc_issues_assigned_of_assigned', 'pc_pull_request_created', 'pc_pull_request_closed', 'pc_DC', 'pc_sum_n_interactions', 'pc_interaction_days', 'pc_created-closed_issues'].
# [2025-05-13 12:54:21,430] INFO:Clustering dataset has shape (2357, 10)
# [2025-05-13 12:54:21,430] INFO:Attempting to use 2357 repo-individuals dataset for clustering
# [2025-05-13 12:54:21,739] INFO:Created ward clustering linkage object, now attempting to generate dendrogram
# [2025-05-13 12:54:22,644] INFO:Plot saved out to file images/analysis_run_sample_45pc_cluster0_2025-05-13/sample_dendrogram__2025-05-13.png.
# [2025-05-13 12:54:22,644] INFO:clustering data is df, with shape: (2357, 10).
# [2025-05-13 12:54:22,880] INFO:CH score for n_clusters 2 is 830.7914322998251.
# [2025-05-13 12:54:23,068] INFO:CH score for n_clusters 3 is 602.3836673042332.
# [2025-05-13 12:54:23,262] INFO:CH score for n_clusters 4 is 518.0883168409516.
# [2025-05-13 12:54:23,471] INFO:CH score for n_clusters 5 is 451.9669120863637.
# [2025-05-13 12:54:23,657] INFO:CH score for n_clusters 6 is 417.7133720867297.
# [2025-05-13 12:54:23,846] INFO:CH score for n_clusters 7 is 399.1372489480757.
# [2025-05-13 12:54:24,034] INFO:CH score for n_clusters 8 is 383.4109143950731.
# [2025-05-13 12:54:24,221] INFO:CH score for n_clusters 9 is 363.9283488709656.
# [2025-05-13 12:54:24,410] INFO:CH score for n_clusters 10 is 348.0787136601301.
# [2025-05-13 12:54:24,416] INFO:CH scores for 9 clusters written out to file data/analysis_run_sample_45pc_cluster0_2025-05-13/sample_calinski-harabasz_scores_across_N_clusters__2025-05-13.csv.
# [2025-05-13 12:54:24,417] INFO:Calinski-Harabasz Score evaluation of 10 clusters shows best number of clusters for sample is 2 with score 830.7914322998251.
# [2025-05-13 12:54:24,593] INFO:Plot saved out to file images/analysis_run_sample_45pc_cluster0_2025-05-13/sample_CHscore_per_Ncluster__2025-05-13.png.
# [2025-05-13 12:54:24,664] INFO:Generating best_n_clusters: 2.
# [2025-05-13 12:54:24,664] INFO:Attempting clustering with dataset shape (2357, 10) and 10 columns: Index(['pc_commit_created', 'pc_issue_created', 'pc_issue_closed',
#        'pc_issues_assigned_of_assigned', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_DC', 'pc_sum_n_interactions',
#        'pc_interaction_days', 'pc_created-closed_issues'],
#       dtype='object').
# [2025-05-13 12:54:24,884] INFO:Applied 2 cluster labels to dataset to create labelled dataset of shape: (2357, 86).
# [2025-05-13 12:54:24,940] INFO:Explained variability per principal component: [0.42087225 0.18908615]
# [2025-05-13 12:54:25,259] INFO:PCA 2D Plot saved out to file images/analysis_run_sample_45pc_cluster0_2025-05-13/sample_2D_PCA__2025-05-13.png.
# [2025-05-13 12:54:25,290] INFO:Explained variability per principal component: [0.42087225 0.18908615 0.15550259]
# [2025-05-13 12:54:25,523] INFO:PCA 3D Plot saved out to file images/analysis_run_sample_45pc_cluster0_2025-05-13/sample_3D_PCA__2025-05-13.png.
# [2025-05-13 12:54:25,523] INFO:Generating feature importance ranking for PCA via clustering data.
# [2025-05-13 12:54:25,523] INFO:clustering data is df, with shape: (2357, 10).
# [2025-05-13 12:54:25,523] INFO:Re-applying PCA and gathering PCA values from clustering data.
# [2025-05-13 12:54:25,543] INFO:Gathering feature importance values for each variable involved in clustering. These were: ['pc_commit_created', 'pc_issue_created', 'pc_issue_closed', 'pc_issues_assigned_of_assigned', 'pc_pull_request_created', 'pc_pull_request_closed', 'pc_DC', 'pc_sum_n_interactions', 'pc_interaction_days', 'pc_created-closed_issues']
# [2025-05-13 12:54:25,563] INFO:PCA feature importances ranked:
# [2025-05-13 12:54:25,563] INFO:PCA1 mainly explained by pc_pull_request_closed with importance value 0.48950801763581214.
# [2025-05-13 12:54:25,563] INFO:PCA2 mainly explained by pc_issues_assigned_of_assigned with importance value 0.9566871283031092.
# [2025-05-13 12:54:25,563] INFO:PCA3 mainly on pc_pull_request_created with importance value 0.495440433935109.
    
# (coding-smart-github) flic@eidf103-vm:~/clonezone/coding-smart$(parse_git_branch)$ time python githubanalysis/analysis/analyse_data.py -d subsample_45pc_cluster_0_data__2025-05-13.csv -z sample_45pc_cluster0

# real    0m7.906s
# user    0m11.221s
# sys     0m0.794s

# %%
# PC of sample repos from POPULATION N repos.
(1284 / 36226)*100
# Out:
# 3.5444156130955666

# %%
# PC of unique gh_usernames in sample which appear 
# in more than one repo_name
(10140 / 97521)*100
# Out:
# 10.397760482357645

# %%
# plotting details: 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion,

# %%
orig_data_file = "../../data/merged-data-per-dev_x2868-repos_2025-05-10.csv"
analysis_dataset_file = "../../data/analysis_run_sample_45pc_cluster0_2025-05-13/clustered_sample_data_with_labels__2025-05-13.csv"
# via:  "../../data/merged-data-per-dev_x2868-repos_2025-05-10.csv" and merged-interactions-data-per-dev_x2946-repos_2025-05-12.csv
sample_repo_stats_file = "../../data/analysis_run_sample_45pc_cluster0_2025-05-13/summarised_SAMPLE_repos_stats_2025-05-13.csv"
study_repos_file = "../../data/study-sample-repo-names_2025-05-01_x2981.txt"

# %%
orig_dataset = pd.read_csv(orig_data_file, header=0, low_memory=False)
orig_dataset
# Out:
#                               repo_name  author_username  \
# 0                     WIPACrepo/iceprod     actions-user
# 1                     WIPACrepo/iceprod           alemsh
# 2                     WIPACrepo/iceprod         carlwitt
# 3                     WIPACrepo/iceprod  dependabot[bot]
# 4                     WIPACrepo/iceprod         dsschult
# ...                                 ...              ...
# 244138            trendscenter/coinstac              NaN
# 244139            trendscenter/coinstac              NaN
# 244140               geopython/pygeoapi              NaN
# 244141  h2020-westlife-eu/virtualfolder              NaN
# 244142  h2020-westlife-eu/virtualfolder              NaN
#
#         n_of_commit_creators  n_commits  pc_repo_commits  n_changes  \
# 0                       12.0        7.0         0.271108       40.0
# 1                       12.0        1.0         0.038730      151.0
# 2                       12.0        1.0         0.038730        2.0
# 3                       12.0       10.0         0.387297       24.0
# 4                       12.0     2275.0        88.109992  1117264.0
# ...                      ...        ...              ...        ...
# 244138                   NaN        0.0         0.000000        NaN
# 244139                   NaN        0.0         0.000000        NaN
# 244140                   NaN        0.0         0.000000        NaN
# 244141                   NaN        0.0         0.000000        NaN
# 244142                   NaN        0.0         0.000000        NaN
#
#         mean_n_changes  median_n_changes_changed  std_n_changes_changed  \
# 0             5.714286                       5.0               1.253566
# 1           151.000000                     151.0                    NaN
# 2             2.000000                       2.0                    NaN
# 3             2.400000                       2.0               1.264911
# 4           491.105055                      10.0            4118.362826
# ...                ...                       ...                    ...
# 244138             NaN                       NaN                    NaN
# 244139             NaN                       NaN                    NaN
# 244140             NaN                       NaN                    NaN
# 244141             NaN                       NaN                    NaN
# 244142             NaN                       NaN                    NaN
#
#         n_files_changed  ...  pc_repo_issues  n_of_issues_creators  \
# 0                  14.0  ...        0.000000                   NaN
# 1                   6.0  ...        0.234192                  18.0
# 2                   1.0  ...        0.468384                  18.0
# 3                  12.0  ...        5.386417                  18.0
# 4               10371.0  ...       84.543326                  18.0
# ...                 ...  ...             ...                   ...
# 244138              NaN  ...        0.000000                   NaN
# 244139              NaN  ...        0.000000                   NaN
# 244140              NaN  ...        0.000000                   NaN
# 244141              NaN  ...        0.000000                   NaN
# 244142              NaN  ...        0.000000                   NaN
#
#         assigned_devs  n_issues_assigned  pc_issues_assigned_of_assigned  \
# 0          unassigned                0.0                        0.000000
# 1              alemsh                1.0                        0.390625
# 2          unassigned                0.0                        0.000000
# 3          unassigned                0.0                        0.000000
# 4            dsschult              216.0                       84.375000
# ...               ...                ...                             ...
# 244138   krootesmurdy                5.0                        2.590674
# 244139  sunithabasodi               10.0                        5.181347
# 244140     msmitherdc                2.0                        0.519481
# 244141   chrishmorris                1.0                        2.857143
# 244142         kouril                1.0                        2.857143
#
#             _merge   issue_username  commiss_merge      gh_username  \
# 0              NaN              NaN      left_only     actions-user
# 1             both           alemsh           both           alemsh
# 2        left_only         carlwitt           both         carlwitt
# 3        left_only  dependabot[bot]           both  dependabot[bot]
# 4             both         dsschult           both         dsschult
# ...            ...              ...            ...              ...
# 244138  right_only     krootesmurdy     right_only     krootesmurdy
# 244139  right_only    sunithabasodi     right_only    sunithabasodi
# 244140  right_only       msmitherdc     right_only       msmitherdc
# 244141  right_only     chrishmorris     right_only     chrishmorris
# 244142  right_only           kouril     right_only           kouril
#
#         _dataset_source
# 0          Only Commits
# 1                  Both
# 2                  Both
# 3                  Both
# 4                  Both
# ...                 ...
# 244138      Only Issues
# 244139      Only Issues
# 244140      Only Issues
# 244141      Only Issues
# 244142      Only Issues
#
# [244143 rows x 48 columns]

# %%
orig_dataset.groupby(["repo_name", "gh_username"]).ngroups
# Out:
# 244143

# %%
orig_dataset.n_commits.sum() # number of commits 4.7million across all 262,706 repo-individs
# Out:
# 4746707.0

# %%
orig_dataset.n_issues.sum() # number of issues 1.7 million across all 262,706 repo-indiviuals
# Out:
# 1772477.0

# %%
orig_dataset.n_issues_assigned.sum() # 400,000 issues assigned across all 262,706 repo-individuals
# Out:
# 404572.0

# %%
orig_dataset.groupby("repo_name").size()
# SHOWS FIX IN NAMES: 
# repo_name
# 1313e/CMasher                         33
# 3MAH/microgen                         13
# 3dct/open_iA                          18
# 4DNucleome/PartSeg                    23
# 52North/javaPS                        16
#                                     ... 
# zfit/zfit                             65
# zkbt/chromatic                        19
# zooniverse/aggregation-for-caesar     33
# zqfang/GSEApy                        190
# zwicker-group/py-pde                  65

# PREVIOUS PUIR EFFORT:
# repo_name
# 1313e/CMasher                         33
# 3MAH/microgen                         13
# 3dct/open_iA                          18
# 4DNucleome/PartSeg                    23
# 52North/javaPS                        16
#                                     ... 
# zooniverse/aggregation-for-caesar     32
# zooniverse/aggregation/for/caesar     19
# zqfang/GSEApy                        190
# zwicker-group/py-pde                  65
# zwicker/group/py/pde                   7
# Out:
# repo_name
# 1313e/CMasher                         33
# 3MAH/microgen                         13
# 3dct/open_iA                          18
# 4DNucleome/PartSeg                    23
# 52North/javaPS                        16
#                                     ...
# zfit/zfit                             65
# zkbt/chromatic                        19
# zooniverse/aggregation-for-caesar     33
# zqfang/GSEApy                        190
# zwicker-group/py-pde                  65
# Length: 2868, dtype: int64

# %%
# read in the analysed dataset with cluster labels
analysis_dataset = pd.read_csv(analysis_dataset_file, header=0, low_memory=False)
#analysis_dataset.columns

# %%
analysis_dataset.cluster_labels.value_counts(dropna=False)
# cluster_labels
# 1    106079
# 0      1879
# Name: count, dtype: int64
# Out:
# cluster_labels
# 0    1781
# 1     576
# Name: count, dtype: int64

# %%
subsample_cluster0 = analysis_dataset.query("cluster_labels == 0")[["repo_name", "gh_username", "cluster_labels"]]
subsample_cluster0
# Out:
#                                             repo_name       gh_username  \
# 0                 SINTEF/AutoActive-ActivityPresenter          aliverud
# 1                              feelpp/book.feelpp.org   dependabot[bot]
# 2                              feelpp/book.feelpp.org  vincentchabannes
# 4                                       LDflex/LDflex   dependabot[bot]
# 6                           TuringLang/AdvancedHMC.jl           ErikQQY
# ...                                               ...               ...
# 2352                                  ctuning/ck-math           ens-lg4
# 2353                                  ctuning/ck-math           gfursin
# 2354                               coin-or/python-mip             h-g-s
# 2355  Open-Science-Training-Handbook/handbook_content          helenebr
# 2356                            opencitations/oc_meta            ivanhb
#
#       cluster_labels
# 0                  0
# 1                  0
# 2                  0
# 4                  0
# 6                  0
# ...              ...
# 2352               0
# 2353               0
# 2354               0
# 2355               0
# 2356               0
#
# [1781 rows x 3 columns]

# %%
subsample_0 = pd.merge(subsample_cluster0, orig_dataset, on=["gh_username", "repo_name"], )
subsample_0.drop(columns=["cluster_labels"], inplace=True)

dataanalyser.writeout_data_to_csv(subsample_0, "subsample_45pc_cluster_0_data_")
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster0_2025-05-13/subsample_45pc_cluster_0_data__2025-05-13.csv')

# %%
subsample_cluster1 = analysis_dataset.query("cluster_labels == 1")[["repo_name", "gh_username", "cluster_labels"]]
subsample_cluster1
# Out:
#                       repo_name    gh_username  cluster_labels
# 3                 LDflex/LDflex  RubenVerborgh               1
# 5                 LDflex/LDflex          jeswr               1
# 7     TuringLang/AdvancedHMC.jl        xukai92               1
# 8     TuringLang/AdvancedHMC.jl          yebai               1
# 9                 TGAC/brassica       kammerer               1
# ...                         ...            ...             ...
# 2332          PhiLFitters/kafe2      cverstege               1
# 2335                NREL/OpenOA     jordanperr               1
# 2336         cohenlabUNC/clpipe           trh3               1
# 2340      INCF/BIDS-Starter-Kit       Remi-Gau               1
# 2344           Ouranosinc/raven          huard               1
#
# [576 rows x 3 columns]

# %%
subsample_1 = pd.merge(subsample_cluster1, orig_dataset, on=["gh_username", "repo_name"], )
subsample_1.drop(columns=["cluster_labels"], inplace=True)

dataanalyser.writeout_data_to_csv(subsample_1, "subsample_45pc_cluster_1_data_")
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster0_2025-05-13/subsample_45pc_cluster_1_data__2025-05-13.csv')

# %%
subsample_cluster2 = analysis_dataset.query("cluster_labels == 2")[["repo_name", "gh_username", "cluster_labels"]]
subsample_cluster2
# Out:
# Empty DataFrame
# Columns: [repo_name, gh_username, cluster_labels]
# Index: []

# %%
subsample_2 = pd.merge(subsample_cluster2, orig_dataset, on=["gh_username", "repo_name"], )
subsample_2.drop(columns=["cluster_labels"], inplace=True)

dataanalyser.writeout_data_to_csv(subsample_2, "subsample_45pc_cluster_2_data_")
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster0_2025-05-13/subsample_45pc_cluster_2_data__2025-05-13.csv')

# %%
len(analysis_dataset)
# Out:
# 2357

# %%
cluster1_issues_only = len(analysis_dataset.query("cluster_labels == 1 and which_interactions == 'issue_created'")[["gh_username", "repo_name", "cluster_labels", "breadth_interactions", "which_interactions"]])
cluster0_issues_only = len(analysis_dataset.query("cluster_labels == 0 and which_interactions == 'issue_created'")[["gh_username", "repo_name", "cluster_labels", "breadth_interactions", "which_interactions"]])

print(f'Cluster 0 contains {cluster0_issues_only} issues_only folks of {len(analysis_dataset.query("cluster_labels == 0"))}; cluster 1 contains {cluster1_issues_only} issues_only folks of {len(analysis_dataset.query("cluster_labels == 1"))}.')
# Out:
# Cluster 0 contains 27 issues_only folks of 1781; cluster 1 contains 0 issues_only folks of 576.

# %%
#analysis_dataset.query("cluster_labels == 0 and which_interactions == 'issue_created'")[["gh_username", "repo_name", "cluster_labels", "breadth_interactions", "which_interactions"]]
# 53736 rows × 5 columns

no_issues_only = analysis_dataset.query("which_interactions != 'issue_created'")[["repo_name","gh_username",]]
no_issues_only_sample = pd.merge(no_issues_only, orig_dataset, on=["repo_name","gh_username"], )
no_issues_only_sample
dataanalyser.writeout_data_to_csv(no_issues_only_sample, "subsample_no_issues_only_data_") 
#no_issues_only_sample

# no initial cluster 1 w/ issues only; cluster 0 only. 
# Removing issues_only leaves 52595 repo-individuals in analysis dataset (ie total 107958 - issues-only 55363).
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster0_2025-05-13/subsample_no_issues_only_data__2025-05-13.csv')

# %%
analysis_dataset.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
analysis_dataset.groupby("repo_name")["n_of_commit_creators"].mean().max()
# Out:
# 283.0

# %%
sample_repo_stats = pd.read_csv(sample_repo_stats_file, header=0, low_memory=False)
#sample_repo_stats.columns
sample_repo_stats
# Out:
#                         repo_name  initial_HTTP_code  issues_enabled  \
# 0                   3MAH/microgen                200            True
# 1                    3dct/open_iA                200            True
# 2                  52North/javaPS                200            True
# 3           AAROC/AnsibleBootCamp                200            True
# 4                 AIDASoft/DD4hep                200            True
# ...                           ...                ...             ...
# 998                 xopt-org/Xopt                200            True
# 999                  xsuite/xpart                200            True
# 1000       ythuang0522/homopolish                200            True
# 1001  zarr-developers/zarr-python                200            True
# 1002              zfit/phasespace                200            True
#
#       repo_license  repo_visibility  repo_is_fork  devs  \
# 0          GPL-3.0             True         False    10
# 1          GPL-3.0             True         False    28
# 2       Apache-2.0             True         False    12
# 3       Apache-2.0             True         False    21
# 4         LGPL-3.0             True         False    72
# ...            ...              ...           ...   ...
# 998     Apache-2.0             True         False    23
# 999     Apache-2.0             True         False    18
# 1000       GPL-3.0             True         False    13
# 1001           MIT             True         False   126
# 1002  BSD-3-Clause             True         False    11
#
#                                           repo_language  \
# 0        ['Python', 'Dockerfile', 'Batchfile', 'Shell']
# 1     ['C++', 'SCSS', 'CMake', 'C', 'Cuda', 'Makefil...
# 2     ['Java', 'Dockerfile', 'CSS', 'HTML', 'JavaScr...
# 3                     ['TeX', 'Jinja', 'Ruby', 'Shell']
# 4     ['C++', 'Python', 'CMake', 'C', 'Shell', 'Emac...
# ...                                                 ...
# 998                                 ['Python', 'Shell']
# 999                                 ['Python', 'Shell']
# 1000                                         ['Python']
# 1001                                         ['Python']
# 1002                           ['Python', 'C++', 'TeX']
#
#       total_commits_last_year  has_PRs             last_PR_update  \
# 0                          38     True  2025-04-22 12:32:11+00:00
# 1                         459     True  2024-06-04 19:16:55+00:00
# 2                           0     True  2023-04-04 17:06:09+00:00
# 3                           0     True  2023-12-18 09:15:04+00:00
# 4                         257     True  2025-04-16 08:21:01+00:00
# ...                       ...      ...                        ...
# 998                       343     True  2025-04-22 19:45:04+00:00
# 999                        72     True  2025-03-27 14:52:45+00:00
# 1000                        1     True  2025-03-31 07:34:29+00:00
# 1001                      515     True  2025-04-28 16:34:39+00:00
# 1002                       10     True  2025-04-07 18:33:36+00:00
#
#       open_tickets  closed_tickets  repo_age_days  n_commits_main_branch
# 0                0               0           1396                    789
# 1                0               0           3245                   8712
# 2                0               0           3386                    689
# 3                0               0           3466                    230
# 4                0               0           3240                   4594
# ...            ...             ...            ...                    ...
# 998              0               0           2218                   1947
# 999              0               0           1412                    890
# 1000             0               0           1747                    167
# 1001             0               0           3422                   2491
# 1002             0               0           2252                    675
#
# [1003 rows x 15 columns]

# %%
sample_repo_stats.repo_license.value_counts(dropna=False,normalize=True)*100
# Out:
# repo_license
# MIT             34.097707
# Apache-2.0      18.444666
# BSD-3-Clause    16.350947
# GPL-3.0         15.453639
# GPL-2.0          3.489531
# LGPL-3.0         2.293121
# BSD-2-Clause     2.093719
# AGPL-3.0         1.894317
# CC-BY-4.0        1.794616
# CC0-1.0          1.096710
# LGPL-2.1         0.897308
# MPL-2.0          0.697906
# CC-BY-SA-4.0     0.498504
# Unlicense        0.398804
# EUPL-1.2         0.199402
# EPL-1.0          0.099701
# EPL-2.0          0.099701
# ISC              0.099701
# Name: proportion, dtype: float64

# %%
sample_repo_stats.repo_license.nunique()
# Out:
# 18

# %% [markdown]
# ## N Repos

# %%
print(f"There are {analysis_dataset.groupby(['repo_name'], as_index=False).ngroups} repos")
# Out:
# There are 1003 repos

# %% [markdown]
# ## N Repo-Individuals

# %%
grouped_by_devs = analysis_dataset.groupby(["gh_username", "repo_name"], as_index=False)
print(f"There are {grouped_by_devs.ngroups} repo-individuals")
# Out:
# There are 2357 repo-individuals

# %% [markdown]
# ## N GH-Usernames

# %%
multi_repo_users = analysis_dataset.groupby("gh_username")[["repo_name"]].count().reset_index(names=["gh_username", "count"])
multi_repo_users = multi_repo_users.query("repo_name > 1")
total_gh_users = analysis_dataset.groupby("gh_username").ngroups

print(f"There are {len(multi_repo_users)} gh-usernames which appear in more than one repository within the sample; this represents {round((len(multi_repo_users)/total_gh_users)*100, 2)}% of all {total_gh_users} unique gh-usernames \n")

uptotenrepos = multi_repo_users.query("repo_name <= 10")
tentohundredrepos = multi_repo_users.query("repo_name > 10 and repo_name <= 100")
hundredup = multi_repo_users.query("repo_name > 100")


if len(uptotenrepos) > 1: 
    print(f"There are {len(uptotenrepos)} gh-usernames in between 2 and 10 repos in the sample. \n")

else:
    print("no users in 2+ repos")

if len(tentohundredrepos) > 1: 
    print(f"There are {len(tentohundredrepos)} gh-usernames in between 11 and 100 repos in the sample. \n")
    #print(tentohundredrepos.query("repo_name > 50").sort_values(by="repo_name"))
else: 
    print("no users in 10+ repos")
    
if len(hundredup) > 1: 
    print(f"There are {len(hundredup)} gh-usernames in > 100 repos in the sample. \n")
    print(hundredup.sort_values(by="repo_name"))

else: 
     print("no users in 100+ repos")
# Out:
# There are 173 gh-usernames which appear in more than one repository within the sample; this represents 8.4% of all 2060 unique gh-usernames
#
# There are 171 gh-usernames in between 2 and 10 repos in the sample.
#
# There are 2 gh-usernames in between 11 and 100 repos in the sample.
#
# no users in 100+ repos

# %%
multi_repo_users.repo_name.mean()
# Out:
# 2.7167630057803467

# %%
print(tentohundredrepos.query("repo_name > 20").sort_values(by="repo_name")) # how many of these are bots?
# Out:
#          gh_username  repo_name
# 732  dependabot[bot]         47

# %%
print("BOTS: anything ending [bot], anything ending -badger, probably anything ending Bot or -bot")
# Out:
# BOTS: anything ending [bot], anything ending -badger, probably anything ending Bot or -bot

# %%
sns.histplot(data=uptotenrepos, x="repo_name", stat="count", binwidth=1, color="black")
# Out:
# <Axes: xlabel='repo_name', ylabel='Count'>

# %%
sns.histplot(data=tentohundredrepos, x="repo_name", stat="count", binwidth=1, color="black")
# Out:
# <Axes: xlabel='repo_name', ylabel='Count'>

# %%
#sns.histplot(data=hundredup, x="repo_name", stat="count", binwidth=1, color="black")

# %% [markdown]
# # Initial Clustering:

# %%
# N clusters: 
# distribution of repo-individuals amongst cluster labels: 
# distirbution of clusters within repos 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion,

# %%
analysis_dataset.cluster_labels.value_counts()
# Out:
# cluster_labels
# 0    1781
# 1     576
# Name: count, dtype: int64

# %%
cl0 = round((analysis_dataset.cluster_labels.value_counts(normalize=True)[0]*100), 2)
cl1 = round((analysis_dataset.cluster_labels.value_counts(normalize=True)[1]*100), 2)
#cl2 = round((analysis_dataset.cluster_labels.value_counts(normalize=True)[2]*100), 2)

# how are the users distributed across clusters: what size are the clusters? 
g = sns.countplot(
    data=analysis_dataset, 
    x="cluster_labels", 
    hue="cluster_labels", 
    stat="count", 
    palette=label_color_dict, 
)
#g.tick_params(axis='x', which='both', rotation=70)
g.set_title("Distribution of Repo-Individuals Across Sub-Clusters within Initial Cluster 2")
g.set_xlabel("Cluster Label")
g.set_ylabel("N of Repo-Individuals")
plt.legend(title="Clusters", loc='upper left', labels=[f"{cl0}%", f"{cl1}%",])# f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_subcluster_distribution_{current_date_info}.png") 
plt.show(g)

# %%
devs_per_cluster = analysis_dataset.groupby(["repo_name", "cluster_labels"])["gh_username"].count().reset_index(name="n_devs")
devs_per_cluster

cl0 = f'{devs_per_cluster.groupby("cluster_labels")["n_devs"].count()[0]} repos'
cl1 = f'{devs_per_cluster.groupby("cluster_labels")["n_devs"].count()[1]} repos'
#cl2 = f'{devs_per_cluster.groupby("cluster_labels")["n_devs"].count()[2]} repos'

labels = [cl0, cl1,]# cl2]

g = sns.barplot(
    data=devs_per_cluster, 
    x="cluster_labels", 
    y="n_devs", 
    hue="cluster_labels",
    estimator="mean", 
    palette=label_color_dict, 
    legend="full",
)
g.set_title("Distribution of Clusters Across Repositories")
g.set_xlabel("Cluster Label")
g.set_ylabel("Mean Number of Repo-Individuals")
h, l = g.get_legend_handles_labels()
g.legend(h, labels, title="Clusters", loc="upper right")

plt.legend(labels, title="Clusters", loc='upper left')
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_initial_cluster_repo_distribution_{current_date_info}.png") 
plt.show(g)
print(f"There are {analysis_dataset.groupby('repo_name').ngroups} unique repositories in this sample")
# Out:
# There are 1003 unique repositories in this sample

# %%
clusters_per_repo = devs_per_cluster.groupby("repo_name")["cluster_labels"].nunique().reset_index(name="n_clusters")
clusters_per_repo

clusters_per_repo.n_clusters.mean()

g = sns.countplot(
    data=clusters_per_repo, 
    x="n_clusters",
    color="black"
    #hue="cluster_labels",
    #palette=label_color_dict, 
)
g.set_title("Diversity of Clusters Across Repositories")
g.set_xlabel("Number of Clusters Present")
g.set_ylabel("Number of Repositories with N Clusters")
#h, l = g.get_legend_handles_labels()
#g.legend(h, labels, title="Clusters", loc="upper right")
#plt.legend(labels, title="Clusters", loc='upper right',)
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_n-clusters-present-per-repo_{current_date_info}.png") 
plt.show(g)

# %%
clusters_per_repo.groupby("n_clusters").count()
# Out:
#             repo_name
# n_clusters
# 1                 620
# 2                 383

# %% [markdown]
# ## Interaction Types

# %% [markdown]
# ### UIT: number of different types

# %%
# aka. breadth_interactions in df
sum(analysis_dataset.breadth_interactions.isna()) # no missing data in this col
# Out:
# 0

# %%
sns.catplot(data=analysis_dataset, x="breadth_interactions", kind="count", color="black")
# distribution of interaction types per repo-individual

# %%
sns.catplot(data=analysis_dataset, x="breadth_interactions", kind="count", hue="cluster_labels", palette=label_color_dict,  )
# distribution of interaction types per repo-individual by initial cluster

# %%
print(f"Min breadth of interactions by repo-individuals is: {analysis_dataset.breadth_interactions.min()}; and max is: {analysis_dataset.breadth_interactions.max()}.")
print(f"Mode breadth of interactions by repo-individuals is: {analysis_dataset.breadth_interactions.mode()[0]} interaction type.")
# Out:
# Min breadth of interactions by repo-individuals is: 1; and max is: 6.
# Mode breadth of interactions by repo-individuals is: 6 interaction type.

# %%
# how many only single type?
print(f"There are {len(analysis_dataset.query('breadth_interactions == 1'))} repo-individuals with single interaction types")
# which type? (see later)
# Out:
# There are 34 repo-individuals with single interaction types

# %%
# which many show >1 type?
print(f"There are {len(analysis_dataset.query('breadth_interactions > 1'))} repo-individuals with more than one interaction type")
# Out:
# There are 2323 repo-individuals with more than one interaction type

# %%
# repo-individ UIT vs their repo mean UITs: TODO

# %%
# per-repo mean UIT value: 
analysis_dataset.groupby(["repo_name"])["breadth_interactions"].mean()
# Out:
# repo_name
# 3MAH/microgen                  5.250000
# 3dct/open_iA                   5.000000
# 52North/javaPS                 4.000000
# AAROC/AnsibleBootCamp          3.000000
# AIDASoft/DD4hep                5.750000
#                                  ...
# xopt-org/Xopt                  5.000000
# xsuite/xpart                   2.666667
# ythuang0522/homopolish         3.166667
# zarr-developers/zarr-python    6.000000
# zfit/phasespace                5.000000
# Name: breadth_interactions, Length: 1003, dtype: float64

# %%
# sample mean UIT value:
print(f"The overall sample mean UIT (average number of included interaction interaction types) per repo-individual is {round(analysis_dataset['breadth_interactions'].mean(), 3)}")
# Out:
# The overall sample mean UIT (average number of included interaction interaction types) per repo-individual is 5.023

# %%
print("The mean breadth of interactions per initial cluster labelling are:")
analysis_dataset.groupby(["cluster_labels"])["breadth_interactions"].mean()
# Out:
# The mean breadth of interactions per initial cluster labelling are:
# cluster_labels
# 0    4.884896
# 1    5.449653
# Name: breadth_interactions, dtype: float64

# %%
# how are the users distributed across clusters: what size are the clusters? 
g = sns.countplot(
    data=analysis_dataset, 
    x="breadth_interactions", 
    hue="cluster_labels", 
    stat="count", 
    palette=label_color_dict, 
)
#g.tick_params(axis='x', which='both', rotation=70)
g.set_title("Distribution of Repo-Individuals by UIT")
g.set_xlabel("N of Unique Interaction Types (UIT)")
plt.legend(title="Clusters", loc='upper right',) #labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_commit_created",
    hue="cluster_labels", 
    #binwidth=1,
    estimator="mean",
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Commit Creation")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' Commits")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_RC-commit_creation_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# Issue creation
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_issue_created",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Issue Ticket Creation")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' Issues Created")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_RC-issue_creation_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# Issue closure
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_issue_closed",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Issue Ticket Closing")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' Issues Closed")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_RC-issue_closure_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# Issue assignment
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_issues_assigned_of_assigned",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("Mean Percentage Contribution Depth of Issue Ticket Assignment")
g.set_ylabels("% of Repos' Issues Assigned")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_breadth_depth_pc_issue_assignment_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# PRs
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_pull_request_created",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Pull Request Creation")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' PRs")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_RC-PRs_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %% [markdown]
# ### Combinations of Types:

# %%
sum(analysis_dataset.which_interactions.isna()) # no missing data
# Out:
# 0

# %%
from githubanalysis.visualization.plot_repoindividual_upset_plot import UpsetPlotter

upsetplotter = UpsetPlotter(
    in_notebook=True,
    logger=None, 
)

# %%
print("{Plotting single combined sample UpSet Plot")
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=analysis_dataset,
    sort_combos_by="cardinality",
    file_name="sample_upset_plot_45pc_cluster0_all",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot without separating by clusters
# INFO:data is df, with shape: (2357, 86).
# INFO:Attempting to plot cluster whole_dataset using colour black.
# {Plotting single combined sample UpSet Plot
# INFO:Plot saved out to file ../../images/sample_upset_plot_45pc_cluster0_all_whole_dataset_2025-05-13.pdf.
# INFO:Completed UpSet plotting.

# %%
print("Plotting separate clusters into UpSet Plot: this doesn't currently work in the script")

tmp0 = analysis_dataset.query("cluster_labels == 0")
tmp1 = analysis_dataset.query("cluster_labels == 1")
# Out:
# Plotting separate clusters into UpSet Plot: this doesn't currently work in the script

# %%
# plot cluster 0
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp0,
    sort_combos_by="cardinality",
    file_name="sample_upset_plot_45pc_cluster0_cluster0_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot without separating by clusters
# INFO:data is df, with shape: (1781, 86).
# INFO:Attempting to plot cluster whole_dataset using colour black.
# INFO:Plot saved out to file ../../images/sample_upset_plot_45pc_cluster0_cluster0__whole_dataset_2025-05-13.pdf.
# INFO:Completed UpSet plotting.

# %%
# plot cluster 1
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    sort_combos_by="cardinality",
    file_name="sample_upset_plot_45pc_cluster0_cluster1_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot without separating by clusters
# INFO:data is df, with shape: (576, 86).
# INFO:Attempting to plot cluster whole_dataset using colour black.
# INFO:Plot saved out to file ../../images/sample_upset_plot_45pc_cluster0_cluster1__whole_dataset_2025-05-13.pdf.
# INFO:Completed UpSet plotting.

# %% [markdown]
# ## MRC:

# %%
# pc_DC (percentage DEPTH of contribution across all of users' interactions)

g = sns.catplot(
    data=analysis_dataset, 
    x="cluster_labels", 
    y="pc_DC",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict, 
    legend = False,
)
#g.tick_params(axis='x', which='both', rotation=70)
#g.axes.legend().set_title("")
#g.add_legend(title="Clusters", loc='upper right',) #labels=['0', '1', '2']))
g.fig.subplots_adjust(top=0.9) # adjust the Figure in rp
g.fig.suptitle("Mean Repository Contributions by Repo-Individuals")
g.axes[0,0].set_xlabel('Cluster Label')
g.axes[0,0].set_ylabel('% Mean Repository Contribution')
plt.tight_layout()
#.axes.set_le
#plt.legend(title="Clusters", loc='upper left',) #labels=['0', '1', '2'])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_sample_mrc_cluster_{current_date_info}.png") 
plt.show(g)

# %%
analysis_dataset.groupby("breadth_interactions")["pc_DC"].mean()
# Out:
# breadth_interactions
# 1    12.846896
# 2    11.962243
# 3    14.259033
# 4    15.075677
# 5    17.798280
# 6    21.836160
# Name: pc_DC, dtype: float64

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
g = sns.boxplot(data=analysis_dataset,
    x="breadth_interactions", 
    y="pc_DC",
    hue="cluster_labels", 
    palette = label_color_dict)
g.set_title("% Mean Repository Contribution by Unique Interaction Types")
g.set_xlabel("UIT")
g.set_ylabel("% Mean Repository Contributions")
plt.legend(title="Clusters", loc='upper left',)# labels=[0,1,2])
plt.tight_layout()
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_uit_mrc_cluster_{current_date_info}.png") 
plt.show(g)

# %%
analysis_dataset
# Out:
#       cluster_labels                                        repo_name  \
# 0                  0              SINTEF/AutoActive-ActivityPresenter
# 1                  0                           feelpp/book.feelpp.org
# 2                  0                           feelpp/book.feelpp.org
# 3                  1                                    LDflex/LDflex
# 4                  0                                    LDflex/LDflex
# ...              ...                                              ...
# 2352               0                                  ctuning/ck-math
# 2353               0                                  ctuning/ck-math
# 2354               0                               coin-or/python-mip
# 2355               0  Open-Science-Training-Handbook/handbook_content
# 2356               0                            opencitations/oc_meta
#
#            gh_username   author_username  n_of_commit_creators  n_commits  \
# 0             aliverud          aliverud                   8.0      171.0
# 1      dependabot[bot]   dependabot[bot]                  24.0       36.0
# 2     vincentchabannes  vincentchabannes                  24.0      245.0
# 3        RubenVerborgh     RubenVerborgh                  10.0      191.0
# 4      dependabot[bot]   dependabot[bot]                  10.0      334.0
# ...                ...               ...                   ...        ...
# 2352           ens-lg4               NaN                   NaN        0.0
# 2353           gfursin               NaN                   NaN        0.0
# 2354             h-g-s               NaN                   NaN        0.0
# 2355          helenebr               NaN                   NaN        0.0
# 2356            ivanhb               NaN                   NaN        0.0
#
#       n_changes  mean_n_changes  median_n_changes_changed  \
# 0       42031.0      245.795322                      20.0
# 1        4966.0      137.944444                      12.0
# 2      296592.0     1210.579592                      42.0
# 3       45116.0      236.209424                      36.0
# 4      139050.0      416.317365                      28.0
# ...         ...             ...                       ...
# 2352        NaN             NaN                       NaN
# 2353        NaN             NaN                       NaN
# 2354        NaN             NaN                       NaN
# 2355        NaN             NaN                       NaN
# 2356        NaN             NaN                       NaN
#
#       std_n_changes_changed  ...  \
# 0               1308.633809  ...
# 1                367.074297  ...
# 2               4414.001519  ...
# 3                788.754934  ...
# 4               2815.523983  ...
# ...                     ...  ...
# 2352                    NaN  ...
# 2353                    NaN  ...
# 2354                    NaN  ...
# 2355                    NaN  ...
# 2356                    NaN  ...
#
#                                      which_interactions  breadth_interactions  \
# 0     commit_created, pull_request_created, pull_req...                     3
# 1     commit_created, pull_request_created, pull_req...                     3
# 2     commit_created, pull_request_created, pull_req...                     5
# 3     commit_created, pull_request_closed, issue_clo...                     5
# 4     commit_created, pull_request_created, pull_req...                     3
# ...                                                 ...                   ...
# 2352                pull_request_closed, assigned_issue                     2
# 2353  pull_request_closed, issue_closed, assigned_issue                     3
# 2354  pull_request_closed, issue_closed, assigned_issue                     3
# 2355                pull_request_closed, assigned_issue                     2
# 2356                       issue_closed, assigned_issue                     2
#
#       pc_pull_request_created  pc_pull_request_closed  pc_commit_created  \
# 0                   57.142857               95.238095          29.553265
# 1                   44.334975               25.654450           2.149254
# 2                    2.463054                9.424084          14.626866
# 3                    0.000000                4.470588          23.095526
# 4                   90.000000               12.235294          40.386941
# ...                       ...                     ...                ...
# 2352                 0.000000               13.636364           0.000000
# 2353                 0.000000               36.363636           0.000000
# 2354                 0.000000               41.414141           0.000000
# 2355                 0.000000               92.307692           0.000000
# 2356                 0.000000                0.000000           0.000000
#
#       pc_issue_created  pc_issue_closed  pc_sum_n_interactions  \
# 0             0.000000         0.000000              32.176656
# 1             0.000000         0.000000               7.802051
# 2             0.000000         2.380952              12.037450
# 3            27.160494        59.615385              14.490358
# 4             0.000000         0.000000              42.589532
# ...                ...              ...                    ...
# 2352          0.000000         0.000000               3.947368
# 2353          0.000000         7.692308              11.842105
# 2354          0.000000        22.000000              12.211221
# 2355          0.000000         0.000000              33.333333
# 2356          0.000000        25.000000               0.091912
#
#       pc_interaction_days      pc_DC
# 0               25.384615  17.339224
# 1               13.333333   9.296846
# 2               13.170732   6.089296
# 3               17.153996  37.974281
# 4               33.918129  26.077388
# ...                   ...        ...
# 2352             5.172414   4.000000
# 2353            13.793103   4.205128
# 2354            11.830357  16.164706
# 2355            16.666667  13.333333
# 2356             0.280899   6.666667
#
# [2357 rows x 86 columns]

# %%
sklearn_hcwdata = analysis_dataset

# %% [markdown]
# ### how does pc_DC vary between clusters?

# %%
sklearn_hcwdata.pc_DC.describe()
# Out:
# count    2357.000000
# mean       18.878235
# std         9.966164
# min         0.174672
# 25%        10.793001
# 50%        16.846403
# 75%        25.090371
# max        59.371728
# Name: pc_DC, dtype: float64

# %%
sns.boxplot(data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_DC",
    hue="cluster_labels", palette=label_color_dict)
print("pc_DC across each cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_DC"]].mean()
# Out:
# pc_DC across each cluster
#                     pc_DC
# cluster_labels
# 0               14.853312
# 1               31.323354

# %%
sklearn_hcwdata.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    y="pc_DC",
    hue="cluster_labels", 
    palette = label_color_dict)
print("pc_DC across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["pc_DC"]].mean()
# Out:
# pc_DC across breadth_interactions by Cluster
#                                          pc_DC
# breadth_interactions cluster_labels
# 1                    0               12.846896
# 2                    0               11.363762
#                      1               23.034151
# 3                    0               12.941896
#                      1               23.643640
# 4                    0               13.228257
#                      1               24.180820
# 5                    0               14.517888
#                      1               28.453566
# 6                    0               16.413041
#                      1               33.849773

# %%
# pc_DC (percentage DEPTH of contribution across all of users' interactions)

g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_DC",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict 
)
g.tick_params(axis='x', which='both', rotation=70)
print("mean pc_DC across each clusters")

sklearn_hcwdata.groupby("cluster_labels")[["pc_DC"]].mean()
# Out:
# mean pc_DC across each clusters
#                     pc_DC
# cluster_labels
# 0               14.853312
# 1               31.323354

# %%
sns.boxplot(data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_commit_created",
    hue="cluster_labels", palette=label_color_dict)
print("pc_DC across each cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_DC"]].mean()
# Out:
# pc_DC across each cluster
#                     pc_DC
# cluster_labels
# 0               14.853312
# 1               31.323354

# %%
# # cluster 1 has highest pc of repo's commits values, 0 is minimal. 
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_commit_created",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's commits")
sklearn_hcwdata.groupby("cluster_labels")[["pc_commit_created"]].mean()
# Out:
# cluster x % of repo's commits
#                 pc_commit_created
# cluster_labels
# 0                       10.702327
# 1                       30.133001

# %% [markdown]
# #### pc_commit_created: \~59% more of repos' commits by cluster 1 (\~62%) vs Cluster 0 (~3%)

# %%
# # cluster 1 has highest pc of repo's issue ticket creation  values, 0 is minimal
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_issue_created",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's issues created")
sklearn_hcwdata.groupby("cluster_labels")[["pc_issue_created"]].mean()
# Out:
# cluster x % of repo's issues created
#                 pc_issue_created
# cluster_labels
# 0                      12.346918
# 1                      22.470116

# %%
# # cluster 1 has highest pc of repo's issue ticket creation  values, 0 is minimal
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_issue_closed",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict, 
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's issues closed")
sklearn_hcwdata.groupby("cluster_labels")[["pc_issue_closed"]].mean()
# Out:
# cluster x % of repo's issues closed
#                 pc_issue_closed
# cluster_labels
# 0                     12.957912
# 1                     43.621331

# %%
# assignment pcs
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_issues_assigned_of_assigned",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's issues assigned to user")
sklearn_hcwdata.groupby("cluster_labels")[["pc_issues_assigned_of_assigned"]].mean()
# Out:
# cluster x % of repo's issues assigned to user
#                 pc_issues_assigned_of_assigned
# cluster_labels
# 0                                    22.713408
# 1                                    34.829075

# %%
# assignment pcs
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_pull_request_created",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's pull requests created by user")
sklearn_hcwdata.groupby("cluster_labels")[["pc_pull_request_created"]].mean()
# Out:
# cluster x % of repo's pull requests created by user
#                 pc_pull_request_created
# cluster_labels
# 0                             15.545993
# 1                             25.563248

# %%
# assignment pcs
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_pull_request_closed",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's pull requests closed by user")
sklearn_hcwdata.groupby("cluster_labels")[["pc_pull_request_closed"]].mean()
# Out:
# cluster x % of repo's pull requests closed by user
#                 pc_pull_request_closed
# cluster_labels
# 0                            16.111822
# 1                            44.809848

# %% [markdown]
# #### Number of repo committers: `n_of_commit_creators`

# %%
sklearn_hcwdata.groupby("cluster_labels")['repo_name'].nunique() # how many repos fall into each category?
# Out:
# cluster_labels
# 0    910
# 1    476
# Name: repo_name, dtype: int64

# %%
# THIS IS A REALLY HACKY WAY OF PLOTTING THE ACTUAL MEAN APPX REPO SIZES. 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} 
approx_repo_sizes = pd.DataFrame({
    "cluster_labels": [0, 1, 2], 
    "mean_n_of_commit_creators": [sklearn_hcwdata.query("cluster_labels == 0").groupby("repo_name")[["n_of_commit_creators"]].mean().mean().item() , sklearn_hcwdata.query("cluster_labels == 1").groupby("repo_name")[["n_of_commit_creators"]].mean().mean().item(), sklearn_hcwdata.query("cluster_labels == 2").groupby("repo_name")[["n_of_commit_creators"]].mean().mean().item() ]
})

#sklearn_hcwdata.query("cluster_labels == 1").groupby("repo_name")[["n_of_commit_creators"]].mean().mean()
  # double .mean() gets first the mean of all n_of_commit_creators per repo_name 
    # (which is legit, since it's the same for each dev inside it) 
  # THEN it gets the mean of THOSE MEANS (ie for the cluster group)
  # THEN .item gets the value afterwards 

g = sns.catplot(
    data=approx_repo_sizes, 
    x="cluster_labels", 
    y="mean_n_of_commit_creators",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster labels x mean number of repo commit creators")
print(approx_repo_sizes)
# Out:
# cluster labels x mean number of repo commit creators
#    cluster_labels  mean_n_of_commit_creators
# 0               0                  27.468300
# 1               1                  29.350267
# 2               2                        NaN

# %%
# users from different sizes of n_of_commit_creators counts, shown with cluster labels  
ax = sns.histplot(
    data=sklearn_hcwdata, 
    x="n_of_commit_creators", 
    #y="cluster_labels",
    hue="cluster_labels", 
    binwidth=5,
    #alpha=1, 
    multiple="stack", 
    palette=label_color_dict,
)
#ax.tick_params(axis='x', which='both', rotation=90)
print("Users from different sizes of n_of_commit_creators counts, shown with cluster labels  ")
# spread of cluster 1 repo 'appx sizes' is much lower, but sample is TINY comparatively
# Out:
# Users from different sizes of n_of_commit_creators counts, shown with cluster labels

# %%
# Counts of users in repos of varying sizes + cluster label distributions
ax = sns.displot(
    data=sklearn_hcwdata, 
    #x="repo_name", 
    x="n_of_commit_creators",
    col="cluster_labels",
    hue="cluster_labels", 
    binwidth=5,
    alpha=1, 
    palette=label_color_dict,
    #multiple="stack", 
    #kde="true"
)
ax.tick_params(axis='x', which='both', rotation=90)
print("Counts of users in repos of varying sizes + cluster label distributions")
# Out:
# Counts of users in repos of varying sizes + cluster label distributions

# %% [markdown]
# ### CBRIs across clusters
#
# How are project-individuals with different CBRI values spread across the clusters?

# %%
g = sns.countplot(
    data=sklearn_hcwdata, 
    x="breadth_interactions", 
    hue="cluster_labels", 
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("count of breadth_interactions across 'clusters'")

sklearn_hcwdata.groupby(["cluster_labels", "breadth_interactions"])[["breadth_interactions"]].count()
# Out:
# count of breadth_interactions across 'clusters'
#                                      breadth_interactions
# cluster_labels breadth_interactions
# 0              1                                       34
#                2                                      111
#                3                                      171
#                4                                      207
#                5                                      445
#                6                                      813
# 1              2                                        6
#                3                                       24
#                4                                       42
#                5                                      137
#                6                                      367

# %%
sklearn_hcwdata.cluster_labels.value_counts()
# Out:
# cluster_labels
# 0    1781
# 1     576
# Name: count, dtype: int64

# %% [markdown]
# ### Contribution-Type-Combos (contributions_by_user)

# %% [markdown]
# ### Commit Classification Variations (HL- and V-)

# %% [markdown]
# #### HL-MANAGEMENT

# %%
# Percentage of user's commits which categorised as HL commit content category MANAGEMENT
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-mgmt",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL commit content category MANAGEMENT by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-mgmt"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL commit content category MANAGEMENT by cluster
#                 pc_HL-mgmt
# cluster_labels
# 0                29.384478
# 1                27.593307

# %% [markdown]
# #### V-DOCS

# %%
# Percentage of user's commits which categorised as V commit filetype category DOCS
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_V-doc",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as V-cat Docs by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_V-doc"]].mean()
# Out:
# # Percentage of user's commits which categorised as V-cat Docs by cluster
#                  pc_V-doc
# cluster_labels
# 0               25.837742
# 1               25.452138

# %% [markdown]
# #### HL-FORWARD-ENGINEERING

# %%
# Percentage of user's commits which categorised as HL commit content category FORWARD ENGINEERING
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-fweng",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL-FWENG (Forward Engineering) by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-fweng"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL-FWENG (Forward Engineering) by cluster
#                 pc_HL-fweng
# cluster_labels
# 0                 13.713854
# 1                 13.435066

# %% [markdown]
# #### V-CODE

# %%
# Percentage of user's commits which categorised as V commit filetype category CODE
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_V-code",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as V-cat CODE by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_V-code"]].mean()
# Out:
# # Percentage of user's commits which categorised as V-cat CODE by cluster
#                 pc_V-code
# cluster_labels
# 0               65.644270
# 1               66.671172

# %% [markdown]
# #### HL-RE-ENGINEERING

# %%
# Percentage of user's commits which categorised as HL commit content category RE-ENGINEERING
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-reeng",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL-RE-ENG (Re-Engineering) by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-reeng"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL-RE-ENG (Re-Engineering) by cluster
#                 pc_HL-reeng
# cluster_labels
# 0                 25.720144
# 1                 25.888049

# %% [markdown]
# #### HL-CORRECTIVE-ENGINEERING

# %%
# Percentage of user's commits which categorised as HL commit content category CORRECTIVE-ENGINEERING
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-corr",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL-CORR (Corrective-Engineering) by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-corr"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL-CORR (Corrective-Engineering) by cluster
#                 pc_HL-corr
# cluster_labels
# 0                11.849749
# 1                12.629792

# %% [markdown]
# ### HLs-cats

# %% [markdown]
# ### HL-Cats

# %%
sklearn_hcwdata.groupby("cluster_labels")[['pc_HL-fweng', 'pc_HL-reeng', 'pc_HL-corr','pc_HL-mgmt']].mean()
# Out:
#                 pc_HL-fweng  pc_HL-reeng  pc_HL-corr  pc_HL-mgmt
# cluster_labels
# 0                 13.713854    25.720144   11.849749   29.384478
# 1                 13.435066    25.888049   12.629792   27.593307

# %% [markdown]
# ### V-Cats

# %%
sklearn_hcwdata.groupby("cluster_labels")[['pc_V-code','pc_V-doc', 'pc_V-dvdoc', 'pc_V-confg', 'pc_V-build','pc_V-test']].mean()
# Out:
#                 pc_V-code   pc_V-doc  pc_V-dvdoc  pc_V-confg  pc_V-build  \
# cluster_labels
# 0               65.644270  25.837742    0.585691    1.027489    0.954848
# 1               66.671172  25.452138    0.649511    0.408745    0.588974
#
#                 pc_V-test
# cluster_labels
# 0                0.453568
# 1                0.322639

# %% [markdown]
# ### Commit Size (more about depth)

# %% [markdown]
# #### Raw n_commits:

# %%
sklearn_hcwdata.groupby("cluster_labels")[["pc_n_commits"]].mean()
# Out:
#                 pc_n_commits
# cluster_labels
# 0                   0.029494
# 1                   0.082416

# %%
sklearn_hcwdata.groupby("cluster_labels")[["pc_n_commits"]].describe() 
# pc_n_commits didn't need to be scaled for this clustering, and represents the average of users' contributions the repo, so this seems more likely to be legit?
# Out:
#                pc_n_commits                                               \
#                       count      mean       std  min       25%       50%
# cluster_labels
# 0                    1781.0  0.029494  0.066492  0.0  0.000000  0.007321
# 1                     576.0  0.082416  0.158458  0.0  0.004007  0.030103
#
#
#                      75%       max
# cluster_labels
# 0               0.028904  0.737357
# 1               0.089740  1.435966

# %% [markdown]
# #### Commit Size: HLs-

# %%
sklearn_hcwdata.groupby("cluster_labels")[['pc_HLs-tiny', 'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg']].mean()
# Out:
#                 pc_HLs-tiny  pc_HLs-sml  pc_HLs-med  pc_HLs-lrg
# cluster_labels
# 0                 83.291594   12.863027    3.063532    0.781847
# 1                 82.243789   13.383879    3.492848    0.879483

# %%
# Percentage of user's commits which categorised as HL commit size category TINY
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-tiny",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-TINY commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-tiny"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-TINY commit size by cluster
#                 pc_HLs-tiny
# cluster_labels
# 0                 83.291594
# 1                 82.243789

# %%
# Percentage of user's commits which categorised as HL commit size category SMALL
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-sml",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-SMALL commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-sml"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-SMALL commit size by cluster
#                 pc_HLs-sml
# cluster_labels
# 0                12.863027
# 1                13.383879

# %%
# Percentage of user's commits which categorised as HL commit size category MEDIUM
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-med",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-MEDIUM commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-med"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-MEDIUM commit size by cluster
#                 pc_HLs-med
# cluster_labels
# 0                 3.063532
# 1                 3.492848

# %%
# Percentage of user's commits which categorised as HL commit size category LARGE
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-lrg",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-LARGE commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-lrg"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-LARGE commit size by cluster
#                 pc_HLs-lrg
# cluster_labels
# 0                 0.781847
# 1                 0.879483

# %% [markdown]
# ### (Raw) Number of Commits: `n_commits`: depth (commits)

# %% [markdown]
# #### Number of Commits: n_commits

# %% [markdown]
# ### DEPTH

# %%
sklearn_hcwdata.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="mean_n_interactions_per_interaction_day",
    hue="cluster_labels", 
    palette = label_color_dict)
print("mean_n_interactions_per_interaction_day across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean()
# Out:
# mean_n_interactions_per_interaction_day across breadth_interactions by Cluster
#                                      mean_n_interactions_per_interaction_day
# breadth_interactions cluster_labels
# 1                    0                                              1.225271
# 2                    0                                             10.506050
#                      1                                              2.592051
# 3                    0                                              9.033758
#                      1                                              3.159063
# 4                    0                                              2.782275
#                      1                                              2.806900
# 5                    0                                              2.740559
#                      1                                              2.859166
# 6                    0                                              3.682287
#                      1                                              4.081488
#                 mean_n_interactions_per_interaction_day
# cluster_labels
# 0                                              4.234577
# 1                                              3.643874

# %% [markdown]
# ## TIME

# %%
# interaction_days

# %% [markdown]
# #### mean_n_interactions_per_interaction_day: significantly different by breadth, cluster

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="mean_n_interactions_per_interaction_day",
    hue="cluster_labels", 
    palette = label_color_dict)
print("mean_n_interactions_per_interaction_day across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean()
# Out:
# mean_n_interactions_per_interaction_day across breadth_interactions by Cluster
#                                      mean_n_interactions_per_interaction_day
# breadth_interactions cluster_labels
# 1                    0                                              1.225271
# 2                    0                                             10.506050
#                      1                                              2.592051
# 3                    0                                              9.033758
#                      1                                              3.159063
# 4                    0                                              2.782275
#                      1                                              2.806900
# 5                    0                                              2.740559
#                      1                                              2.859166
# 6                    0                                              3.682287
#                      1                                              4.081488
#                 mean_n_interactions_per_interaction_day
# cluster_labels
# 0                                              4.234577
# 1                                              3.643874

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    #x="breadth_interactions", 
    x="cluster_labels",
    y="mean_n_interactions_per_interaction_day",
    hue="cluster_labels", 
    palette = label_color_dict)
print("mean_n_interactions_per_interaction_day by Cluster")
#print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean()
# Out:
# mean_n_interactions_per_interaction_day by Cluster
#                 mean_n_interactions_per_interaction_day
# cluster_labels
# 0                                              4.234577
# 1                                              3.643874

# %% [markdown]
# #### interaction_days:

# %%
# interaction days
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("interaction_days across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["interaction_days"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_days"]].mean()
# Out:
# interaction_days across breadth_interactions by Cluster
#                                      interaction_days
# breadth_interactions cluster_labels
# 1                    0                      12.382353
# 2                    0                      31.297297
#                      1                      28.333333
# 3                    0                      73.438596
#                      1                     211.375000
# 4                    0                      52.338164
#                      1                     146.404762
# 5                    0                      90.294382
#                      1                     209.014599
# 6                    0                     179.838868
#                      1                     326.828338
#                 interaction_days
# cluster_labels
# 0                     119.975856
# 1                     277.730903

# %%
# interaction days
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("N interaction_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_days"]].mean()
# Out:
# N interaction_days across breadth_interactions by Cluster
#                 interaction_days
# cluster_labels
# 0                     119.975856
# 1                     277.730903

# %% [markdown]
# #### interaction_period_days:

# %%
# interaction period
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="interaction_period_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("N interaction_period_days across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["interaction_period_days"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_period_days"]].mean()
# Out:
# N interaction_period_days across breadth_interactions by Cluster
#                                      interaction_period_days
# breadth_interactions cluster_labels
# 1                    0                            196.058824
# 2                    0                            495.972973
#                      1                           1911.000000
# 3                    0                            889.549708
#                      1                           2101.666667
# 4                    0                           1170.111111
#                      1                           2037.000000
# 5                    0                           1438.087640
#                      1                           1878.284672
# 6                    0                           1733.841328
#                      1                           2256.408719
#                 interaction_period_days
# cluster_labels
# 0                           1406.854015
# 1                           2140.428819

# %%
# interaction_period 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata, # SHOWS MEDIAN (and upper/lower quartile, and 1.5 Inter-quartile range)
    #x="breadth_interactions", 
    x="cluster_labels",
    y="interaction_period_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("N interaction_period_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_period_days"]].mean() # MEAN AVERAGE
# Out:
# N interaction_period_days across breadth_interactions by Cluster
#                 interaction_period_days
# cluster_labels
# 0                           1406.854015
# 1                           2140.428819

# %% [markdown]
# #### pc_interaction_days:

# %%
# pc_interaction_days
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata, # SHOWS MEDIAN (and upper/lower quartile, and 1.5 Inter-quartile range)
    #x="breadth_interactions", 
    x="cluster_labels",
    y="pc_interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("pc_interaction_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["pc_interaction_days"]].mean() # MEAN AVERAGE
# Out:
# pc_interaction_days across breadth_interactions by Cluster
#                 pc_interaction_days
# cluster_labels
# 0                         13.196110
# 1                         29.532036

# %%
# pc_interaction_days BARPLOT
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata, # SHOWS MEDIAN (and upper/lower quartile, and 1.5 Inter-quartile range)
    #x="breadth_interactions", 
    x="cluster_labels",
    y="pc_interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("pc_interaction_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["pc_interaction_days"]].mean() # MEAN
# Out:
# pc_interaction_days across breadth_interactions by Cluster
#                 pc_interaction_days
# cluster_labels
# 0                         13.196110
# 1                         29.532036

# %%
from githubanalysis.visualization.plot_repoindividual_upset_plot import UpsetPlotter

upsetplotter = UpsetPlotter(
    dataset_name="sample_45pc_cluster0",
    image_write_location = dataanalyser.image_write_location,
    #image_write_location="../../data/analysis_run_sample_45pc_2025-05-12/",
    in_notebook=True,
    logger=None,
)

def upset_plot(
    cluster: int | None,
    data: pd.DataFrame,
    show_min: float = 0.005,
    show_counts: bool = False,
    sort_combos_by: str = "cardinality",
    data_set_name: str = "dataset",  # manual naming, goes into title of plots
    file_name: str = "upset_plot_",
    save_type: str = "pdf",  # one of: ['png', 'pdf', 'svg']
):
    assert (
        isinstance(cluster, int) or cluster is None
    ), f"give valid input for 'cluster': should be a number or None. You supplied {cluster}."
    assert save_type in [
        "svg",
        "pdf",
        "png",
    ], "save_type is not valid; check you have entered one of: 'svg', 'pdf', 'png'."
    assert (
        sort_combos_by
        in ["cardinality", "-cardinality", "degree", "-degree", "input", "-input"]
    ), "sort_combos_by is not valid, check you've entered one of: 'cardinality', 'degree', 'input' or '-cardinality', '-degree', '-input'."

    # what type is data?
    if isinstance(data, pd.DataFrame):
        assert data.empty is False, "Dataframe data is empty; check inputs."
        print(f"data is df, with shape: {data.shape}.")

    # colours = list(sns.color_palette("colorblind").as_hex())

    data_by_interaction = from_memberships(  # format data to upsetplot requirements
        data.which_interactions.apply(lambda x: [x.strip() for x in x.split(",")]),
        data=data,
    )
    assert isinstance(
        data_by_interaction, pd.DataFrame
    ), "data_by_interaction needs to be a dataframe, check this was generated correctly."

    if cluster is not None:
        cluster_query = f"cluster_labels == {cluster}"
        data = data_by_interaction.query("@cluster_query", engine="python")
        # plot_colour = colours[cluster]
        cluster_name = f"cluster{cluster}"
    else:  # if no clusters supplied:
        data = data_by_interaction
        # plot_colour = "auto"
        cluster_name = data_set_name


    smallest_n_to_show = round(len(data) * show_min)

    print(
        f"Attempting to plot cluster {cluster_name} and showing as far as {show_min}%, which is {smallest_n_to_show} repo-individuals from the data"  # {plot_colour}."
    )

    if show_counts:
        format = "{:,}"
    else:
        format = ""
        
    upset = UpSet(
        data=data,
        how_counts=format,
        sort_by=sort_combos_by,
        # facecolor=plot_colour,
        orientation="horizontal",
        min_subset_size=smallest_n_to_show,
    )
    upset.plot()
    plt.suptitle(
        f"{data_set_name} Interaction-Combinations (showing >{smallest_n_to_show} ({show_min}%) Repo-Individuals),  N={len(data)}"
    )
    plot_file = Path(
        image_write_location,
        f"{file_name}_{cluster_name}_{current_date_info}.{save_type}",
    )
    plt.savefig(fname=plot_file, format=save_type, bbox_inches="tight")
    plt.close()
    print(f"Plot saved out to file {plot_file}.")
    
    
    
def plot_upset_plot_interaction_combinations(
    
    data: pd.DataFrame,
    # colours: list | dict = sns.color_palette("colorblind"),
    separate_by_clusters: bool = False,
    show_min: float = 0.005,
    show_counts: bool = False,
    sort_combos_by: str = "cardinality",
    data_set_name: str = "dataset",
    file_name: str = "upset_plot_",
    save_type: str = "pdf",  # one of: ['png', 'pdf', 'svg']
    # min_repo_individs_per_combo: int = 2,
    # show_counts_per_combo: boolean = True,
    # show_pc: boolean = False,
):
    """
    This generates UpSet plots from GH interaction data from a dataframe or csv file.
    Data must be in a per-repo-individual format, and cluster labels must be in column titled "cluster_labels".

    """
    assert isinstance(
        data, (pd.DataFrame, Path)
    ), "Data is not of type pandas dataframe or Path; check your inputs."
    if isinstance(data, Path):
        print(f"data is a path: {data}")
        data = pd.read_csv(filepath_or_buffer=data, header=0)
        assert isinstance(data, pd.DataFrame), "data could not be read in properly."
        print(f"data is df, with shape: {data.shape}.")
    # if colours is a list and separate_by_clusters is true, does len(colours) match nunique('cluster_labels')?

    assert isinstance(
        data, pd.DataFrame
    ), "data should be dataframe format by now, check why this isn't correct"

    if separate_by_clusters:
        assert (
            "cluster_labels" in data.columns
        ), "df has no column 'cluster_labels - please check this is present in the data."
        n_clusters = data.cluster_labels.nunique()
        print(
                f"Plotting upset plot for {data_set_name}, separating by {n_clusters} clusters from data labels."
        )

        for cluster in range(0, n_clusters - 1, 1):
            # range: start at 0 because this is how they're named by clustering
            # end on n_clusters - 1 because we're starting at 0 and off-by-one; increases by 1
            upset_plot(
                    cluster=cluster,
                    data=data,
                    show_min=show_min,
                    data_set_name=data_set_name,
                    show_counts=show_counts,
                    file_name=f"{file_name}_cluster-{cluster}_",
                )
        print(
            f"Completed UpSet plotting for {n_clusters} clusters from data labels."
        )
    else:
        print("Plotting upset plot without separating by clusters")
        upset_plot(
                cluster=None,
                data=data,
                show_min=show_min,
                show_counts=show_counts,
                sort_combos_by="cardinality",
                data_set_name=data_set_name,
                file_name=file_name,
                save_type="pdf",  # one of: ['png', 'pdf', 'svg']
        )
        print("Completed UpSet plotting.")


print("{Plotting single combined sample UpSet Plot")
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=analysis_dataset,
    show_min = 0.005,
    show_counts=True,  ##### SHOW COUNTS VERSION 
    sort_combos_by="cardinality",
    data_set_name="Sample",
    file_name="sample_upset_plot_45pc_counts_cluster0",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
plt.show()

print("{Plotting single combined sample UpSet Plot")
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=analysis_dataset,
    show_min = 0.005,
    sort_combos_by="cardinality",  ### NO COUNTS
    data_set_name="Sample",
    file_name="sample_upset_plot_45pc_cluster0",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
plt.show()



tmp0 = analysis_dataset.query("cluster_labels == 0")
tmp1 = analysis_dataset.query("cluster_labels == 1")


# plot cluster 0
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp0,
    show_min = 0.01,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 0:0",
    file_name="sample_upset_plot_45pc_subcluster0_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)

# plot cluster 0 WITH COUNTS
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp0,
    show_min = 0.01,
    show_counts=True,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 0:0",
    file_name="sample_upset_plot_45pc_subcluster0_counts",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)



# plot cluster 1
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    show_min = 0.01,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 0:1",
    file_name="sample_upset_plot_45pc_subcluster1_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)

# plot cluster 1 WITH COUNTS
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    show_min = 0.01,
    show_counts=True,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 0:1",
    file_name="sample_upset_plot_45pc_subcluster1_counts",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot for Sample without separating by clusters
# INFO:data is df, with shape: (2357, 86).
# INFO:Attempting to plot cluster Sample and showing as far as 0.005%, which is 12 repo-individuals from the data
# {Plotting single combined sample UpSet Plot
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster0_2025-05-18/sample_upset_plot_45pc_counts_cluster0_Sample_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sample without separating by clusters
# INFO:data is df, with shape: (2357, 86).
# INFO:Attempting to plot cluster Sample and showing as far as 0.005%, which is 12 repo-individuals from the data
# {Plotting single combined sample UpSet Plot
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster0_2025-05-18/sample_upset_plot_45pc_cluster0_Sample_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 0:0 without separating by clusters
# INFO:data is df, with shape: (1781, 86).
# INFO:Attempting to plot cluster Sub-Cluster 0:0 and showing as far as 0.01%, which is 18 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster0_2025-05-18/sample_upset_plot_45pc_subcluster0__Sub-Cluster 0:0_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 0:0 without separating by clusters
# INFO:data is df, with shape: (1781, 86).
# INFO:Attempting to plot cluster Sub-Cluster 0:0 and showing as far as 0.01%, which is 18 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster0_2025-05-18/sample_upset_plot_45pc_subcluster0_counts_Sub-Cluster 0:0_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 0:1 without separating by clusters
# INFO:data is df, with shape: (576, 86).
# INFO:Attempting to plot cluster Sub-Cluster 0:1 and showing as far as 0.01%, which is 6 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster0_2025-05-18/sample_upset_plot_45pc_subcluster1__Sub-Cluster 0:1_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 0:1 without separating by clusters
# INFO:data is df, with shape: (576, 86).
# INFO:Attempting to plot cluster Sub-Cluster 0:1 and showing as far as 0.01%, which is 6 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster0_2025-05-18/sample_upset_plot_45pc_subcluster1_counts_Sub-Cluster 0:1_2025-05-18.pdf.
# INFO:Completed UpSet plotting.

# %%
(analysis_dataset.cluster_labels.value_counts()/115174)*100
# Out:
# cluster_labels
# 0    1.546356
# 1    0.500113
# Name: count, dtype: float64

# %%
label_color_dict
# Out:
# {0: '#D50032', 1: '#1D2A3D', 2: '#FDBC42'}

# %%
#pc_interaction_days

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_pull_request_closed", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)
hatches = ["//", "..", ]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#000000")
    patch.set_facecolor('#D50032')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#000000")
    lp.set_facecolor('#D50032')

ax.set_title("Cluster 0: RC Pull Requests Closed by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% RC Pull Requests Closed")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_boxplot_PRs_closed_{current_date_info}.pdf")

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_closed"].mean()
# Out:
# cluster_labels
# 0    16.111822
# 1    44.809848
# Name: pc_pull_request_closed, dtype: float64

# %%
#pc_interaction_days

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_created-closed_issues", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)
hatches = ["//", "..", ]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#000000")
    patch.set_facecolor('#D50032')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#000000")
    lp.set_facecolor('#D50032')

ax.set_title("Cluster 0: RC Created-Closed Issues by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% RC Created-Closed Issues")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_boxplot_created-closed_issues_{current_date_info}.pdf")

# %%
analysis_dataset.groupby("cluster_labels")["pc_issues_assigned_of_assigned"].mean()
# Out:
# cluster_labels
# 0    22.713408
# 1    34.829075
# Name: pc_issues_assigned_of_assigned, dtype: float64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_issues_assigned_of_assigned", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)
hatches = ["//", "..", ]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#000000")
    patch.set_facecolor('#D50032')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#000000")
    lp.set_facecolor('#D50032')

ax.set_title("Cluster 0: RC Issue Assignment by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% RC Assigned Issues")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_boxplot_assignment_issues_{current_date_info}.pdf")

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_DC", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)
hatches = ["//", "..", ]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#000000")
    patch.set_facecolor('#D50032')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#000000")
    lp.set_facecolor('#D50032')

ax.set_title("Cluster 0: MRC by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% MRC")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_boxplot_MRC_{current_date_info}.pdf")

# %%
analysis_dataset.groupby("cluster_labels")["pc_created-closed_issues"].mean()
# Out:
# cluster_labels
# 0   -12.838373
# 1   -43.396630
# Name: pc_created-closed_issues, dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_created"].mean() - analysis_dataset.groupby("cluster_labels")["pc_pull_request_closed"].mean()
# Out:
# cluster_labels
# 0    -0.565829
# 1   -19.246600
# dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["pc_DC"].mean()
# Out:
# cluster_labels
# 0    14.853312
# 1    31.323354
# Name: pc_DC, dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["breadth_interactions"].mean()
# Out:
# cluster_labels
# 0    4.884896
# 1    5.449653
# Name: breadth_interactions, dtype: float64

# %%
#pc_interaction_days

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="breadth_interactions", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)
hatches = ["//", "..", ]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#000000")
    patch.set_facecolor('#D50032')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#000000")
    lp.set_facecolor('#D50032')

ax.set_title("Cluster 0: UIT by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("Mean UIT")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_boxplot_UIT_{current_date_info}.pdf")

# %%
#pc_interaction_days

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_issues_assigned_of_assigned", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)
hatches = ["//", "..", ]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#000000")
    patch.set_facecolor('#D50032')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#000000")
    lp.set_facecolor('#D50032')

ax.set_title("Cluster 0: RC Issue Assignment by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% RC Assigned Issues")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_boxplot_assignment_{current_date_info}.pdf")

# %%
analysis_dataset.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
#pc_interaction_days

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_interaction_days", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)
hatches = ["//", "..", ]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#000000")
    patch.set_facecolor('#D50032')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#000000")
    lp.set_facecolor('#D50032')

ax.set_title("Cluster 0: RC Interaction Days by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% RC Interaction Days")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster0_2025-05-13/45pc_cluster0_pc_interaction_days_{current_date_info}.pdf")

# %%
import numpy as np
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd

def run_anova(variable, data):
        variable = variable
        df = analysis_dataset

        # One-Way ANOVA: 
        anova = f_oneway(
            df.groupby("cluster_labels")[variable].get_group(0),
            df.groupby("cluster_labels")[variable].get_group(1),
        )

        print("\n")
        print(f"{anova}")


        # perform Tukey's test
        tukey = pairwise_tukeyhsd(endog=df[variable],
                                  groups=df['cluster_labels'],
                                  alpha=0.05)

        #display results
        print(tukey.summary())

        print(f"For {variable}, anova result p-value is {anova.pvalue}; groups are significantly different = {anova.pvalue < 0.05}")
        print(f"For {variable}, Tukey HSD test result p-value is {tukey.pvalues}; groups are significantly different = {tukey.reject == True}")
        
        if anova.pvalue < 0.05:
            print(f">>>>>> {variable} ^^^ is significant <<<<<< \n ")

        return df.groupby("cluster_labels")[variable].mean()

# %%
for var in ['n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
       'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
       'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
       'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
       'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
       'hattori_lanza_content_cat_forward_engineering',
       'hattori_lanza_content_cat_reengineering',
       'hattori_lanza_content_cat_corrective_engineering',
       'hattori_lanza_content_cat_management',
       'hattori_lanza_content_cat_empty_message',
       'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
       'vasilescu_category_img', 'vasilescu_category_l10n',
       'vasilescu_category_ui', 'vasilescu_category_media',
       'vasilescu_category_code', 'vasilescu_category_meta',
       'vasilescu_category_config', 'vasilescu_category_build',
       'vasilescu_category_devdoc', 'vasilescu_category_db',
       'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
       'n_of_issues_creators', 'n_issues_assigned',
       'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
       'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
       'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
       'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
       'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
       'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
       'pull_request_closed', 'pull_request_created', 'interaction_days',
       'interaction_period_days', 'created-closed_issues',
       'pc_created-closed_issues', 'sum_n_interactions',
       'mean_n_interactions_per_interaction_day', 
       'breadth_interactions', 'pc_pull_request_created',
       'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
       'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
       'pc_DC']:
    print(run_anova(variable=var, data=analysis_dataset))
# Out:
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For n_of_commit_creators, anova result p-value is nan; groups are significantly different = False
# For n_of_commit_creators, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    28.176115
# 1    27.592593
# Name: n_of_commit_creators, dtype: float64
#
#
# F_onewayResult(statistic=128.68828421625952, pvalue=4.4447253725998566e-29)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1 419.2939   0.0 346.8135 491.7743   True
# -----------------------------------------------------
# For n_commits, anova result p-value is 4.4447253725998566e-29; groups are significantly different = True
# For n_commits, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> n_commits ^^^ is significant <<<<<<
#
# cluster_labels
# 0    233.676586
# 1    652.970486
# Name: n_commits, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For n_changes, anova result p-value is nan; groups are significantly different = False
# For n_changes, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    5.838440e+05
# 1    2.060246e+06
# Name: n_changes, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For mean_n_changes, anova result p-value is nan; groups are significantly different = False
# For mean_n_changes, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    3189.812727
# 1    3066.936949
# Name: mean_n_changes, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For median_n_changes_changed, anova result p-value is nan; groups are significantly different = False
# For median_n_changes_changed, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    1008.779667
# 1      49.932462
# Name: median_n_changes_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For std_n_changes_changed, anova result p-value is nan; groups are significantly different = False
# For std_n_changes_changed, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    15108.188954
# 1    19567.425748
# Name: std_n_changes_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For n_files_changed, anova result p-value is nan; groups are significantly different = False
# For n_files_changed, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    2039.600151
# 1    5875.056645
# Name: n_files_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For mean_n_files, anova result p-value is nan; groups are significantly different = False
# For mean_n_files, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    6.199656
# 1    6.733457
# Name: mean_n_files, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For median_n_files_changed, anova result p-value is nan; groups are significantly different = False
# For median_n_files_changed, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    2.098639
# 1    2.025054
# Name: median_n_files_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For std_n_files_changed, anova result p-value is nan; groups are significantly different = False
# For std_n_files_changed, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    14.094340
# 1    16.267261
# Name: std_n_files_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_tiny, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_tiny, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    263.594860
# 1    671.272331
# Name: hattori_lanza_size_cat_tiny, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_small, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_small, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     38.258503
# 1    111.688453
# Name: hattori_lanza_size_cat_small, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_medium, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_medium, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     9.894936
# 1    27.795207
# Name: hattori_lanza_size_cat_medium, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_large, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_large, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    2.823129
# 1    8.657952
# Name: hattori_lanza_size_cat_large, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_forward_engineering, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_forward_engineering, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     40.566138
# 1    106.601307
# Name: hattori_lanza_content_cat_forward_engineering, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_reengineering, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_reengineering, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     74.468632
# 1    200.653595
# Name: hattori_lanza_content_cat_reengineering, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_corrective_engineering, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_corrective_engineering, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     41.655329
# 1    116.932462
# Name: hattori_lanza_content_cat_corrective_engineering, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_management, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_management, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     88.990174
# 1    221.775599
# Name: hattori_lanza_content_cat_management, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_empty_message, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_empty_message, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.290249
# 1    0.021786
# Name: hattori_lanza_content_cat_empty_message, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_no_categorisation, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_no_categorisation, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     68.600907
# 1    173.429194
# Name: hattori_lanza_content_cat_no_categorisation, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_doc, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_doc, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     66.626606
# 1    187.437908
# Name: vasilescu_category_doc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_img, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_img, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.297052
# 1    0.664488
# Name: vasilescu_category_img, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_l10n, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_l10n, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0     0.875283
# 1    10.411765
# Name: vasilescu_category_l10n, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_ui, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_ui, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.923658
# 1    1.832244
# Name: vasilescu_category_ui, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_media, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_media, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.575964
# 1    2.344227
# Name: vasilescu_category_media, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_code, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_code, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    223.256236
# 1    570.488017
# Name: vasilescu_category_code, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_meta, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_meta, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.001512
# 1    0.006536
# Name: vasilescu_category_meta, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_config, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_config, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    2.854875
# 1    2.917211
# Name: vasilescu_category_config, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_build, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_build, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    3.170068
# 1    3.137255
# Name: vasilescu_category_build, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_devdoc, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_devdoc, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.591837
# 1    4.858388
# Name: vasilescu_category_devdoc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_db, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_db, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    1.292517
# 1    1.106754
# Name: vasilescu_category_db, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_test, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_test, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    1.581255
# 1    2.050109
# Name: vasilescu_category_test, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_unknown, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_unknown, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    12.523810
# 1    32.148148
# Name: vasilescu_category_unknown, dtype: float64
#
#
# F_onewayResult(statistic=45.52208593807468, pvalue=1.8932628173807043e-11)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj lower   upper  reject
# --------------------------------------------------
#      0      1  74.4097   0.0 52.783 96.0363   True
# --------------------------------------------------
# For n_issues, anova result p-value is 1.8932628173807043e-11; groups are significantly different = True
# For n_issues, Tukey HSD test result p-value is [1.87514448e-11]; groups are significantly different = [ True]
# >>>>>> n_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0     93.564290
# 1    167.973958
# Name: n_issues, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For n_of_issues_creators, anova result p-value is nan; groups are significantly different = False
# For n_of_issues_creators, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    84.073352
# 1    90.335135
# Name: n_of_issues_creators, dtype: float64
#
#
# F_onewayResult(statistic=24.423886816086686, pvalue=8.274130889560042e-07)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      0      1   28.017   0.0  16.9 39.1339   True
# -------------------------------------------------
# For n_issues_assigned, anova result p-value is 8.274130889560042e-07; groups are significantly different = True
# For n_issues_assigned, Tukey HSD test result p-value is [8.27412908e-07]; groups are significantly different = [ True]
# >>>>>> n_issues_assigned ^^^ is significant <<<<<<
#
# cluster_labels
# 0    30.403144
# 1    58.420139
# Name: n_issues_assigned, dtype: float64
#
#
# F_onewayResult(statistic=117.36447219490339, pvalue=1.0078619331145161e-26)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj lower   upper  reject
# --------------------------------------------------
#      0      1  12.1157   0.0 9.9226 14.3087   True
# --------------------------------------------------
# For pc_issues_assigned_of_assigned, anova result p-value is 1.0078619331145161e-26; groups are significantly different = True
# For pc_issues_assigned_of_assigned, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_issues_assigned_of_assigned ^^^ is significant <<<<<<
#
# cluster_labels
# 0    22.713408
# 1    34.829075
# Name: pc_issues_assigned_of_assigned, dtype: float64
#
#
# F_onewayResult(statistic=128.68828421625952, pvalue=4.4447253725998566e-29)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      0      1   0.0529   0.0 0.0438 0.0621   True
# -------------------------------------------------
# For pc_n_commits, anova result p-value is 4.4447253725998566e-29; groups are significantly different = True
# For pc_n_commits, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_n_commits ^^^ is significant <<<<<<
#
# cluster_labels
# 0    0.029494
# 1    0.082416
# Name: pc_n_commits, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-tiny, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-tiny, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    83.291594
# 1    82.243789
# Name: pc_HLs-tiny, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-sml, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-sml, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    12.863027
# 1    13.383879
# Name: pc_HLs-sml, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-med, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-med, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    3.063532
# 1    3.492848
# Name: pc_HLs-med, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-lrg, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-lrg, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.781847
# 1    0.879483
# Name: pc_HLs-lrg, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-fweng, anova result p-value is nan; groups are significantly different = False
# For pc_HL-fweng, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    13.713854
# 1    13.435066
# Name: pc_HL-fweng, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-reeng, anova result p-value is nan; groups are significantly different = False
# For pc_HL-reeng, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    25.720144
# 1    25.888049
# Name: pc_HL-reeng, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-corr, anova result p-value is nan; groups are significantly different = False
# For pc_HL-corr, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    11.849749
# 1    12.629792
# Name: pc_HL-corr, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-mgmt, anova result p-value is nan; groups are significantly different = False
# For pc_HL-mgmt, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    29.384478
# 1    27.593307
# Name: pc_HL-mgmt, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-empty, anova result p-value is nan; groups are significantly different = False
# For pc_HL-empty, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.033908
# 1    0.000670
# Name: pc_HL-empty, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-nocat, anova result p-value is nan; groups are significantly different = False
# For pc_HL-nocat, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    19.297866
# 1    20.453115
# Name: pc_HL-nocat, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-doc, anova result p-value is nan; groups are significantly different = False
# For pc_V-doc, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    25.837742
# 1    25.452138
# Name: pc_V-doc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-code, anova result p-value is nan; groups are significantly different = False
# For pc_V-code, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    65.644270
# 1    66.671172
# Name: pc_V-code, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-confg, anova result p-value is nan; groups are significantly different = False
# For pc_V-confg, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    1.027489
# 1    0.408745
# Name: pc_V-confg, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-build, anova result p-value is nan; groups are significantly different = False
# For pc_V-build, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.954848
# 1    0.588974
# Name: pc_V-build, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-dvdoc, anova result p-value is nan; groups are significantly different = False
# For pc_V-dvdoc, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.585691
# 1    0.649511
# Name: pc_V-dvdoc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-test, anova result p-value is nan; groups are significantly different = False
# For pc_V-test, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.453568
# 1    0.322639
# Name: pc_V-test, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-meta, anova result p-value is nan; groups are significantly different = False
# For pc_V-meta, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.000054
# 1    0.000236
# Name: pc_V-meta, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-img, anova result p-value is nan; groups are significantly different = False
# For pc_V-img, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.099343
# 1    0.110369
# Name: pc_V-img, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-l10n, anova result p-value is nan; groups are significantly different = False
# For pc_V-l10n, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.331062
# 1    0.488406
# Name: pc_V-l10n, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-ui, anova result p-value is nan; groups are significantly different = False
# For pc_V-ui, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.103453
# 1    0.065616
# Name: pc_V-ui, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-media, anova result p-value is nan; groups are significantly different = False
# For pc_V-media, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    0.111853
# 1    0.113212
# Name: pc_V-media, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-nocat, anova result p-value is nan; groups are significantly different = False
# For pc_V-nocat, Tukey HSD test result p-value is [nan]; groups are significantly different = [False]
# cluster_labels
# 0    4.604589
# 1    4.872679
# Name: pc_V-nocat, dtype: float64
#
#
# F_onewayResult(statistic=134.17506003395306, pvalue=3.2428797452846426e-30)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1 433.0873   0.0 359.7693 506.4054   True
# -----------------------------------------------------
# For commit_created, anova result p-value is 3.2428797452846426e-30; groups are significantly different = True
# For commit_created, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> commit_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    234.959573
# 1    668.046875
# Name: commit_created, dtype: float64
#
#
# F_onewayResult(statistic=138.64352731140872, pvalue=3.8647197185137516e-31)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#      0      1  75.5867   0.0 62.9984 88.175   True
# --------------------------------------------------
# For issue_closed, anova result p-value is 3.8647197185137516e-31; groups are significantly different = True
# For issue_closed, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> issue_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0     34.467153
# 1    110.053819
# Name: issue_closed, dtype: float64
#
#
# F_onewayResult(statistic=36.98205274563173, pvalue=1.3870833154336589e-09)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  31.6362   0.0 21.4348 41.8376   True
# ---------------------------------------------------
# For issue_created, anova result p-value is 1.3870833154336589e-09; groups are significantly different = True
# For issue_created, Tukey HSD test result p-value is [1.38690226e-09]; groups are significantly different = [ True]
# >>>>>> issue_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    31.799551
# 1    63.435764
# Name: issue_created, dtype: float64
#
#
# F_onewayResult(statistic=65.10111762280623, pvalue=1.1218408887212761e-15)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj  lower   upper   reject
# ----------------------------------------------------
#      0      1 116.2419   0.0 87.9905 144.4933   True
# ----------------------------------------------------
# For pull_request_closed, anova result p-value is 1.1218408887212761e-15; groups are significantly different = True
# For pull_request_closed, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pull_request_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0     73.265020
# 1    189.506944
# Name: pull_request_closed, dtype: float64
#
#
# F_onewayResult(statistic=26.696718301384788, pvalue=2.5801690060951136e-07)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  42.7735   0.0 26.5398 59.0071   True
# ---------------------------------------------------
# For pull_request_created, anova result p-value is 2.5801690060951136e-07; groups are significantly different = True
# For pull_request_created, Tukey HSD test result p-value is [2.5801672e-07]; groups are significantly different = [ True]
# >>>>>> pull_request_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0     61.764739
# 1    104.538194
# Name: pull_request_created, dtype: float64
#
#
# F_onewayResult(statistic=194.8770579704045, pvalue=1.303077736194506e-42)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1  157.755   0.0 135.5948 179.9153   True
# -----------------------------------------------------
# For interaction_days, anova result p-value is 1.303077736194506e-42; groups are significantly different = True
# For interaction_days, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> interaction_days ^^^ is significant <<<<<<
#
# cluster_labels
# 0    119.975856
# 1    277.730903
# Name: interaction_days, dtype: float64
#
#
# F_onewayResult(statistic=179.57164031711534, pvalue=1.6218617987776604e-39)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1 733.5748   0.0 626.2261 840.9235   True
# -----------------------------------------------------
# For interaction_period_days, anova result p-value is 1.6218617987776604e-39; groups are significantly different = True
# For interaction_period_days, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> interaction_period_days ^^^ is significant <<<<<<
#
# cluster_labels
# 0    1406.854015
# 1    2140.428819
# Name: interaction_period_days, dtype: float64
#
#
# F_onewayResult(statistic=53.59132233004597, pvalue=3.370620092687879e-13)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1 -43.9505   0.0 -55.7235 -32.1774   True
# -----------------------------------------------------
# For created-closed_issues, anova result p-value is 3.370620092687879e-13; groups are significantly different = True
# For created-closed_issues, Tukey HSD test result p-value is [1.55986335e-13]; groups are significantly different = [ True]
# >>>>>> created-closed_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0    -2.667602
# 1   -46.618056
# Name: created-closed_issues, dtype: float64
#
#
# F_onewayResult(statistic=2305.167340656016, pvalue=0.0)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1 -30.5583   0.0 -31.8064 -29.3102   True
# -----------------------------------------------------
# For pc_created-closed_issues, anova result p-value is 0.0; groups are significantly different = True
# For pc_created-closed_issues, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_created-closed_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0   -12.838373
# 1   -43.396630
# Name: pc_created-closed_issues, dtype: float64
#
#
# F_onewayResult(statistic=157.69567162481758, pvalue=4.6657877416947386e-35)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj  lower   upper   reject
# ----------------------------------------------------
#      0      1 699.3256   0.0 590.121 808.5301   True
# ----------------------------------------------------
# For sum_n_interactions, anova result p-value is 4.6657877416947386e-35; groups are significantly different = True
# For sum_n_interactions, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> sum_n_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0     436.256036
# 1    1135.581597
# Name: sum_n_interactions, dtype: float64
#
#
# F_onewayResult(statistic=0.23708562985400428, pvalue=0.6263643097982312)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1  -0.5907 0.6264 -2.9697 1.7883  False
# ---------------------------------------------------
# For mean_n_interactions_per_interaction_day, anova result p-value is 0.6263643097982312; groups are significantly different = False
# For mean_n_interactions_per_interaction_day, Tukey HSD test result p-value is [0.62636431]; groups are significantly different = [False]
# cluster_labels
# 0    4.234577
# 1    3.643874
# Name: mean_n_interactions_per_interaction_day, dtype: float64
#
#
# F_onewayResult(statistic=89.17736964454336, pvalue=8.377661869915257e-21)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================
# group1 group2 meandiff p-adj lower  upper reject
# ------------------------------------------------
#      0      1   0.5648   0.0 0.4475 0.682   True
# ------------------------------------------------
# For breadth_interactions, anova result p-value is 8.377661869915257e-21; groups are significantly different = True
# For breadth_interactions, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> breadth_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    4.884896
# 1    5.449653
# Name: breadth_interactions, dtype: float64
#
#
# F_onewayResult(statistic=143.53311020214477, pvalue=3.787695397202802e-32)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj lower   upper  reject
# --------------------------------------------------
#      0      1  10.0173   0.0 8.3776 11.6569   True
# --------------------------------------------------
# For pc_pull_request_created, anova result p-value is 3.787695397202802e-32; groups are significantly different = True
# For pc_pull_request_created, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_pull_request_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    15.545993
# 1    25.563248
# Name: pc_pull_request_created, dtype: float64
#
#
# F_onewayResult(statistic=1046.5792659487556, pvalue=2.734235929417403e-190)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1   28.698   0.0 26.9585 30.4376   True
# ---------------------------------------------------
# For pc_pull_request_closed, anova result p-value is 2.734235929417403e-190; groups are significantly different = True
# For pc_pull_request_closed, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_pull_request_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0    16.111822
# 1    44.809848
# Name: pc_pull_request_closed, dtype: float64
#
#
# F_onewayResult(statistic=685.8102087090242, pvalue=6.887173615493899e-133)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  19.4307   0.0 17.9757 20.8857   True
# ---------------------------------------------------
# For pc_commit_created, anova result p-value is 6.887173615493899e-133; groups are significantly different = True
# For pc_commit_created, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_commit_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    10.702327
# 1    30.133001
# Name: pc_commit_created, dtype: float64
#
#
# F_onewayResult(statistic=195.38899525176524, pvalue=1.0275203058137334e-42)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      0      1  10.1232   0.0 8.703 11.5434   True
# -------------------------------------------------
# For pc_issue_created, anova result p-value is 1.0275203058137334e-42; groups are significantly different = True
# For pc_issue_created, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_issue_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    12.346918
# 1    22.470116
# Name: pc_issue_created, dtype: float64
#
#
# F_onewayResult(statistic=2310.0002704766507, pvalue=0.0)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  30.6634   0.0 29.4123 31.9145   True
# ---------------------------------------------------
# For pc_issue_closed, anova result p-value is 0.0; groups are significantly different = True
# For pc_issue_closed, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_issue_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0    12.957912
# 1    43.621331
# Name: pc_issue_closed, dtype: float64
#
#
# F_onewayResult(statistic=1432.073923480809, pvalue=3.1142926754306693e-245)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#      0      1  21.9391   0.0 20.8023 23.076   True
# --------------------------------------------------
# For pc_sum_n_interactions, anova result p-value is 3.1142926754306693e-245; groups are significantly different = True
# For pc_sum_n_interactions, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_sum_n_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    13.988691
# 1    35.927812
# Name: pc_sum_n_interactions, dtype: float64
#
#
# F_onewayResult(statistic=965.8078011030775, pvalue=5.475459620832443e-178)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  16.3359   0.0 15.3051 17.3667   True
# ---------------------------------------------------
# For pc_interaction_days, anova result p-value is 5.475459620832443e-178; groups are significantly different = True
# For pc_interaction_days, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_interaction_days ^^^ is significant <<<<<<
#
# cluster_labels
# 0    13.196110
# 1    29.532036
# Name: pc_interaction_days, dtype: float64
#
#
# F_onewayResult(statistic=2398.039423667594, pvalue=0.0)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1    16.47   0.0 15.8105 17.1296   True
# ---------------------------------------------------
# For pc_DC, anova result p-value is 0.0; groups are significantly different = True
# For pc_DC, Tukey HSD test result p-value is [0.]; groups are significantly different = [ True]
# >>>>>> pc_DC ^^^ is significant <<<<<<
#
# cluster_labels
# 0    14.853312
# 1    31.323354
# Name: pc_DC, dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["pc_commit_created"].describe()
# Out:
#                  count       mean        std  min       25%        50%  \
# cluster_labels
# 0               1781.0  10.702327  12.195468  0.0  0.000000   7.221284
# 1                576.0  30.133001  22.823895  0.0  9.147806  30.515792
#
#                       75%         max
# cluster_labels
# 0               17.053643   98.566308
# 1               45.555813  100.000000

# %%
analysis_dataset.groupby("cluster_labels")["pc_issue_created"].describe()
# Out:
#                  count       mean        std  min       25%        50%  \
# cluster_labels
# 0               1781.0  12.346918  14.592178  0.0  1.845907   8.108108
# 1                576.0  22.470116  16.606649  0.0  9.175931  20.620205
#
#                       75%         max
# cluster_labels
# 0               17.647059  100.000000
# 1               33.333333   78.787879

# %%
analysis_dataset.groupby("cluster_labels")["pc_issue_closed"].describe()
# Out:
#                  count       mean        std  min        25%        50%  \
# cluster_labels
# 0               1781.0  12.957912  12.130919  0.0   2.247191  10.344828
# 1                576.0  43.621331  16.432158  0.0  33.923440  43.555666
#
#                       75%         max
# cluster_labels
# 0               20.754717   67.857143
# 1               53.058190  100.000000

# %%
analysis_dataset.groupby("cluster_labels")["pc_issues_assigned_of_assigned"].describe()
# Out:
#                  count       mean        std  min        25%        50%  \
# cluster_labels
# 0               1781.0  22.713408  22.415177  0.0   1.971831  19.607843
# 1                576.0  34.829075  25.963866  0.0  15.104167  32.441382
#
#                       75%    max
# cluster_labels
# 0               33.333333  100.0
# 1               50.000000  100.0

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_created"].describe()
# Out:
#                  count       mean        std  min        25%        50%  \
# cluster_labels
# 0               1781.0  15.545993  17.406541  0.0   3.703704  11.111111
# 1                576.0  25.563248  17.557822  0.0  11.145546  25.471300
#
#                       75%         max
# cluster_labels
# 0               20.524017  100.000000
# 1               37.575330   85.294118

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_closed"].describe()
# Out:
#                  count       mean        std  min        25%        50%  \
# cluster_labels
# 0               1781.0  16.111822  16.998563  0.0   2.861897  12.421581
# 1                576.0  44.809848  22.544681  0.0  28.138616  44.444444
#
#                       75%    max
# cluster_labels
# 0               24.324324  100.0
# 1               60.484243  100.0

# %%
analysis_dataset.groupby("cluster_labels")["pc_DC"].describe()
# Out:
#                  count       mean       std        min        25%        50%  \
# cluster_labels
# 0               1781.0  14.853312  6.661322   0.174672   9.595631  13.567276
# 1                576.0  31.323354  8.017413  11.273408  25.547359  31.480087
#
#                       75%        max
# cluster_labels
# 0               18.856828  59.371728
# 1               37.316961  54.269570

# %%
analysis_dataset['RSE_persona'] = analysis_dataset['cluster_labels']

analysis_dataset[["repo_name", "gh_username", "cluster_labels", "RSE_persona"]]
# Out:
#                                             repo_name       gh_username  \
# 0                 SINTEF/AutoActive-ActivityPresenter          aliverud
# 1                              feelpp/book.feelpp.org   dependabot[bot]
# 2                              feelpp/book.feelpp.org  vincentchabannes
# 3                                       LDflex/LDflex     RubenVerborgh
# 4                                       LDflex/LDflex   dependabot[bot]
# ...                                               ...               ...
# 2352                                  ctuning/ck-math           ens-lg4
# 2353                                  ctuning/ck-math           gfursin
# 2354                               coin-or/python-mip             h-g-s
# 2355  Open-Science-Training-Handbook/handbook_content          helenebr
# 2356                            opencitations/oc_meta            ivanhb
#
#       cluster_labels  RSE_persona
# 0                  0            0
# 1                  0            0
# 2                  0            0
# 3                  1            1
# 4                  0            0
# ...              ...          ...
# 2352               0            0
# 2353               0            0
# 2354               0            0
# 2355               0            0
# 2356               0            0
#
# [2357 rows x 4 columns]

# %%
analysis_dataset.replace(to_replace={'RSE_persona': {0: "project_organiser", 1: "moderate_contributor"}}, inplace=True)

analysis_dataset[["repo_name", "gh_username", "cluster_labels", "RSE_persona"]]
# Out:
#                                             repo_name       gh_username  \
# 0                 SINTEF/AutoActive-ActivityPresenter          aliverud
# 1                              feelpp/book.feelpp.org   dependabot[bot]
# 2                              feelpp/book.feelpp.org  vincentchabannes
# 3                                       LDflex/LDflex     RubenVerborgh
# 4                                       LDflex/LDflex   dependabot[bot]
# ...                                               ...               ...
# 2352                                  ctuning/ck-math           ens-lg4
# 2353                                  ctuning/ck-math           gfursin
# 2354                               coin-or/python-mip             h-g-s
# 2355  Open-Science-Training-Handbook/handbook_content          helenebr
# 2356                            opencitations/oc_meta            ivanhb
#
#       cluster_labels           RSE_persona
# 0                  0     project_organiser
# 1                  0     project_organiser
# 2                  0     project_organiser
# 3                  1  moderate_contributor
# 4                  0     project_organiser
# ...              ...                   ...
# 2352               0     project_organiser
# 2353               0     project_organiser
# 2354               0     project_organiser
# 2355               0     project_organiser
# 2356               0     project_organiser
#
# [2357 rows x 4 columns]

# %%
analysis_dataset.to_csv("../../data/analysis_run_sample_45pc_cluster0_2025-05-13/sample_45pc_cluster0_personas_named_dataset_2025-05-30.csv", header=True, index=False)
