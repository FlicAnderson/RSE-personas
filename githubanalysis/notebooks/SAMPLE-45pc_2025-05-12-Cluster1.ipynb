# %%
import datetime 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from githubanalysis.analysis.analyse_data import DataAnalyser


dataanalyser = DataAnalyser(in_notebook=True, logger=None, dataset_name="sample_45pc_notebook_cluster1")
current_date_info = datetime.datetime.now().strftime(
            "%Y-%m-%d"
        )
print(current_date_info)
# Out:
# 2025-08-31

# %%
# # SUBCLUSTERING CLUSTER 1: 
# [2025-05-13 12:53:55,309] INFO:
#         Running Data Analysis with arguments: Namespace(data_file='subsample_45pc_cluster_1_data__2025-05-13.csv', subset_file='study-sample-repo-names_2025-05-01_x2981.txt', pc_subset_repos=100, interactions_file='merged-interactions-data-per-dev_x2946-repos_2025-05-12.csv', repo_stats_file='summarised_repo_stats_2025-05-01.csv', max_n_clusters=10, n_clusters=None, dataset_run_name='sample_45pc_cluster1');
#         data: subsample_45pc_cluster_1_data__2025-05-13.csv;
#         run name: sample_45pc_cluster1;
#         subset to: study-sample-repo-names_2025-05-01_x2981.txt;
#         percentage of subset to use: 100;
#         interactions: merged-interactions-data-per-dev_x2946-repos_2025-05-12.csv;
#         repo_stats summary data: summarised_repo_stats_2025-05-01.csv;
#         max number of clusters to eval: 10;
#         number of clusters to use: None; .

# [2025-05-13 12:53:55,320] INFO:data is df, with shape: (700, 48).
# [2025-05-13 12:53:55,321] INFO:Before subsetting: Number of unique gh_usernames in sample is: 653.
# [2025-05-13 12:53:55,328] INFO:Before subsetting: Number of gh_usernames appearing in more than one repository in this sample is: 37.
# [2025-05-13 12:53:55,330] INFO:Before subsetting: Number of repo-individuals (repo_name plus gh_username combos) in sample is: 700.
# [2025-05-13 12:53:55,330] INFO:Before subsetting: Number of repositories in sample is: 700.
# [2025-05-13 12:53:55,330] INFO:data is df, with shape: (700, 48).
# [2025-05-13 12:53:55,363] INFO:length of subset_repos_file is: 2981 repos
# [2025-05-13 12:53:55,363] INFO:Subsetting percentage is: 100; using random seed: 42
# [2025-05-13 12:53:55,367] INFO:After applying subset percentage, length of subset_repos_file is: 2981 repos
# [2025-05-13 12:53:55,370] INFO:length of subset dataset is now: 700
# [2025-05-13 12:53:55,394] INFO:Number of repositories in sample is: 700.
# [2025-05-13 12:53:55,395] INFO:Number of unique gh_usernames in sample is: 653.
# [2025-05-13 12:53:55,398] INFO:Number of gh_usernames appearing in more than one repository in this sample is: 37.
# [2025-05-13 12:53:55,399] INFO:Number of repo-individuals (repo_name plus gh_username combos) in sample is: 700.
# [2025-05-13 12:53:57,129] INFO:Column names from cleaned_df: Index(['repo_name', 'gh_username', 'author_username', 'n_of_commit_creators',
#        'n_commits', 'pc_repo_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown',
#        'issue_author_username', 'n_issues', 'pc_repo_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', '_merge', 'issue_username',
#        'commiss_merge', '_dataset_source', 'CBRI', 'contributions_by_user',
#        'pcCDC', 'pc_n_commits', 'pc_HLs-tiny', 'pc_HLs-sml', 'pc_HLs-med',
#        'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng', 'pc_HL-corr', 'pc_HL-mgmt',
#        'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc', 'pc_V-code', 'pc_V-confg',
#        'pc_V-build', 'pc_V-dvdoc', 'pc_V-test', 'pc_V-meta', 'pc_V-img',
#        'pc_V-l10n', 'pc_V-ui', 'pc_V-media', 'pc_V-nocat'],
#       dtype='object')
# [2025-05-13 12:53:57,129] INFO:Column names from interactions file: Index(['repo_name', 'gh_username', 'commit_created', 'issue_closed',
#        'issue_created', 'pull_request_closed', 'pull_request_created',
#        'interaction_days', 'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days'],
#       dtype='object')
# [2025-05-13 12:53:57,129] INFO:cleaned_data.shape =(700, 74)
# [2025-05-13 12:53:57,129] INFO:all_interaction_data.shape =(244561, 22)
# [2025-05-13 12:53:57,192] INFO:cleaned_data_with_interactions.shape = (700, 94)
# [2025-05-13 12:53:57,192] INFO:Number of unique cols in cleaned_data_with_interactions is: 94.
# [2025-05-13 12:53:57,246] INFO:Combined cleaned_data_with_interaction_data df has shape: (700, 85).
# [2025-05-13 12:53:57,280] INFO:Combined cleaned_data and interaction_data written out to data/analysis_run_sample_45pc_cluster1_2025-05-13/cleaned_data_with_interaction-data-per-dev__2025-05-13.csv
# [2025-05-13 12:53:57,281] INFO:Wrote out 700 records to file sample_45pc_cluster1_subsample_repo_names_list_2025-05-13_x700.txt.
# [2025-05-13 12:53:57,444] INFO:data is df, with shape: (36196, 15).
# [2025-05-13 12:53:57,445] INFO:length of subset_repos_file is: 700 repos
# [2025-05-13 12:53:57,445] INFO:Subsetting percentage is: 100; using random seed: 42
# [2025-05-13 12:53:57,445] INFO:After applying subset percentage, length of subset_repos_file is: 700 repos
# [2025-05-13 12:53:57,449] INFO:length of subset dataset is now: 700
# [2025-05-13 12:53:57,454] INFO:Relevant repo_stats subset written out to data/analysis_run_sample_45pc_cluster1_2025-05-13/summarised_SAMPLE_repos_stats_2025-05-13.csv
# [2025-05-13 12:53:57,494] INFO:234 unique languages listed in dataset of 700 unique repositories...
# [2025-05-13 12:53:57,503] INFO:Top 15 RS Repo Languages from Dataset:        repo_language  n_repos_using_language  pc_repos_using_language
# 0             Python                     529                75.571429
# 1              Shell                     332                47.428571
# 2           Makefile                     173                24.714286
# 3         Dockerfile                     153                21.857143
# 4               HTML                     148                21.142857
# 5                TeX                     121                17.285714
# 6   Jupyter Notebook                     114                16.285714
# 7                C++                     108                15.428571
# 8                  C                     105                15.000000
# 9         JavaScript                      95                13.571429
# 10               CSS                      90                12.857143
# 11             CMake                      66                 9.428571
# 12                 R                      64                 9.142857
# 13         Batchfile                      60                 8.571429
# 14             Julia                      46                 6.571429
# [2025-05-13 12:53:57,504] INFO:dataset languages information written out to data/analysis_run_sample_45pc_cluster1_2025-05-13/sample_languages_info__2025-05-13.csv
# [2025-05-13 12:53:57,959] INFO:Plot saved out to file images/analysis_run_sample_45pc_cluster1_2025-05-13/sample_languages_2025-05-13.png.
# [2025-05-13 12:53:57,960] INFO:Sample repos languages info collected and written out and plotted.
# [2025-05-13 12:53:57,997] INFO:Processed sample data written out to data/analysis_run_sample_45pc_cluster1_2025-05-13/pre-processing_dataset_x700repos_x700project-individuals__2025-05-13.csv
# [2025-05-13 12:53:57,997] INFO:Data will be clustered on the following 10 variables: ['pc_commit_created', 'pc_issue_created', 'pc_issue_closed', 'pc_issues_assigned_of_assigned', 'pc_pull_request_created', 'pc_pull_request_closed', 'pc_DC', 'pc_sum_n_interactions', 'pc_interaction_days', 'pc_created-closed_issues'].
# [2025-05-13 12:53:58,005] INFO:Clustering dataset has shape (700, 10)
# [2025-05-13 12:53:58,005] INFO:Attempting to use 700 repo-individuals dataset for clustering
# [2025-05-13 12:53:58,164] INFO:Created ward clustering linkage object, now attempting to generate dendrogram
# [2025-05-13 12:53:58,550] INFO:Plot saved out to file images/analysis_run_sample_45pc_cluster1_2025-05-13/sample_dendrogram__2025-05-13.png.
# [2025-05-13 12:53:58,550] INFO:clustering data is df, with shape: (700, 10).
# [2025-05-13 12:53:58,676] INFO:CH score for n_clusters 2 is 148.14586833295115.
# [2025-05-13 12:53:58,745] INFO:CH score for n_clusters 3 is 165.5523813394446.
# [2025-05-13 12:53:58,810] INFO:CH score for n_clusters 4 is 155.27406576604494.
# [2025-05-13 12:53:58,874] INFO:CH score for n_clusters 5 is 141.40530571295156.
# [2025-05-13 12:53:58,943] INFO:CH score for n_clusters 6 is 130.71468949161962.
# [2025-05-13 12:53:59,026] INFO:CH score for n_clusters 7 is 125.68657950569802.
# [2025-05-13 12:53:59,093] INFO:CH score for n_clusters 8 is 119.22425165863523.
# [2025-05-13 12:53:59,158] INFO:CH score for n_clusters 9 is 112.96813337647251.
# [2025-05-13 12:53:59,223] INFO:CH score for n_clusters 10 is 107.3871930729121.
# [2025-05-13 12:53:59,224] INFO:CH scores for 9 clusters written out to file data/analysis_run_sample_45pc_cluster1_2025-05-13/sample_calinski-harabasz_scores_across_N_clusters__2025-05-13.csv.
# [2025-05-13 12:53:59,225] INFO:Calinski-Harabasz Score evaluation of 10 clusters shows best number of clusters for sample is 3 with score 165.5523813394446.
# [2025-05-13 12:53:59,400] INFO:Plot saved out to file images/analysis_run_sample_45pc_cluster1_2025-05-13/sample_CHscore_per_Ncluster__2025-05-13.png.
# [2025-05-13 12:53:59,473] INFO:Generating best_n_clusters: 3.
# [2025-05-13 12:53:59,473] INFO:Attempting clustering with dataset shape (700, 10) and 10 columns: Index(['pc_commit_created', 'pc_issue_created', 'pc_issue_closed',
#        'pc_issues_assigned_of_assigned', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_DC', 'pc_sum_n_interactions',
#        'pc_interaction_days', 'pc_created-closed_issues'],
#       dtype='object').
# [2025-05-13 12:53:59,520] INFO:Applied 3 cluster labels to dataset to create labelled dataset of shape: (700, 86).
# [2025-05-13 12:53:59,770] INFO:Explained variability per principal component: [0.30514354 0.24929692]
# [2025-05-13 12:54:00,062] INFO:PCA 2D Plot saved out to file images/analysis_run_sample_45pc_cluster1_2025-05-13/sample_2D_PCA__2025-05-13.png.
# [2025-05-13 12:54:00,084] INFO:Explained variability per principal component: [0.30514354 0.24929692 0.17758264]
# [2025-05-13 12:54:00,262] INFO:PCA 3D Plot saved out to file images/analysis_run_sample_45pc_cluster1_2025-05-13/sample_3D_PCA__2025-05-13.png.
# [2025-05-13 12:54:00,262] INFO:Generating feature importance ranking for PCA via clustering data.
# [2025-05-13 12:54:00,262] INFO:clustering data is df, with shape: (700, 10).
# [2025-05-13 12:54:00,263] INFO:Re-applying PCA and gathering PCA values from clustering data.
# [2025-05-13 12:54:00,272] INFO:Gathering feature importance values for each variable involved in clustering. These were: ['pc_commit_created', 'pc_issue_created', 'pc_issue_closed', 'pc_issues_assigned_of_assigned', 'pc_pull_request_created', 'pc_pull_request_closed', 'pc_DC', 'pc_sum_n_interactions', 'pc_interaction_days', 'pc_created-closed_issues']
# [2025-05-13 12:54:00,294] INFO:PCA feature importances ranked:
# [2025-05-13 12:54:00,294] INFO:PCA1 mainly explained by pc_created-closed_issues with importance value 0.08488413348826697.
# [2025-05-13 12:54:00,294] INFO:PCA2 mainly explained by pc_issues_assigned_of_assigned with importance value 0.6736043754470048.
# [2025-05-13 12:54:00,294] INFO:PCA3 mainly on pc_issue_created with importance value 0.7012991980677717.
    
# (coding-smart-github) flic@eidf103-vm:~/clonezone/coding-smart$(parse_git_branch)$ time python githubanalysis/analysis/analyse_data.py -d subsample_45pc_cluster_1_data__2025-05-13.csv -z sample_45pc_cluster1
# real    0m10.048s
# user    0m9.544s
# sys     0m0.882s

# %%
# PC of sample repos from POPULATION N repos.
(1284 / 36226)*100
# Out:
# 3.5444156130955666

# %%
# PC of unique gh_usernames in sample which appear 
# in more than one repo_name
(10140 / 97521)*100
# Out:
# 10.397760482357645

# %%
# plotting details: 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion,

# %%
orig_data_file = "../../data/merged-data-per-dev_x2868-repos_2025-05-10.csv"
analysis_dataset_file = "../../data/analysis_run_sample_45pc_cluster1_2025-05-13/clustered_sample_data_with_labels__2025-05-13.csv"
# via:  "../../data/merged-data-per-dev_x2868-repos_2025-05-10.csv" and merged-interactions-data-per-dev_x2946-repos_2025-05-12.csv
sample_repo_stats_file = "../../data/analysis_run_sample_45pc_cluster1_2025-05-13/summarised_SAMPLE_repos_stats_2025-05-13.csv"
study_repos_file = "../../data/study-sample-repo-names_2025-05-01_x2981.txt"

# %%
orig_dataset = pd.read_csv(orig_data_file, header=0, low_memory=False)
orig_dataset
# Out:
#                               repo_name  author_username  \
# 0                     WIPACrepo/iceprod     actions-user
# 1                     WIPACrepo/iceprod           alemsh
# 2                     WIPACrepo/iceprod         carlwitt
# 3                     WIPACrepo/iceprod  dependabot[bot]
# 4                     WIPACrepo/iceprod         dsschult
# ...                                 ...              ...
# 244138            trendscenter/coinstac              NaN
# 244139            trendscenter/coinstac              NaN
# 244140               geopython/pygeoapi              NaN
# 244141  h2020-westlife-eu/virtualfolder              NaN
# 244142  h2020-westlife-eu/virtualfolder              NaN
#
#         n_of_commit_creators  n_commits  pc_repo_commits  n_changes  \
# 0                       12.0        7.0         0.271108       40.0
# 1                       12.0        1.0         0.038730      151.0
# 2                       12.0        1.0         0.038730        2.0
# 3                       12.0       10.0         0.387297       24.0
# 4                       12.0     2275.0        88.109992  1117264.0
# ...                      ...        ...              ...        ...
# 244138                   NaN        0.0         0.000000        NaN
# 244139                   NaN        0.0         0.000000        NaN
# 244140                   NaN        0.0         0.000000        NaN
# 244141                   NaN        0.0         0.000000        NaN
# 244142                   NaN        0.0         0.000000        NaN
#
#         mean_n_changes  median_n_changes_changed  std_n_changes_changed  \
# 0             5.714286                       5.0               1.253566
# 1           151.000000                     151.0                    NaN
# 2             2.000000                       2.0                    NaN
# 3             2.400000                       2.0               1.264911
# 4           491.105055                      10.0            4118.362826
# ...                ...                       ...                    ...
# 244138             NaN                       NaN                    NaN
# 244139             NaN                       NaN                    NaN
# 244140             NaN                       NaN                    NaN
# 244141             NaN                       NaN                    NaN
# 244142             NaN                       NaN                    NaN
#
#         n_files_changed  ...  pc_repo_issues  n_of_issues_creators  \
# 0                  14.0  ...        0.000000                   NaN
# 1                   6.0  ...        0.234192                  18.0
# 2                   1.0  ...        0.468384                  18.0
# 3                  12.0  ...        5.386417                  18.0
# 4               10371.0  ...       84.543326                  18.0
# ...                 ...  ...             ...                   ...
# 244138              NaN  ...        0.000000                   NaN
# 244139              NaN  ...        0.000000                   NaN
# 244140              NaN  ...        0.000000                   NaN
# 244141              NaN  ...        0.000000                   NaN
# 244142              NaN  ...        0.000000                   NaN
#
#         assigned_devs  n_issues_assigned  pc_issues_assigned_of_assigned  \
# 0          unassigned                0.0                        0.000000
# 1              alemsh                1.0                        0.390625
# 2          unassigned                0.0                        0.000000
# 3          unassigned                0.0                        0.000000
# 4            dsschult              216.0                       84.375000
# ...               ...                ...                             ...
# 244138   krootesmurdy                5.0                        2.590674
# 244139  sunithabasodi               10.0                        5.181347
# 244140     msmitherdc                2.0                        0.519481
# 244141   chrishmorris                1.0                        2.857143
# 244142         kouril                1.0                        2.857143
#
#             _merge   issue_username  commiss_merge      gh_username  \
# 0              NaN              NaN      left_only     actions-user
# 1             both           alemsh           both           alemsh
# 2        left_only         carlwitt           both         carlwitt
# 3        left_only  dependabot[bot]           both  dependabot[bot]
# 4             both         dsschult           both         dsschult
# ...            ...              ...            ...              ...
# 244138  right_only     krootesmurdy     right_only     krootesmurdy
# 244139  right_only    sunithabasodi     right_only    sunithabasodi
# 244140  right_only       msmitherdc     right_only       msmitherdc
# 244141  right_only     chrishmorris     right_only     chrishmorris
# 244142  right_only           kouril     right_only           kouril
#
#         _dataset_source
# 0          Only Commits
# 1                  Both
# 2                  Both
# 3                  Both
# 4                  Both
# ...                 ...
# 244138      Only Issues
# 244139      Only Issues
# 244140      Only Issues
# 244141      Only Issues
# 244142      Only Issues
#
# [244143 rows x 48 columns]

# %%
orig_dataset.groupby(["repo_name", "gh_username"]).ngroups
# Out:
# 244143

# %%
orig_dataset.n_commits.sum() # number of commits 4.7million across all 262,706 repo-individs
# Out:
# 4746707.0

# %%
orig_dataset.n_issues.sum() # number of issues 1.7 million across all 262,706 repo-indiviuals
# Out:
# 1772477.0

# %%
orig_dataset.n_issues_assigned.sum() # 400,000 issues assigned across all 262,706 repo-individuals
# Out:
# 404572.0

# %%
orig_dataset.groupby("repo_name").size()
# SHOWS FIX IN NAMES: 
# repo_name
# 1313e/CMasher                         33
# 3MAH/microgen                         13
# 3dct/open_iA                          18
# 4DNucleome/PartSeg                    23
# 52North/javaPS                        16
#                                     ... 
# zfit/zfit                             65
# zkbt/chromatic                        19
# zooniverse/aggregation-for-caesar     33
# zqfang/GSEApy                        190
# zwicker-group/py-pde                  65

# PREVIOUS PUIR EFFORT:
# repo_name
# 1313e/CMasher                         33
# 3MAH/microgen                         13
# 3dct/open_iA                          18
# 4DNucleome/PartSeg                    23
# 52North/javaPS                        16
#                                     ... 
# zooniverse/aggregation-for-caesar     32
# zooniverse/aggregation/for/caesar     19
# zqfang/GSEApy                        190
# zwicker-group/py-pde                  65
# zwicker/group/py/pde                   7
# Out:
# repo_name
# 1313e/CMasher                         33
# 3MAH/microgen                         13
# 3dct/open_iA                          18
# 4DNucleome/PartSeg                    23
# 52North/javaPS                        16
#                                     ...
# zfit/zfit                             65
# zkbt/chromatic                        19
# zooniverse/aggregation-for-caesar     33
# zqfang/GSEApy                        190
# zwicker-group/py-pde                  65
# Length: 2868, dtype: int64

# %%
# read in the analysed dataset with cluster labels
analysis_dataset = pd.read_csv(analysis_dataset_file, header=0, low_memory=False)
#analysis_dataset.columns

# %%
analysis_dataset.cluster_labels.value_counts(dropna=False)
# cluster_labels
# 1    106079
# 0      1879
# Name: count, dtype: int64
# Out:
# cluster_labels
# 0    336
# 1    230
# 2    134
# Name: count, dtype: int64

# %%
subsample_cluster0 = analysis_dataset.query("cluster_labels == 0")[["repo_name", "gh_username", "cluster_labels"]]
subsample_cluster0
# Out:
#                       repo_name  gh_username  cluster_labels
# 1        feelpp/book.feelpp.org     prudhomm               0
# 5           gtonkinhill/panaroo  gtonkinhill               0
# 7       mljs/spectra-processing      lpatiny               0
# 8                 AlDanial/cloc     AlDanial               0
# 15            readchina/ReadAct     duncdrum               0
# ..                          ...          ...             ...
# 695          cohenlabUNC/clpipe    wasciutto               0
# 696         ncihtan/data-models  adamjtaylor               0
# 697             desy-ml/cheetah      jank324               0
# 698      cytoscape/cytoscape.js    maxkfranz               0
# 699  OpenChemistry/avogadrolibs     ghutchis               0
#
# [336 rows x 3 columns]

# %%
subsample_0 = pd.merge(subsample_cluster0, orig_dataset, on=["gh_username", "repo_name"], )
subsample_0.drop(columns=["cluster_labels"], inplace=True)

dataanalyser.writeout_data_to_csv(subsample_0, "subsample_45pc_cluster_0_data_")
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster1_2025-08-31/subsample_45pc_cluster_0_data__2025-08-31.csv')

# %%
subsample_cluster1 = analysis_dataset.query("cluster_labels == 1")[["repo_name", "gh_username", "cluster_labels"]]
subsample_cluster1
# Out:
#                       repo_name        gh_username  cluster_labels
# 0             WIPACrepo/iceprod           dsschult               1
# 2                   dswah/pyGAM              dswah               1
# 3    JuliaMath/MeasureTheory.jl          cscherrer               1
# 4           sintefmath/Jutul.jl             moyner               1
# 6       vivekjoshy/openskill.py         vivekjoshy               1
# ..                          ...                ...             ...
# 566           mala-project/mala  RandomDefaultUser               1
# 568             a-h-b/dadasnake              a-h-b               1
# 570           hammerlab/varcode            iskandr               1
# 573              Chrismarsh/CHM         Chrismarsh               1
# 576       annoviko/pyclustering           annoviko               1
#
# [230 rows x 3 columns]

# %%
subsample_1 = pd.merge(subsample_cluster1, orig_dataset, on=["gh_username", "repo_name"], )
subsample_1.drop(columns=["cluster_labels"], inplace=True)

dataanalyser.writeout_data_to_csv(subsample_1, "subsample_45pc_cluster_1_data_")
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster1_2025-08-31/subsample_45pc_cluster_1_data__2025-08-31.csv')

# %%
subsample_cluster2 = analysis_dataset.query("cluster_labels == 2")[["repo_name", "gh_username", "cluster_labels"]]
subsample_cluster2
# Out:
#                                 repo_name       gh_username  cluster_labels
# 9              pyro-kinetics/pyrokinetics        bpatel2107               2
# 17                         NREL/graph-env           pstjohn               2
# 19   cgrudz/DataAssimilationBenchmarks.jl            cgrudz               2
# 22                qbic-pipelines/rnadeseq           WackerO               2
# 23                       nf-core/fetchngs          drpatelh               2
# ..                                    ...               ...             ...
# 539                marcelauliano/MitoHiFi     marcelauliano               2
# 542                    dftd3/simple-dftd3            awvwgk               2
# 563                    wtclarke/pymapvbvd          wtclarke               2
# 569                     shandley/hecatomb  beardymcjohnface               2
# 577                J535D165/recordlinkage          J535D165               2
#
# [134 rows x 3 columns]

# %%
subsample_2 = pd.merge(subsample_cluster2, orig_dataset, on=["gh_username", "repo_name"], )
subsample_2.drop(columns=["cluster_labels"], inplace=True)

dataanalyser.writeout_data_to_csv(subsample_2, "subsample_45pc_cluster_2_data_")
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster1_2025-08-31/subsample_45pc_cluster_2_data__2025-08-31.csv')

# %%
len(analysis_dataset)
# Out:
# 700

# %%
cluster1_issues_only = len(analysis_dataset.query("cluster_labels == 1 and which_interactions == 'issue_created'")[["gh_username", "repo_name", "cluster_labels", "breadth_interactions", "which_interactions"]])
cluster0_issues_only = len(analysis_dataset.query("cluster_labels == 0 and which_interactions == 'issue_created'")[["gh_username", "repo_name", "cluster_labels", "breadth_interactions", "which_interactions"]])

print(f'Cluster 0 contains {cluster0_issues_only} issues_only folks of {len(analysis_dataset.query("cluster_labels == 0"))}; cluster 1 contains {cluster1_issues_only} issues_only folks of {len(analysis_dataset.query("cluster_labels == 1"))}.')
# Out:
# Cluster 0 contains 0 issues_only folks of 336; cluster 1 contains 0 issues_only folks of 230.

# %%
#analysis_dataset.query("cluster_labels == 0 and which_interactions == 'issue_created'")[["gh_username", "repo_name", "cluster_labels", "breadth_interactions", "which_interactions"]]
# 53736 rows × 5 columns

no_issues_only = analysis_dataset.query("which_interactions != 'issue_created'")[["repo_name","gh_username",]]
no_issues_only_sample = pd.merge(no_issues_only, orig_dataset, on=["repo_name","gh_username"], )
no_issues_only_sample
dataanalyser.writeout_data_to_csv(no_issues_only_sample, "subsample_no_issues_only_data_") 
#no_issues_only_sample

# no initial cluster 1 w/ issues only; cluster 0 only. 
# Removing issues_only leaves 52595 repo-individuals in analysis dataset (ie total 107958 - issues-only 55363).
# Out:
# PosixPath('../../data/analysis_run_sample_45pc_notebook_cluster1_2025-05-13/subsample_no_issues_only_data__2025-05-13.csv')

# %%
analysis_dataset.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
analysis_dataset.groupby("repo_name")["n_of_commit_creators"].mean().max()
# Out:
# 197.0

# %%
sample_repo_stats = pd.read_csv(sample_repo_stats_file, header=0, low_memory=False)
#sample_repo_stats.columns
sample_repo_stats
# Out:
#                   repo_name  initial_HTTP_code  issues_enabled  repo_license  \
# 0              3dct/open_iA                200            True       GPL-3.0
# 1            52North/javaPS                200            True    Apache-2.0
# 2     AAROC/AnsibleBootCamp                200            True    Apache-2.0
# 3         ANNarchy/ANNarchy                200            True       GPL-2.0
# 4    ARUP-CAS/aiscr-webamcr                200            True       GPL-3.0
# ..                      ...                ...             ...           ...
# 695            xsuite/xcoll                200            True    Apache-2.0
# 696            xsuite/xpart                200            True    Apache-2.0
# 697               zfit/zfit                200            True  BSD-3-Clause
# 698           zqfang/GSEApy                200            True  BSD-3-Clause
# 699    zwicker-group/py-pde                200            True           MIT
#
#      repo_visibility  repo_is_fork  devs  \
# 0               True         False    28
# 1               True         False    12
# 2               True         False    21
# 3               True         False    18
# 4               True         False    21
# ..               ...           ...   ...
# 695             True         False    16
# 696             True         False    18
# 697             True         False    29
# 698             True         False    34
# 699             True         False    10
#
#                                          repo_language  \
# 0    ['C++', 'SCSS', 'CMake', 'C', 'Cuda', 'Makefil...
# 1    ['Java', 'Dockerfile', 'CSS', 'HTML', 'JavaScr...
# 2                    ['TeX', 'Jinja', 'Ruby', 'Shell']
# 3                          ['Python', 'C++', 'Cython']
# 4    ['Python', 'JavaScript', 'HTML', 'SCSS', 'Shel...
# ..                                                 ...
# 695                           ['Python', 'C', 'Shell']
# 696                                ['Python', 'Shell']
# 697                                ['Python', 'Shell']
# 698                    ['Python', 'Rust', 'R', 'Apex']
# 699            ['Python', 'Jupyter Notebook', 'Shell']
#
#      total_commits_last_year  has_PRs             last_PR_update  \
# 0                        459     True  2024-06-04 19:16:55+00:00
# 1                          0     True  2023-04-04 17:06:09+00:00
# 2                          0     True  2023-12-18 09:15:04+00:00
# 3                        149     True  2024-10-19 09:52:13+00:00
# 4                       1289     True  2025-04-22 18:08:54+00:00
# ..                       ...      ...                        ...
# 695                      223     True  2025-04-18 13:10:50+00:00
# 696                       72     True  2025-03-27 14:52:45+00:00
# 697                      119     True  2025-04-23 10:39:53+00:00
# 698                       70     True  2025-02-07 18:43:24+00:00
# 699                      109     True  2025-04-10 13:20:53+00:00
#
#      open_tickets  closed_tickets  repo_age_days  n_commits_main_branch
# 0               0               0           3245                   8712
# 1               0               0           3386                    689
# 2               0               0           3466                    230
# 3               0               0           3280                   3658
# 4               0               0           1660                   4455
# ..            ...             ...            ...                    ...
# 695             0               0           1149                   1003
# 696             0               0           1412                    890
# 697             0               0           2594                   3982
# 698             0               0           3398                   1267
# 699             0               0           1893                   1338
#
# [700 rows x 15 columns]

# %%
sample_repo_stats.repo_license.value_counts(dropna=False,normalize=True)*100
# Out:
# repo_license
# MIT                   38.857143
# GPL-3.0               17.285714
# Apache-2.0            15.142857
# BSD-3-Clause          14.714286
# GPL-2.0                3.142857
# AGPL-3.0               2.142857
# BSD-2-Clause           2.000000
# LGPL-3.0               1.857143
# CC-BY-4.0              1.428571
# MPL-2.0                1.000000
# CC0-1.0                0.571429
# ISC                    0.428571
# LGPL-2.1               0.428571
# CC-BY-SA-4.0           0.428571
# BSD-3-Clause-Clear     0.142857
# EPL-1.0                0.142857
# EUPL-1.2               0.142857
# Unlicense              0.142857
# Name: proportion, dtype: float64

# %%
sample_repo_stats.repo_license.nunique()
# Out:
# 18

# %% [markdown]
# ## N Repos

# %%
print(f"There are {analysis_dataset.groupby(['repo_name'], as_index=False).ngroups} repos")
# Out:
# There are 700 repos

# %% [markdown]
# ## N Repo-Individuals

# %%
grouped_by_devs = analysis_dataset.groupby(["gh_username", "repo_name"], as_index=False)
print(f"There are {grouped_by_devs.ngroups} repo-individuals")
# Out:
# There are 700 repo-individuals

# %% [markdown]
# ## N GH-Usernames

# %%
multi_repo_users = analysis_dataset.groupby("gh_username")[["repo_name"]].count().reset_index(names=["gh_username", "count"])
multi_repo_users = multi_repo_users.query("repo_name > 1")
total_gh_users = analysis_dataset.groupby("gh_username").ngroups

print(f"There are {len(multi_repo_users)} gh-usernames which appear in more than one repository within the sample; this represents {round((len(multi_repo_users)/total_gh_users)*100, 2)}% of all {total_gh_users} unique gh-usernames \n")

uptotenrepos = multi_repo_users.query("repo_name <= 10")
tentohundredrepos = multi_repo_users.query("repo_name > 10 and repo_name <= 100")
hundredup = multi_repo_users.query("repo_name > 100")


if len(uptotenrepos) > 1: 
    print(f"There are {len(uptotenrepos)} gh-usernames in between 2 and 10 repos in the sample. \n")

else:
    print("no users in 2+ repos")

if len(tentohundredrepos) > 1: 
    print(f"There are {len(tentohundredrepos)} gh-usernames in between 11 and 100 repos in the sample. \n")
    #print(tentohundredrepos.query("repo_name > 50").sort_values(by="repo_name"))
else: 
    print("no users in 10+ repos")
    
if len(hundredup) > 1: 
    print(f"There are {len(hundredup)} gh-usernames in > 100 repos in the sample. \n")
    print(hundredup.sort_values(by="repo_name"))

else: 
     print("no users in 100+ repos")
# Out:
# There are 37 gh-usernames which appear in more than one repository within the sample; this represents 5.67% of all 653 unique gh-usernames
#
# There are 37 gh-usernames in between 2 and 10 repos in the sample.
#
# no users in 10+ repos
# no users in 100+ repos

# %%
multi_repo_users.repo_name.mean()
# Out:
# 2.27027027027027

# %%
print(tentohundredrepos.query("repo_name > 20").sort_values(by="repo_name")) # how many of these are bots?
# Out:
# Empty DataFrame
# Columns: [gh_username, repo_name]
# Index: []

# %%
print("BOTS: anything ending [bot], anything ending -badger, probably anything ending Bot or -bot")
# Out:
# BOTS: anything ending [bot], anything ending -badger, probably anything ending Bot or -bot

# %%
sns.histplot(data=uptotenrepos, x="repo_name", stat="count", binwidth=1, color="black")
# Out:
# <Axes: xlabel='repo_name', ylabel='Count'>

# %%
#sns.histplot(data=tentohundredrepos, x="repo_name", stat="count", binwidth=1, color="black")

# %%
#sns.histplot(data=hundredup, x="repo_name", stat="count", binwidth=1, color="black")

# %% [markdown]
# # Initial Clustering:

# %%
# N clusters: 
# distribution of repo-individuals amongst cluster labels: 
# distirbution of clusters within repos 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion,

# %%
analysis_dataset.cluster_labels.value_counts()
# Out:
# cluster_labels
# 0    336
# 1    230
# 2    134
# Name: count, dtype: int64

# %%
cl0 = round((analysis_dataset.cluster_labels.value_counts(normalize=True)[0]*100), 2)
cl1 = round((analysis_dataset.cluster_labels.value_counts(normalize=True)[1]*100), 2)
cl2 = round((analysis_dataset.cluster_labels.value_counts(normalize=True)[2]*100), 2)

# how are the users distributed across clusters: what size are the clusters? 
g = sns.countplot(
    data=analysis_dataset, 
    x="cluster_labels", 
    hue="cluster_labels", 
    stat="count", 
    palette=label_color_dict, 
)
#g.tick_params(axis='x', which='both', rotation=70)
g.set_title("Distribution of Repo-Individuals Across Initial Clusters")
g.set_xlabel("Cluster Label")
g.set_ylabel("N of Repo-Individuals")
plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/sample_initial_cluster_distribution_{current_date_info}.png") 
plt.show(g)

# %%
devs_per_cluster = analysis_dataset.groupby(["repo_name", "cluster_labels"])["gh_username"].count().reset_index(name="n_devs")
devs_per_cluster

cl0 = f'{devs_per_cluster.groupby("cluster_labels")["n_devs"].count()[0]} repos'
cl1 = f'{devs_per_cluster.groupby("cluster_labels")["n_devs"].count()[1]} repos'
#cl2 = f'{devs_per_cluster.groupby("cluster_labels")["n_devs"].count()[2]} repos'

labels = [cl0, cl1,]# cl2]

g = sns.barplot(
    data=devs_per_cluster, 
    x="cluster_labels", 
    y="n_devs", 
    hue="cluster_labels",
    estimator="mean", 
    palette=label_color_dict, 
    legend="full",
)
g.set_title("Distribution of Clusters Across Repositories")
g.set_xlabel("Cluster Label")
g.set_ylabel("Mean Number of Repo-Individuals")
h, l = g.get_legend_handles_labels()
g.legend(h, labels, title="Clusters", loc="upper right")

plt.legend(labels, title="Clusters", loc='upper left')
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_cluster_repo_distribution_{current_date_info}.png") 
plt.show(g)
print(f"There are {analysis_dataset.groupby('repo_name').ngroups} unique repositories in this sample")
# Out:
# There are 700 unique repositories in this sample

# %%
clusters_per_repo = devs_per_cluster.groupby("repo_name")["cluster_labels"].nunique().reset_index(name="n_clusters")
clusters_per_repo

clusters_per_repo.n_clusters.mean()

g = sns.countplot(
    data=clusters_per_repo, 
    x="n_clusters",
    color="black"
    #hue="cluster_labels",
    #palette=label_color_dict, 
)
g.set_title("Diversity of Clusters Across Repositories")
g.set_xlabel("Number of Clusters Present")
g.set_ylabel("Number of Repositories with N Clusters")
#h, l = g.get_legend_handles_labels()
#g.legend(h, labels, title="Clusters", loc="upper right")
#plt.legend(labels, title="Clusters", loc='upper right',)
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_n-clusters-present-per-repo_{current_date_info}.png") 
plt.show(g)

# %%
clusters_per_repo.groupby("n_clusters").count()
# Out:
#             repo_name
# n_clusters
# 1                 700

# %% [markdown]
# ## Interaction Types

# %% [markdown]
# ### UIT: number of different types

# %%
# aka. breadth_interactions in df
sum(analysis_dataset.breadth_interactions.isna()) # no missing data in this col
# Out:
# 0

# %%
sns.catplot(data=analysis_dataset, x="breadth_interactions", kind="count", color="black")
# distribution of interaction types per repo-individual

# %%
sns.catplot(data=analysis_dataset, x="breadth_interactions", kind="count", hue="cluster_labels", palette=label_color_dict,  )
# distribution of interaction types per repo-individual by initial cluster

# %%
print(f"Min breadth of interactions by repo-individuals is: {analysis_dataset.breadth_interactions.min()}; and max is: {analysis_dataset.breadth_interactions.max()}.")
print(f"Mode breadth of interactions by repo-individuals is: {analysis_dataset.breadth_interactions.mode()[0]} interaction type.")
# Out:
# Min breadth of interactions by repo-individuals is: 2; and max is: 6.
# Mode breadth of interactions by repo-individuals is: 6 interaction type.

# %%
# how many only single type?
print(f"There are {len(analysis_dataset.query('breadth_interactions == 1'))} repo-individuals with single interaction types")
# which type? (see later)
# Out:
# There are 0 repo-individuals with single interaction types

# %%
# which many show >1 type?
print(f"There are {len(analysis_dataset.query('breadth_interactions > 1'))} repo-individuals with more than one interaction type")
# Out:
# There are 700 repo-individuals with more than one interaction type

# %%
# repo-individ UIT vs their repo mean UITs: TODO

# %%
# per-repo mean UIT value: 
analysis_dataset.groupby(["repo_name"])["breadth_interactions"].mean()
# Out:
# repo_name
# 3dct/open_iA              5.0
# 52North/javaPS            6.0
# AAROC/AnsibleBootCamp     5.0
# ANNarchy/ANNarchy         5.0
# ARUP-CAS/aiscr-webamcr    6.0
#                          ...
# xsuite/xcoll              6.0
# xsuite/xpart              5.0
# zfit/zfit                 6.0
# zqfang/GSEApy             6.0
# zwicker-group/py-pde      6.0
# Name: breadth_interactions, Length: 700, dtype: float64

# %%
# sample mean UIT value:
print(f"The overall sample mean UIT (average number of included interaction interaction types) per repo-individual is {round(analysis_dataset['breadth_interactions'].mean(), 3)}")
# Out:
# The overall sample mean UIT (average number of included interaction interaction types) per repo-individual is 5.524

# %%
(100+100)/6
# Out:
# 33.333333333333336

# %%
print("The mean breadth of interactions per initial cluster labelling are:")
analysis_dataset.groupby(["cluster_labels"])["breadth_interactions"].mean()
# Out:
# The mean breadth of interactions per initial cluster labelling are:
# cluster_labels
# 0    5.431548
# 1    5.878261
# 2    5.149254
# Name: breadth_interactions, dtype: float64

# %%
# how are the users distributed across clusters: what size are the clusters? 
g = sns.countplot(
    data=analysis_dataset, 
    x="breadth_interactions", 
    hue="cluster_labels", 
    stat="count", 
    palette=label_color_dict, 
)
#g.tick_params(axis='x', which='both', rotation=70)
g.set_title("Distribution of Repo-Individuals by UIT")
g.set_xlabel("N of Unique Interaction Types (UIT)")
plt.legend(title="Clusters", loc='upper right',) #labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_commit_created",
    hue="cluster_labels", 
    #binwidth=1,
    estimator="mean",
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Commit Creation")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' Commits")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_RC-commit_creation_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# Issue creation
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_issue_created",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster 1:{col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Issue Ticket Creation")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' Issues Created")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_RC-issue_creation_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# Issue closure
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_issue_closed",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Issue Ticket Closing")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' Issues Closed")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_RC-issue_closure_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# Issue assignment
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_issues_assigned_of_assigned",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("Mean Percentage Contribution Depth of Issue Ticket Assignment")
g.set_ylabels("% of Repos' Issues Assigned")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_breadth_depth_pc_issue_assignment_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# PRs
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_pull_request_created",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Pull Request Creation")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' PRs")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_RC-PRs_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %%
# PRs
# how are the users distributed across clusters: what size are the clusters? 
g = sns.FacetGrid(data=analysis_dataset, sharey=True, col="cluster_labels",)
g.map_dataframe(sns.barplot,
    x="breadth_interactions", 
    y="pc_pull_request_closed",
    hue="cluster_labels", 
    #binwidth=1,
    #stat="count", 
    palette=label_color_dict, 
)
g.set_axis_labels("")
g.set_titles("Cluster 1: {col_name}")
g.figure.subplots_adjust(top=0.80)
g.figure.suptitle("% Repository Contribution: Pull Request Closure")
g.set_xlabels("UIT")
g.set_ylabels("% of Repos' PRs")
#g.set_xlabels("Percentage Contribution Depth (% of repo commits)")
#plt.legend(title="Clusters", loc='upper right', labels=[f"{cl0}%", f"{cl1}%", f"{cl2}%"])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_RC-PRs_closed_UIT_distribution_{current_date_info}.png") 
plt.show(g)

# %% [markdown]
# ### Combinations of Types:

# %%
sum(analysis_dataset.which_interactions.isna()) # no missing data
# Out:
# 0

# %%
from githubanalysis.visualization.plot_repoindividual_upset_plot import UpsetPlotter

upsetplotter = UpsetPlotter(
    in_notebook=True,
    logger=None, 
)

# %%
print("{Plotting single combined sample UpSet Plot")
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=analysis_dataset,
    sort_combos_by="cardinality",
    file_name="sample_upset_plot_45pc_cluster1_all",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot without separating by clusters
# INFO:data is df, with shape: (700, 86).
# INFO:Attempting to plot cluster whole_dataset using colour black.
# {Plotting single combined sample UpSet Plot
# INFO:Plot saved out to file ../../images/sample_upset_plot_45pc_cluster1_all_whole_dataset_2025-05-13.pdf.
# INFO:Completed UpSet plotting.

# %%
print("Plotting separate clusters into UpSet Plot: this doesn't currently work in the script")

tmp0 = analysis_dataset.query("cluster_labels == 0")
tmp1 = analysis_dataset.query("cluster_labels == 1")
tmp2 = analysis_dataset.query("cluster_labels == 2")
# Out:
# Plotting separate clusters into UpSet Plot: this doesn't currently work in the script

# %%
# plot cluster 0
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp0,
    sort_combos_by="cardinality",
    file_name="sample_upset_plot_45pc_cluster1_cluster0_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot without separating by clusters
# INFO:data is df, with shape: (336, 86).
# INFO:Attempting to plot cluster whole_dataset using colour black.
# INFO:Plot saved out to file ../../images/sample_upset_plot_45pc_cluster1_cluster0__whole_dataset_2025-05-13.pdf.
# INFO:Completed UpSet plotting.

# %%
# plot cluster 1
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    sort_combos_by="cardinality",
    file_name="sample_upset_plot_45pc_cluster1_cluster1_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot without separating by clusters
# INFO:data is df, with shape: (230, 86).
# INFO:Attempting to plot cluster whole_dataset using colour black.
# INFO:Plot saved out to file ../../images/sample_upset_plot_45pc_cluster1_cluster1__whole_dataset_2025-05-13.pdf.
# INFO:Completed UpSet plotting.

# %%
# plot cluster 1
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp2,
    sort_combos_by="cardinality",
    file_name="sample_upset_plot_45pc_cluster1_cluster2_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot without separating by clusters
# INFO:data is df, with shape: (134, 86).
# INFO:Attempting to plot cluster whole_dataset using colour black.
# INFO:Plot saved out to file ../../images/sample_upset_plot_45pc_cluster1_cluster2__whole_dataset_2025-05-13.pdf.
# INFO:Completed UpSet plotting.

# %%
analysis_dataset.cluster_labels.value_counts(normalize=True)
# Out:
# cluster_labels
# 0    0.480000
# 1    0.328571
# 2    0.191429
# Name: proportion, dtype: float64

# %% [markdown]
# ## MRC:

# %%
# pc_DC (percentage DEPTH of contribution across all of users' interactions)

g = sns.catplot(
    data=analysis_dataset, 
    x="cluster_labels", 
    y="pc_DC",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict, 
    legend = False,
)
#g.tick_params(axis='x', which='both', rotation=70)
#g.axes.legend().set_title("")
#g.add_legend(title="Clusters", loc='upper right',) #labels=['0', '1', '2']))
g.fig.subplots_adjust(top=0.9) # adjust the Figure in rp
g.fig.suptitle("Mean Repository Contributions by Repo-Individuals")
g.axes[0,0].set_xlabel('Cluster Label')
g.axes[0,0].set_ylabel('% Mean Repository Contribution')
plt.tight_layout()
#.axes.set_le
#plt.legend(title="Clusters", loc='upper left',) #labels=['0', '1', '2'])
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_sample_mrc_cluster_{current_date_info}.png") 
plt.show(g)

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_closed"].describe()
# Out:
#                 count       mean        std        min        25%        50%  \
# cluster_labels
# 0               336.0  71.644907  23.685420   0.000000  58.251536  76.468927
# 1               230.0  86.237526  12.703106  43.333333  77.166434  90.499517
# 2               134.0  84.133111  12.451168  52.688172  76.531023  87.300655
#
#                       75%    max
# cluster_labels
# 0               91.482762  100.0
# 1               96.561942  100.0
# 2               94.194934  100.0

# %%
analysis_dataset.groupby("cluster_labels")["breadth_interactions"].describe()
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# cluster_labels
# 0               336.0  5.431548  0.753946  2.0  5.0  6.0  6.0  6.0
# 1               230.0  5.878261  0.340763  4.0  6.0  6.0  6.0  6.0
# 2               134.0  5.149254  0.808856  3.0  5.0  5.0  6.0  6.0

# %%
84.13-11.93 # 1:2
# Out:
# 72.19999999999999

# %%
74.85 -32.88 # 1:0
# Out:
# 41.96999999999999

# %%
86.24 - 50.92 # 1:1
# Out:
# 35.31999999999999

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="breadth_interactions", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)

hatches = ["//", "..", "x"]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#FFFFFF")
    patch.set_facecolor('#1D2A3D')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#FFFFFF")
    lp.set_facecolor('#1D2A3D')

ax.set_title("Cluster 1: UIT by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% Mean UIT")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_UIT_{current_date_info}.pdf")

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_created-closed_issues", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)

hatches = ["//", "..", "x"]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#FFFFFF")
    patch.set_facecolor('#1D2A3D')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#FFFFFF")
    lp.set_facecolor('#1D2A3D')

ax.set_title("Cluster 1: RC Created-Closed Issues by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% Mean RC: Created-Closed Issues")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_created-closed-issues_{current_date_info}.pdf")

# %%
analysis_dataset.groupby("cluster_labels")["pc_created-closed_issues"].describe()
# Out:
#                 count       mean        std    min        25%        50%  \
# cluster_labels
# 0               336.0 -74.444781  14.298466 -100.0 -84.964636 -73.649198
# 1               230.0 -82.074829  13.336205 -100.0 -92.811480 -84.341863
# 2               134.0 -72.515360  14.084017 -100.0 -82.411803 -73.642071
#
#                       75%        max
# cluster_labels
# 0              -64.530799 -26.696162
# 1              -74.423615 -40.912232
# 2              -62.695690 -26.222222

# %%
import textwrap
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=0)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from textwrap import wrap

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_issues_assigned_of_assigned", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",
    dodge=False,
)
hatches = ["//", "..", "x"]
# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#FFFFFF")
    patch.set_facecolor('#1D2A3D')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#FFFFFF")
    lp.set_facecolor('#1D2A3D')

ax.set_title("High Interactivity Grouping: RC Issue Assignment")
ax.set_xlabel("RSE Persona (Sub-Cluster)")
ax.set_ylabel("% Mean RC: Assigned Issues")
ax.set_xticklabels(['Low-Coding Closer (1:0)', 'Active Contributor (1:1)', 'Low-Process Closer (1:2)'])


wrap_labels(ax, 20)
ax.figure


plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_assigned_{current_date_info}.pdf", bbox_inches="tight") 
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_assigned_{current_date_info}.png", bbox_inches="tight")

# %%
analysis_dataset.groupby("cluster_labels")["pc_issues_assigned_of_assigned"].describe()
# Out:
#                 count       mean        std  min        25%        50%  \
# cluster_labels
# 0               336.0  65.480128  31.271004  0.0  44.841270  68.354701
# 1               230.0  77.093274  27.199734  0.0  60.470085  87.356681
# 2               134.0  11.931279  17.443418  0.0   0.000000   0.000000
#
#                        75%    max
# cluster_labels
# 0                98.875988  100.0
# 1               100.000000  100.0
# 2                27.678571   65.0

# %%
analysis_dataset.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_commit_created", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",
    dodge=False,
)

hatches = ["//", "..", "x"]

# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#FFFFFF")
    patch.set_facecolor('#1D2A3D')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#FFFFFF")
    lp.set_facecolor('#1D2A3D')

ax.set_title("High Interactivity Grouping: RC Commit Created")
ax.set_ylabel("% Mean RC: Commits Created")
ax.set_xlabel("RSE Persona (Sub-Cluster)")
ax.set_xticklabels(['Low-Coding Closer (1:0)', 'Active Contributor (1:1)', 'Low-Process Closer (1:2)'])


wrap_labels(ax, 20)
ax.figure

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_commit-created_{current_date_info}.pdf", bbox_inches="tight")  
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_commit-created_{current_date_info}.png", bbox_inches="tight")

# %%
analysis_dataset.groupby("cluster_labels")["pc_commit_created"].describe()
# Out:
#                 count       mean        std        min        25%        50%  \
# cluster_labels
# 0               336.0  32.876974  29.942826   0.000000   0.000000  35.025103
# 1               230.0  83.187279  11.615991  49.914763  75.350245  85.668370
# 2               134.0  74.945404  16.128712  33.333333  63.769328  77.444875
#
#                       75%        max
# cluster_labels
# 0               56.013678  95.986038
# 1               92.853165  99.675588
# 2               88.440687  98.754063

# %%
analysis_dataset.groupby("cluster_labels")["pc_issue_created"].describe()
# Out:
#                 count       mean        std  min        25%        50%  \
# cluster_labels
# 0               336.0  40.469839  26.874005  0.0  15.598060  41.241513
# 1               230.0  51.722466  26.039592  0.0  32.106481  53.981900
# 2               134.0  16.119713  13.411334  0.0   4.298500  14.784457
#
#                       75%         max
# cluster_labels
# 0               59.521086  100.000000
# 1               71.567014  100.000000
# 2               24.719129   52.380952

# %%
analysis_dataset.groupby("cluster_labels")["pc_issue_closed"].describe()
# Out:
#                 count       mean        std        min        25%        50%  \
# cluster_labels
# 0               336.0  74.849480  14.375381  26.785714  64.782256  74.053612
# 1               230.0  82.592054  13.469162  41.267788  75.000000  84.712519
# 2               134.0  72.676557  14.105102  26.262626  62.830340  73.804348
#
#                       75%    max
# cluster_labels
# 0               85.663021  100.0
# 1               93.478261  100.0
# 2               82.750397  100.0

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_created"].describe()
# Out:
#                 count       mean        std  min        25%        50%  \
# cluster_labels
# 0               336.0  36.744507  22.837109  0.0  19.776507  35.626551
# 1               230.0  50.924988  26.891091  0.0  32.576158  53.086957
# 2               134.0  37.036725  21.868953  0.0  24.448420  40.000000
#
#                       75%         max
# cluster_labels
# 0               50.084459  100.000000
# 1               71.313364   99.397590
# 2               51.998082   84.688995

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_closed"].describe()
# Out:
#                 count       mean        std        min        25%        50%  \
# cluster_labels
# 0               336.0  71.644907  23.685420   0.000000  58.251536  76.468927
# 1               230.0  86.237526  12.703106  43.333333  77.166434  90.499517
# 2               134.0  84.133111  12.451168  52.688172  76.531023  87.300655
#
#                       75%    max
# cluster_labels
# 0               91.482762  100.0
# 1               96.561942  100.0
# 2               94.194934  100.0

# %%
analysis_dataset.groupby("cluster_labels")["pc_issues_assigned_of_assigned"].describe()
# Out:
#                 count       mean        std  min        25%        50%  \
# cluster_labels
# 0               336.0  65.480128  31.271004  0.0  44.841270  68.354701
# 1               230.0  77.093274  27.199734  0.0  60.470085  87.356681
# 2               134.0  11.931279  17.443418  0.0   0.000000   0.000000
#
#                        75%    max
# cluster_labels
# 0                98.875988  100.0
# 1               100.000000  100.0
# 2                27.678571   65.0

# %%
analysis_dataset.groupby("cluster_labels")["pc_DC"].describe()
# Out:
#                 count       mean        std        min        25%        50%  \
# cluster_labels
# 0               336.0  50.084185   8.643870  26.956543  43.626150  49.767023
# 1               230.0  69.104012  10.005621  44.470633  61.496624  69.230603
# 2               134.0  42.541936   8.295399  26.354839  36.680321  41.613035
#
#                       75%        max
# cluster_labels
# 0               55.614979  79.568118
# 1               75.395184  94.550828
# 2               48.757881  60.261501

# %%
analysis_dataset.groupby("cluster_labels")["pc_created-closed_issues"].mean()
# Out:
# cluster_labels
# 0   -74.444781
# 1   -82.074829
# 2   -72.515360
# Name: pc_created-closed_issues, dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["pc_pull_request_created"].mean() - analysis_dataset.groupby("cluster_labels")["pc_pull_request_closed"].mean()
# Out:
# cluster_labels
# 0   -34.900400
# 1   -35.312538
# 2   -47.096386
# dtype: float64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_issue_created", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)

# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#FFFFFF")
    patch.set_facecolor('#1D2A3D')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#FFFFFF")
    lp.set_facecolor('#1D2A3D')

ax.set_title("Cluster 1: RC Issues Created by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% Mean RC: Issues Created")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_issues-created_{current_date_info}.pdf")

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="pc_DC", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)

# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#FFFFFF")
    patch.set_facecolor('#1D2A3D')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#FFFFFF")
    lp.set_facecolor('#1D2A3D')

ax.set_title("Cluster 1: MRC by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("% MRC")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_MRC_{current_date_info}.pdf")

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.boxplot(
    data=analysis_dataset,
    y="breadth_interactions", 
    x="cluster_labels",
    hue="cluster_labels", 
    palette="dark:white",

)

# select the correct patches
patches = [patch for patch in ax.patches if type(patch) == mpl.patches.PathPatch]
# the number of patches should be evenly divisible by the number of hatches
h = hatches * (len(patches) // len(hatches))
# iterate through the patches for each subplot
for patch, hatch in zip(patches, h):
    patch.set_hatch(hatch)
    fc = patch.get_facecolor()
    patch.set_edgecolor("#FFFFFF")
    patch.set_facecolor('#1D2A3D')

l = ax.legend()

for lp, hatch in zip(l.get_patches(), hatches):
    lp.set_hatch(hatch)
    fc = lp.get_facecolor()
    lp.set_edgecolor("#FFFFFF")
    lp.set_facecolor('#1D2A3D')

ax.set_title("Cluster 1: UIT by Sub-Cluster")
ax.set_xlabel("Sub-Cluster Label")
ax.set_ylabel("UIT")

plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_boxplot_UIT_{current_date_info}.pdf")

# %%
analysis_dataset.groupby("cluster_labels")["breadth_interactions"].mean()
# Out:
# cluster_labels
# 0    5.431548
# 1    5.878261
# 2    5.149254
# Name: breadth_interactions, dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["breadth_interactions"].std()
# Out:
# cluster_labels
# 0    0.753946
# 1    0.340763
# 2    0.808856
# Name: breadth_interactions, dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["pc_DC"].mean()
# Out:
# cluster_labels
# 0    50.084185
# 1    69.104012
# 2    42.541936
# Name: pc_DC, dtype: float64

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
g = sns.boxplot(data=analysis_dataset,
    x="breadth_interactions", 
    y="pc_DC",
    hue="cluster_labels", 
    palette = label_color_dict)
g.set_title("% Mean Repository Contribution by Unique Interaction Types")
g.set_xlabel("UIT")
g.set_ylabel("% Mean Repository Contributions")
plt.legend(title="Clusters", loc='upper left',)# labels=[0,1,2])
plt.tight_layout()
plt.savefig(f"../../images/analysis_run_sample_45pc_cluster1_2025-05-13/45pc_cluster1_uit_mrc_cluster_{current_date_info}.png") 
plt.show(g)

# %%
analysis_dataset.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
sklearn_hcwdata = analysis_dataset

# %% [markdown]
# ### how does pc_DC vary between clusters?

# %%
sklearn_hcwdata.pc_DC.describe()
# Out:
# count    700.000000
# mean      54.889755
# std       13.729899
# min       26.354839
# 25%       44.457091
# 50%       53.548565
# 75%       63.588146
# max       94.550828
# Name: pc_DC, dtype: float64

# %%
sns.boxplot(data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_DC",
    hue="cluster_labels", palette=label_color_dict)
print("pc_DC across each cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_DC"]].mean()
# Out:
# pc_DC across each cluster
#                     pc_DC
# cluster_labels
# 0               50.084185
# 1               69.104012
# 2               42.541936

# %%
sklearn_hcwdata.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    y="pc_DC",
    hue="cluster_labels", 
    palette = label_color_dict)
print("pc_DC across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["pc_DC"]].mean()
# Out:
# pc_DC across breadth_interactions by Cluster
#                                          pc_DC
# breadth_interactions cluster_labels
# 2                    0               39.937759
# 3                    0               37.278245
#                      2               31.057795
# 4                    0               40.219724
#                      1               55.361709
#                      2               35.706847
# 5                    0               48.354071
#                      1               62.026074
#                      2               41.378974
# 6                    0               52.756832
#                      1               70.078242
#                      2               47.778968

# %%
# pc_DC (percentage DEPTH of contribution across all of users' interactions)

g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_DC",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict 
)
g.tick_params(axis='x', which='both', rotation=70)
print("mean pc_DC across each clusters")

sklearn_hcwdata.groupby("cluster_labels")[["pc_DC"]].mean()
# Out:
# mean pc_DC across each clusters
#                     pc_DC
# cluster_labels
# 0               50.084185
# 1               69.104012
# 2               42.541936

# %%
sns.boxplot(data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_commit_created",
    hue="cluster_labels", palette=label_color_dict)
print("pc_DC across each cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_DC"]].mean()
# Out:
# pc_DC across each cluster
#                     pc_DC
# cluster_labels
# 0               50.084185
# 1               69.104012
# 2               42.541936

# %%
# # cluster 1 has highest pc of repo's commits values, 0 is minimal. 
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_commit_created",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's commits")
sklearn_hcwdata.groupby("cluster_labels")[["pc_commit_created"]].mean()
# Out:
# cluster x % of repo's commits
#                 pc_commit_created
# cluster_labels
# 0                       32.876974
# 1                       83.187279
# 2                       74.945404

# %% [markdown]
# #### pc_commit_created: \~59% more of repos' commits by cluster 1 (\~62%) vs Cluster 0 (~3%)

# %%
# # cluster 1 has highest pc of repo's issue ticket creation  values, 0 is minimal
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_issue_created",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's issues created")
sklearn_hcwdata.groupby("cluster_labels")[["pc_issue_created"]].mean()
# Out:
# cluster x % of repo's issues created
#                 pc_issue_created
# cluster_labels
# 0                      40.469839
# 1                      51.722466
# 2                      16.119713

# %%
# # cluster 1 has highest pc of repo's issue ticket creation  values, 0 is minimal
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_issue_closed",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict, 
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's issues closed")
sklearn_hcwdata.groupby("cluster_labels")[["pc_issue_closed"]].mean()
# Out:
# cluster x % of repo's issues closed
#                 pc_issue_closed
# cluster_labels
# 0                     74.849480
# 1                     82.592054
# 2                     72.676557

# %%
# assignment pcs
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_issues_assigned_of_assigned",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's issues assigned to user")
sklearn_hcwdata.groupby("cluster_labels")[["pc_issues_assigned_of_assigned"]].mean()
# Out:
# cluster x % of repo's issues assigned to user
#                 pc_issues_assigned_of_assigned
# cluster_labels
# 0                                    65.480128
# 1                                    77.093274
# 2                                    11.931279

# %%
# assignment pcs
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_pull_request_created",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
    #rder=ordered_contributions_by_user_categories
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster x % of repo's pull requests created by user")
sklearn_hcwdata.groupby("cluster_labels")[["pc_pull_request_created"]].mean()
# Out:
# cluster x % of repo's pull requests created by user
#                 pc_pull_request_created
# cluster_labels
# 0                             36.744507
# 1                             50.924988
# 2                             37.036725

# %% [markdown]
# #### Number of repo committers: `n_of_commit_creators`

# %%
sklearn_hcwdata.groupby("cluster_labels")['repo_name'].nunique() # how many repos fall into each category?
# Out:
# cluster_labels
# 0    336
# 1    230
# 2    134
# Name: repo_name, dtype: int64

# %%
# THIS IS A REALLY HACKY WAY OF PLOTTING THE ACTUAL MEAN APPX REPO SIZES. 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} 
approx_repo_sizes = pd.DataFrame({
    "cluster_labels": [0, 1, 2], 
    "mean_n_of_commit_creators": [sklearn_hcwdata.query("cluster_labels == 0").groupby("repo_name")[["n_of_commit_creators"]].mean().mean().item() , sklearn_hcwdata.query("cluster_labels == 1").groupby("repo_name")[["n_of_commit_creators"]].mean().mean().item(), sklearn_hcwdata.query("cluster_labels == 2").groupby("repo_name")[["n_of_commit_creators"]].mean().mean().item() ]
})

#sklearn_hcwdata.query("cluster_labels == 1").groupby("repo_name")[["n_of_commit_creators"]].mean().mean()
  # double .mean() gets first the mean of all n_of_commit_creators per repo_name 
    # (which is legit, since it's the same for each dev inside it) 
  # THEN it gets the mean of THOSE MEANS (ie for the cluster group)
  # THEN .item gets the value afterwards 

g = sns.catplot(
    data=approx_repo_sizes, 
    x="cluster_labels", 
    y="mean_n_of_commit_creators",
    hue="cluster_labels", 
    kind="bar", 
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("cluster labels x mean number of repo commit creators")
print(approx_repo_sizes)
# Out:
# cluster labels x mean number of repo commit creators
#    cluster_labels  mean_n_of_commit_creators
# 0               0                  23.411215
# 1               1                  13.647826
# 2               2                  21.925373

# %%
# users from different sizes of n_of_commit_creators counts, shown with cluster labels  
ax = sns.histplot(
    data=sklearn_hcwdata, 
    x="n_of_commit_creators", 
    #y="cluster_labels",
    hue="cluster_labels", 
    binwidth=5,
    #alpha=1, 
    multiple="stack", 
    palette=label_color_dict,
)
#ax.tick_params(axis='x', which='both', rotation=90)
print("Users from different sizes of n_of_commit_creators counts, shown with cluster labels  ")
# spread of cluster 1 repo 'appx sizes' is much lower, but sample is TINY comparatively
# Out:
# Users from different sizes of n_of_commit_creators counts, shown with cluster labels

# %%
# Counts of users in repos of varying sizes + cluster label distributions
ax = sns.displot(
    data=sklearn_hcwdata, 
    #x="repo_name", 
    x="n_of_commit_creators",
    col="cluster_labels",
    hue="cluster_labels", 
    binwidth=5,
    alpha=1, 
    palette=label_color_dict,
    #multiple="stack", 
    #kde="true"
)
ax.tick_params(axis='x', which='both', rotation=90)
print("Counts of users in repos of varying sizes + cluster label distributions")
# Out:
# Counts of users in repos of varying sizes + cluster label distributions

# %% [markdown]
# ### CBRIs across clusters
#
# How are project-individuals with different CBRI values spread across the clusters?

# %%
g = sns.countplot(
    data=sklearn_hcwdata, 
    x="breadth_interactions", 
    hue="cluster_labels", 
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("count of breadth_interactions across 'clusters'")

sklearn_hcwdata.groupby(["cluster_labels", "breadth_interactions"])[["breadth_interactions"]].count()
# Out:
# count of breadth_interactions across 'clusters'
#                                      breadth_interactions
# cluster_labels breadth_interactions
# 0              2                                        4
#                3                                        4
#                4                                       18
#                5                                      127
#                6                                      183
# 1              4                                        1
#                5                                       26
#                6                                      203
# 2              3                                        8
#                4                                       11
#                5                                       68
#                6                                       47

# %%
sklearn_hcwdata.cluster_labels.value_counts()
# Out:
# cluster_labels
# 0    336
# 1    230
# 2    134
# Name: count, dtype: int64

# %% [markdown]
# ### Contribution-Type-Combos (contributions_by_user)

# %% [markdown]
# ### Commit Classification Variations (HL- and V-)

# %% [markdown]
# #### HL-MANAGEMENT

# %%
# Percentage of user's commits which categorised as HL commit content category MANAGEMENT
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-mgmt",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL commit content category MANAGEMENT by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-mgmt"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL commit content category MANAGEMENT by cluster
#                 pc_HL-mgmt
# cluster_labels
# 0                26.165005
# 1                20.603909
# 2                20.537962

# %% [markdown]
# #### V-DOCS

# %%
# Percentage of user's commits which categorised as V commit filetype category DOCS
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_V-doc",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as V-cat Docs by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_V-doc"]].mean()
# Out:
# # Percentage of user's commits which categorised as V-cat Docs by cluster
#                  pc_V-doc
# cluster_labels
# 0               28.207550
# 1               22.478296
# 2               24.382724

# %% [markdown]
# #### HL-FORWARD-ENGINEERING

# %%
# Percentage of user's commits which categorised as HL commit content category FORWARD ENGINEERING
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-fweng",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL-FWENG (Forward Engineering) by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-fweng"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL-FWENG (Forward Engineering) by cluster
#                 pc_HL-fweng
# cluster_labels
# 0                 13.174598
# 1                 15.241799
# 2                 14.124288

# %% [markdown]
# #### V-CODE

# %%
# Percentage of user's commits which categorised as V commit filetype category CODE
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_V-code",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as V-cat CODE by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_V-code"]].mean()
# Out:
# # Percentage of user's commits which categorised as V-cat CODE by cluster
#                 pc_V-code
# cluster_labels
# 0               62.165051
# 1               68.293424
# 2               64.292768

# %% [markdown]
# #### HL-RE-ENGINEERING

# %%
# Percentage of user's commits which categorised as HL commit content category RE-ENGINEERING
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-reeng",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL-RE-ENG (Re-Engineering) by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-reeng"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL-RE-ENG (Re-Engineering) by cluster
#                 pc_HL-reeng
# cluster_labels
# 0                 27.254570
# 1                 25.486629
# 2                 27.853289

# %% [markdown]
# #### HL-CORRECTIVE-ENGINEERING

# %%
# Percentage of user's commits which categorised as HL commit content category CORRECTIVE-ENGINEERING
g = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HL-corr",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
g.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HL-CORR (Corrective-Engineering) by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HL-corr"]].mean()
# Out:
# # Percentage of user's commits which categorised as HL-CORR (Corrective-Engineering) by cluster
#                 pc_HL-corr
# cluster_labels
# 0                12.413151
# 1                14.338577
# 2                13.428867

# %% [markdown]
# ### HLs-cats

# %% [markdown]
# ### HL-Cats

# %%
sklearn_hcwdata.groupby("cluster_labels")[['pc_HL-fweng', 'pc_HL-reeng', 'pc_HL-corr','pc_HL-mgmt']].mean()
# Out:
#                 pc_HL-fweng  pc_HL-reeng  pc_HL-corr  pc_HL-mgmt
# cluster_labels
# 0                 13.174598    27.254570   12.413151   26.165005
# 1                 15.241799    25.486629   14.338577   20.603909
# 2                 14.124288    27.853289   13.428867   20.537962

# %% [markdown]
# ### V-Cats

# %%
sklearn_hcwdata.groupby("cluster_labels")[['pc_V-code','pc_V-doc', 'pc_V-dvdoc', 'pc_V-confg', 'pc_V-build','pc_V-test']].mean()
# Out:
#                 pc_V-code   pc_V-doc  pc_V-dvdoc  pc_V-confg  pc_V-build  \
# cluster_labels
# 0               62.165051  28.207550    0.613358    1.179108    0.878011
# 1               68.293424  22.478296    0.248642    1.417130    0.590498
# 2               64.292768  24.382724    0.525281    0.128113    1.110364
#
#                 pc_V-test
# cluster_labels
# 0                0.460003
# 1                0.598267
# 2                1.079969

# %% [markdown]
# ### Commit Size (more about depth)

# %% [markdown]
# #### Raw n_commits:

# %%
sklearn_hcwdata.groupby("cluster_labels")[["pc_n_commits"]].mean()
# Out:
#                 pc_n_commits
# cluster_labels
# 0                   0.084031
# 1                   0.213438
# 2                   0.169215

# %%
sklearn_hcwdata.groupby("cluster_labels")[["pc_n_commits"]].describe() 
# pc_n_commits didn't need to be scaled for this clustering, and represents the average of users' contributions the repo, so this seems more likely to be legit?
# Out:
#                pc_n_commits                                                    \
#                       count      mean       std       min       25%       50%
# cluster_labels
# 0                     336.0  0.084031  0.171742  0.000000  0.000000  0.020920
# 1                     230.0  0.213438  0.213649  0.006380  0.067099  0.139391
# 2                     134.0  0.169215  0.240630  0.009496  0.047849  0.093694
#
#
#                      75%       max
# cluster_labels
# 0               0.089985  1.522251
# 1               0.296587  1.257266
# 2               0.178709  1.555930

# %% [markdown]
# #### Commit Size: HLs-

# %%
sklearn_hcwdata.groupby("cluster_labels")[['pc_HLs-tiny', 'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg']].mean()
# Out:
#                 pc_HLs-tiny  pc_HLs-sml  pc_HLs-med  pc_HLs-lrg
# cluster_labels
# 0                 82.846754   13.475432    2.995912    0.681903
# 1                 84.308443   12.430127    2.581164    0.680266
# 2                 83.560472   13.328987    2.619782    0.490759

# %%
# Percentage of user's commits which categorised as HL commit size category TINY
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-tiny",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-TINY commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-tiny"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-TINY commit size by cluster
#                 pc_HLs-tiny
# cluster_labels
# 0                 82.846754
# 1                 84.308443
# 2                 83.560472

# %%
# Percentage of user's commits which categorised as HL commit size category SMALL
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-sml",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-SMALL commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-sml"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-SMALL commit size by cluster
#                 pc_HLs-sml
# cluster_labels
# 0                13.475432
# 1                12.430127
# 2                13.328987

# %%
# Percentage of user's commits which categorised as HL commit size category MEDIUM
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-med",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-MEDIUM commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-med"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-MEDIUM commit size by cluster
#                 pc_HLs-med
# cluster_labels
# 0                 2.995912
# 1                 2.581164
# 2                 2.619782

# %%
# Percentage of user's commits which categorised as HL commit size category LARGE
ax = sns.catplot(
    data=sklearn_hcwdata, 
    x="cluster_labels", 
    y="pc_HLs-lrg",
    hue="cluster_labels", 
    kind="bar", 
    estimator="mean",
    palette=label_color_dict,
)
ax.tick_params(axis='x', which='both', rotation=70)
print("# Percentage of user's commits which categorised as HLs-LARGE commit size by cluster")
sklearn_hcwdata.groupby("cluster_labels")[["pc_HLs-lrg"]].mean()
# Out:
# # Percentage of user's commits which categorised as HLs-LARGE commit size by cluster
#                 pc_HLs-lrg
# cluster_labels
# 0                 0.681903
# 1                 0.680266
# 2                 0.490759

# %% [markdown]
# ### (Raw) Number of Commits: `n_commits`: depth (commits)

# %% [markdown]
# #### Number of Commits: n_commits

# %% [markdown]
# ### DEPTH

# %%
sklearn_hcwdata.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="mean_n_interactions_per_interaction_day",
    hue="cluster_labels", 
    palette = label_color_dict)
print("mean_n_interactions_per_interaction_day across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean()
# Out:
# mean_n_interactions_per_interaction_day across breadth_interactions by Cluster
#                                      mean_n_interactions_per_interaction_day
# breadth_interactions cluster_labels
# 2                    0                                            132.250000
# 3                    0                                              2.272472
#                      2                                              4.294610
# 4                    0                                              2.783703
#                      1                                              4.868852
#                      2                                              4.652749
# 5                    0                                              2.792704
#                      1                                              4.268245
#                      2                                              3.923022
# 6                    0                                              4.299926
#                      1                                              5.038808
#                      2                                              4.829011
#                 mean_n_interactions_per_interaction_day
# cluster_labels
# 0                                              5.148085
# 1                                              4.950962
# 2                                              4.322882

# %% [markdown]
# ## TIME

# %%
# interaction_days

# %% [markdown]
# #### mean_n_interactions_per_interaction_day: significantly different by breadth, cluster

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="mean_n_interactions_per_interaction_day",
    hue="cluster_labels", 
    palette = label_color_dict)
print("mean_n_interactions_per_interaction_day across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean()
# Out:
# mean_n_interactions_per_interaction_day across breadth_interactions by Cluster
#                                      mean_n_interactions_per_interaction_day
# breadth_interactions cluster_labels
# 2                    0                                            132.250000
# 3                    0                                              2.272472
#                      2                                              4.294610
# 4                    0                                              2.783703
#                      1                                              4.868852
#                      2                                              4.652749
# 5                    0                                              2.792704
#                      1                                              4.268245
#                      2                                              3.923022
# 6                    0                                              4.299926
#                      1                                              5.038808
#                      2                                              4.829011
#                 mean_n_interactions_per_interaction_day
# cluster_labels
# 0                                              5.148085
# 1                                              4.950962
# 2                                              4.322882

# %%
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    #x="breadth_interactions", 
    x="cluster_labels",
    y="mean_n_interactions_per_interaction_day",
    hue="cluster_labels", 
    palette = label_color_dict)
print("mean_n_interactions_per_interaction_day by Cluster")
#print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["mean_n_interactions_per_interaction_day"]].mean()
# Out:
# mean_n_interactions_per_interaction_day by Cluster
#                 mean_n_interactions_per_interaction_day
# cluster_labels
# 0                                              5.148085
# 1                                              4.950962
# 2                                              4.322882

# %% [markdown]
# #### interaction_days:

# %%
# interaction days
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("interaction_days across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["interaction_days"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_days"]].mean()
# Out:
# interaction_days across breadth_interactions by Cluster
#                                      interaction_days
# breadth_interactions cluster_labels
# 2                    0                       3.250000
# 3                    0                      71.750000
#                      2                     195.875000
# 4                    0                     131.777778
#                      1                     183.000000
#                      2                     241.181818
# 5                    0                     235.889764
#                      1                     356.153846
#                      2                     335.147059
# 6                    0                     347.459016
#                      1                     403.497537
#                      2                     416.680851
#                 interaction_days
# cluster_labels
# 0                     286.354167
# 1                     397.186957
# 2                     347.716418

# %%
# interaction days
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("N interaction_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_days"]].mean()
# Out:
# N interaction_days across breadth_interactions by Cluster
#                 interaction_days
# cluster_labels
# 0                     286.354167
# 1                     397.186957
# 2                     347.716418

# %% [markdown]
# #### interaction_period_days:

# %%
# interaction period
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata,
    x="breadth_interactions", 
    #x="cluster_labels",
    y="interaction_period_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("N interaction_period_days across breadth_interactions by Cluster")
print(sklearn_hcwdata.groupby(["breadth_interactions", "cluster_labels"])[["interaction_period_days"]].mean())
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_period_days"]].mean()
# Out:
# N interaction_period_days across breadth_interactions by Cluster
#                                      interaction_period_days
# breadth_interactions cluster_labels
# 2                    0                            102.750000
# 3                    0                           1583.250000
#                      2                           1970.250000
# 4                    0                           1950.777778
#                      1                           2575.000000
#                      2                           1992.909091
# 5                    0                           2398.212598
#                      1                           2629.230769
#                      2                           2876.147059
# 6                    0                           2444.295082
#                      1                           2509.842365
#                      2                           2373.553191
#                 interaction_period_days
# cluster_labels
# 0                           2362.312500
# 1                           2523.621739
# 2                           2573.276119

# %%
# interaction_period 
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata, # SHOWS MEDIAN (and upper/lower quartile, and 1.5 Inter-quartile range)
    #x="breadth_interactions", 
    x="cluster_labels",
    y="interaction_period_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("N interaction_period_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["interaction_period_days"]].mean() # MEAN AVERAGE
# Out:
# N interaction_period_days across breadth_interactions by Cluster
#                 interaction_period_days
# cluster_labels
# 0                           2362.312500
# 1                           2523.621739
# 2                           2573.276119

# %% [markdown]
# #### pc_interaction_days:

# %%
# pc_interaction_days
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.boxplot(data=sklearn_hcwdata, # SHOWS MEDIAN (and upper/lower quartile, and 1.5 Inter-quartile range)
    #x="breadth_interactions", 
    x="cluster_labels",
    y="pc_interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("pc_interaction_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["pc_interaction_days"]].mean() # MEAN AVERAGE
# Out:
# pc_interaction_days across breadth_interactions by Cluster
#                 pc_interaction_days
# cluster_labels
# 0                         42.466966
# 1                         65.571584
# 2                         53.523913

# %%
# pc_interaction_days BARPLOT
label_color_dict = {0:'#D50032', 1:'#1D2A3D', 2:'#FDBC42'} # universityred, epccnavy, dandelion, 
sns.barplot(data=sklearn_hcwdata, # SHOWS MEDIAN (and upper/lower quartile, and 1.5 Inter-quartile range)
    #x="breadth_interactions", 
    x="cluster_labels",
    y="pc_interaction_days",
    hue="cluster_labels", 
    palette = label_color_dict)
print("pc_interaction_days across breadth_interactions by Cluster")
sklearn_hcwdata.groupby(["cluster_labels"])[["pc_interaction_days"]].mean() # MEAN
# Out:
# pc_interaction_days across breadth_interactions by Cluster
#                 pc_interaction_days
# cluster_labels
# 0                         42.466966
# 1                         65.571584
# 2                         53.523913

# %%
import numpy as np
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd

def run_anova(variable, data):
        variable = variable
        df = analysis_dataset

        # One-Way ANOVA: 
        anova = f_oneway(
            df.groupby("cluster_labels")[variable].get_group(0),
            df.groupby("cluster_labels")[variable].get_group(1),
            df.groupby("cluster_labels")[variable].get_group(2),
        )

        print("\n")
        print(f"{anova}")


        # perform Tukey's test
        tukey = pairwise_tukeyhsd(endog=df[variable],
                                  groups=df['cluster_labels'],
                                  alpha=0.05)

        #display results
        print(tukey.summary())

        print(f"For {variable}, anova result p-value is {anova.pvalue}; groups are significantly different = {anova.pvalue < 0.05}")
        print(f"For {variable}, Tukey HSD test result p-value is {tukey.pvalues}; groups are significantly different = {tukey.reject == True}")
        
        if anova.pvalue < 0.05:
            print(f">>>>>> {variable} ^^^ is significant <<<<<< \n ")

        return df.groupby("cluster_labels")[variable].mean()

# %%
analysis_dataset.columns
# Out:
# Index(['cluster_labels', 'repo_name', 'gh_username', 'author_username',
#        'n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
#        'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
#        'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
#        'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
#        'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
#        'hattori_lanza_content_cat_forward_engineering',
#        'hattori_lanza_content_cat_reengineering',
#        'hattori_lanza_content_cat_corrective_engineering',
#        'hattori_lanza_content_cat_management',
#        'hattori_lanza_content_cat_empty_message',
#        'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
#        'vasilescu_category_img', 'vasilescu_category_l10n',
#        'vasilescu_category_ui', 'vasilescu_category_media',
#        'vasilescu_category_code', 'vasilescu_category_meta',
#        'vasilescu_category_config', 'vasilescu_category_build',
#        'vasilescu_category_devdoc', 'vasilescu_category_db',
#        'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
#        'n_of_issues_creators', 'assigned_devs', 'n_issues_assigned',
#        'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
#        'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
#        'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
#        'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
#        'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
#        'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
#        'pull_request_closed', 'pull_request_created', 'interaction_days',
#        'interaction_period_days', 'created-closed_issues',
#        'pc_created-closed_issues', 'sum_n_interactions',
#        'mean_n_interactions_per_interaction_day', 'which_interactions',
#        'breadth_interactions', 'pc_pull_request_created',
#        'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
#        'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
#        'pc_DC'],
#       dtype='object')

# %%
for var in ['n_of_commit_creators', 'n_commits', 'n_changes', 'mean_n_changes',
       'median_n_changes_changed', 'std_n_changes_changed', 'n_files_changed',
       'mean_n_files', 'median_n_files_changed', 'std_n_files_changed',
       'hattori_lanza_size_cat_tiny', 'hattori_lanza_size_cat_small',
       'hattori_lanza_size_cat_medium', 'hattori_lanza_size_cat_large',
       'hattori_lanza_content_cat_forward_engineering',
       'hattori_lanza_content_cat_reengineering',
       'hattori_lanza_content_cat_corrective_engineering',
       'hattori_lanza_content_cat_management',
       'hattori_lanza_content_cat_empty_message',
       'hattori_lanza_content_cat_no_categorisation', 'vasilescu_category_doc',
       'vasilescu_category_img', 'vasilescu_category_l10n',
       'vasilescu_category_ui', 'vasilescu_category_media',
       'vasilescu_category_code', 'vasilescu_category_meta',
       'vasilescu_category_config', 'vasilescu_category_build',
       'vasilescu_category_devdoc', 'vasilescu_category_db',
       'vasilescu_category_test', 'vasilescu_category_unknown', 'n_issues',
       'n_of_issues_creators', 'n_issues_assigned',
       'pc_issues_assigned_of_assigned', 'pc_n_commits', 'pc_HLs-tiny',
       'pc_HLs-sml', 'pc_HLs-med', 'pc_HLs-lrg', 'pc_HL-fweng', 'pc_HL-reeng',
       'pc_HL-corr', 'pc_HL-mgmt', 'pc_HL-empty', 'pc_HL-nocat', 'pc_V-doc',
       'pc_V-code', 'pc_V-confg', 'pc_V-build', 'pc_V-dvdoc', 'pc_V-test',
       'pc_V-meta', 'pc_V-img', 'pc_V-l10n', 'pc_V-ui', 'pc_V-media',
       'pc_V-nocat', 'commit_created', 'issue_closed', 'issue_created',
       'pull_request_closed', 'pull_request_created', 'interaction_days',
       'interaction_period_days', 'created-closed_issues',
       'pc_created-closed_issues', 'sum_n_interactions',
       'mean_n_interactions_per_interaction_day', 
       'breadth_interactions', 'pc_pull_request_created',
       'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
       'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
       'pc_DC']:
    print(run_anova(variable=var, data=analysis_dataset))
# Out:
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   8.2775   nan   nan   nan  False
# -----------------------------------------------
# For n_of_commit_creators, anova result p-value is nan; groups are significantly different = False
# For n_of_commit_creators, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    23.411215
# 1    13.647826
# 2    21.925373
# Name: n_of_commit_creators, dtype: float64
#
#
# F_onewayResult(statistic=29.853933603251537, pvalue=3.6318535302770933e-13)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj   lower     upper   reject
# -------------------------------------------------------
#      0      1 872.2019    0.0 600.4941 1143.9097   True
#      0      2 574.1429 0.0001 249.7627  898.5231   True
#      1      2 -298.059 0.1061 -643.093    46.975  False
# -------------------------------------------------------
# For n_commits, anova result p-value is 3.6318535302770933e-13; groups are significantly different = True
# For n_commits, Tukey HSD test result p-value is [9.21152044e-13 1.07256962e-04 1.06059536e-01]; groups are significantly different = [ True  True False]
# >>>>>> n_commits ^^^ is significant <<<<<<
#
# cluster_labels
# 0     566.372024
# 1    1438.573913
# 2    1140.514925
# Name: n_commits, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2   meandiff   p-adj lower upper reject
# ---------------------------------------------------
#      0      1          nan   nan   nan   nan  False
#      0      2          nan   nan   nan   nan  False
#      1      2 1276925.4439   nan   nan   nan  False
# ---------------------------------------------------
# For n_changes, anova result p-value is nan; groups are significantly different = False
# For n_changes, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    1.380598e+06
# 1    2.209108e+06
# 2    3.486033e+06
# Name: n_changes, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2 563.9283   nan   nan   nan  False
# -----------------------------------------------
# For mean_n_changes, anova result p-value is nan; groups are significantly different = False
# For mean_n_changes, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    2094.680264
# 1    1649.020105
# 2    2212.948407
# Name: mean_n_changes, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   4.3234   nan   nan   nan  False
# -----------------------------------------------
# For median_n_changes_changed, anova result p-value is nan; groups are significantly different = False
# For median_n_changes_changed, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    68.848131
# 1    27.008696
# 2    31.332090
# Name: median_n_changes_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================
# group1 group2  meandiff p-adj lower upper reject
# ------------------------------------------------
#      0      1       nan   nan   nan   nan  False
#      0      2       nan   nan   nan   nan  False
#      1      2 4169.1291   nan   nan   nan  False
# ------------------------------------------------
# For std_n_changes_changed, anova result p-value is nan; groups are significantly different = False
# For std_n_changes_changed, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    17292.839222
# 1    13216.332346
# 2    17385.461445
# Name: std_n_changes_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2  meandiff  p-adj lower upper reject
# -------------------------------------------------
#      0      1        nan   nan   nan   nan  False
#      0      2        nan   nan   nan   nan  False
#      1      2 -1175.4585   nan   nan   nan  False
# -------------------------------------------------
# For n_files_changed, anova result p-value is nan; groups are significantly different = False
# For n_files_changed, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    5659.233645
# 1    8276.891304
# 2    7101.432836
# Name: n_files_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.3144   nan   nan   nan  False
# -----------------------------------------------
# For mean_n_files, anova result p-value is nan; groups are significantly different = False
# For mean_n_files, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    6.016528
# 1    5.705611
# 2    5.391205
# Name: mean_n_files, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.0683   nan   nan   nan  False
# -----------------------------------------------
# For median_n_files_changed, anova result p-value is nan; groups are significantly different = False
# For median_n_files_changed, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    1.738318
# 1    1.663043
# 2    1.731343
# Name: median_n_files_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -2.5344   nan   nan   nan  False
# -----------------------------------------------
# For std_n_files_changed, anova result p-value is nan; groups are significantly different = False
# For std_n_files_changed, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    15.020213
# 1    15.844331
# 2    13.309971
# Name: std_n_files_changed, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2 -287.108   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_tiny, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_tiny, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0     737.588785
# 1    1212.682609
# 2     925.574627
# Name: hattori_lanza_size_cat_tiny, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -9.3419   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_small, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_small, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    117.252336
# 1    178.647826
# 2    169.305970
# Name: hattori_lanza_size_cat_small, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2    1.508   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_medium, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_medium, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    27.242991
# 1    37.417391
# 2    38.925373
# Name: hattori_lanza_size_cat_medium, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -3.1171   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_size_cat_large, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_size_cat_large, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    7.172897
# 1    9.826087
# 2    6.708955
# Name: hattori_lanza_size_cat_large, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2 -63.3775   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_forward_engineering, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_forward_engineering, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    116.766355
# 1    215.004348
# 2    151.626866
# Name: hattori_lanza_content_cat_forward_engineering, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2 -21.2126   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_reengineering, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_reengineering, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    205.378505
# 1    356.578261
# 2    335.365672
# Name: hattori_lanza_content_cat_reengineering, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2 -65.7657   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_corrective_engineering, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_corrective_engineering, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    127.696262
# 1    215.347826
# 2    149.582090
# Name: hattori_lanza_content_cat_corrective_engineering, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2 -83.1542   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_management, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_management, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    228.490654
# 1    292.034783
# 2    208.880597
# Name: hattori_lanza_content_cat_management, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2    0.694   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_empty_message, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_empty_message, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.158879
# 1    0.000000
# 2    0.694030
# Name: hattori_lanza_content_cat_empty_message, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -65.243   nan   nan   nan  False
# -----------------------------------------------
# For hattori_lanza_content_cat_no_categorisation, anova result p-value is nan; groups are significantly different = False
# For hattori_lanza_content_cat_no_categorisation, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    210.766355
# 1    359.608696
# 2    294.365672
# Name: hattori_lanza_content_cat_no_categorisation, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2 -54.0071   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_doc, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_doc, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    206.200935
# 1    298.313043
# 2    244.305970
# Name: vasilescu_category_doc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   -0.275   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_img, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_img, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    1.392523
# 1    1.939130
# 2    1.664179
# Name: vasilescu_category_img, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.1359   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_l10n, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_l10n, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    2.771028
# 1    1.252174
# 2    1.388060
# Name: vasilescu_category_l10n, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -5.7742   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_ui, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_ui, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    5.528037
# 1    6.013043
# 2    0.238806
# Name: vasilescu_category_ui, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.9175   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_media, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_media, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    1.084112
# 1    1.365217
# 2    0.447761
# Name: vasilescu_category_media, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================
# group1 group2  meandiff p-adj lower upper reject
# ------------------------------------------------
#      0      1       nan   nan   nan   nan  False
#      0      2       nan   nan   nan   nan  False
#      1      2 -247.6883   nan   nan   nan  False
# ------------------------------------------------
# For vasilescu_category_code, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_code, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0     618.457944
# 1    1031.643478
# 2     783.955224
# Name: vasilescu_category_code, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.0304   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_meta, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_meta, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.000000
# 1    0.030435
# 2    0.000000
# Name: vasilescu_category_meta, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -5.8152   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_config, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_config, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    7.771028
# 1    6.539130
# 2    0.723881
# Name: vasilescu_category_config, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -2.5329   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_build, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_build, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    4.028037
# 1    8.047826
# 2    5.514925
# Name: vasilescu_category_build, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   1.2975   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_devdoc, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_devdoc, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    2.710280
# 1    2.665217
# 2    3.962687
# Name: vasilescu_category_devdoc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.4936   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_db, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_db, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.794393
# 1    1.165217
# 2    0.671642
# Name: vasilescu_category_db, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   3.8721   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_test, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_test, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0     3.971963
# 1     7.165217
# 2    11.037313
# Name: vasilescu_category_test, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  14.1697   nan   nan   nan  False
# -----------------------------------------------
# For vasilescu_category_unknown, anova result p-value is nan; groups are significantly different = False
# For vasilescu_category_unknown, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    34.546729
# 1    72.434783
# 2    86.604478
# Name: vasilescu_category_unknown, dtype: float64
#
#
# F_onewayResult(statistic=7.133900973649808, pvalue=0.0008571772726924131)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      0      1   22.6265 0.6907   -42.176   87.429  False
#      0      2 -105.0057 0.0043 -182.3706 -27.6408   True
#      1      2 -127.6322 0.0008  -209.923 -45.3413   True
# --------------------------------------------------------
# For n_issues, anova result p-value is 0.0008571772726924131; groups are significantly different = True
# For n_issues, Tukey HSD test result p-value is [0.69068663 0.00426811 0.00084494]; groups are significantly different = [False  True  True]
# >>>>>> n_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0    220.095238
# 1    242.721739
# 2    115.089552
# Name: n_issues, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1 -30.2508   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2      nan   nan   nan   nan  False
# -----------------------------------------------
# For n_of_issues_creators, anova result p-value is nan; groups are significantly different = False
# For n_of_issues_creators, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    73.946429
# 1    43.695652
# 2    95.608000
# Name: n_of_issues_creators, dtype: float64
#
#
# F_onewayResult(statistic=7.88658323637939, pvalue=0.0004102802573122354)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1  -6.9915 0.8702  -39.6798  25.6969  False
#      0      2 -64.3915 0.0003 -103.4167 -25.3663   True
#      1      2 -57.4001 0.0035  -98.9101 -15.8901   True
# -------------------------------------------------------
# For n_issues_assigned, anova result p-value is 0.0004102802573122354; groups are significantly different = True
# For n_issues_assigned, Tukey HSD test result p-value is [8.70202233e-01 3.42500200e-04 3.48697684e-03]; groups are significantly different = [False  True  True]
# >>>>>> n_issues_assigned ^^^ is significant <<<<<<
#
# cluster_labels
# 0    69.839286
# 1    62.847826
# 2     5.447761
# Name: n_issues_assigned, dtype: float64
#
#
# F_onewayResult(statistic=250.46044087858814, pvalue=1.0824752132301662e-82)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1  11.6131   0.0   6.0314  17.1949   True
#      0      2 -53.5488   0.0 -60.2127  -46.885   True
#      1      2  -65.162   0.0 -72.2501 -58.0739   True
# -----------------------------------------------------
# For pc_issues_assigned_of_assigned, anova result p-value is 1.0824752132301662e-82; groups are significantly different = True
# For pc_issues_assigned_of_assigned, Tukey HSD test result p-value is [3.80471231e-06 4.79505324e-13 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_issues_assigned_of_assigned ^^^ is significant <<<<<<
#
# cluster_labels
# 0    65.480128
# 1    77.093274
# 2    11.931279
# Name: pc_issues_assigned_of_assigned, dtype: float64
#
#
# F_onewayResult(statistic=29.85393360325154, pvalue=3.6318535302770933e-13)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1   0.1294    0.0  0.0891 0.1697   True
#      0      2   0.0852 0.0001  0.0371 0.1333   True
#      1      2  -0.0442 0.1061 -0.0954  0.007  False
# ---------------------------------------------------
# For pc_n_commits, anova result p-value is 3.6318535302770933e-13; groups are significantly different = True
# For pc_n_commits, Tukey HSD test result p-value is [9.21152044e-13 1.07256962e-04 1.06059536e-01]; groups are significantly different = [ True  True False]
# >>>>>> pc_n_commits ^^^ is significant <<<<<<
#
# cluster_labels
# 0    0.084031
# 1    0.213438
# 2    0.169215
# Name: pc_n_commits, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   -0.748   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-tiny, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-tiny, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    82.846754
# 1    84.308443
# 2    83.560472
# Name: pc_HLs-tiny, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.8989   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-sml, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-sml, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    13.475432
# 1    12.430127
# 2    13.328987
# Name: pc_HLs-sml, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.0386   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-med, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-med, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    2.995912
# 1    2.581164
# 2    2.619782
# Name: pc_HLs-med, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.1895   nan   nan   nan  False
# -----------------------------------------------
# For pc_HLs-lrg, anova result p-value is nan; groups are significantly different = False
# For pc_HLs-lrg, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.681903
# 1    0.680266
# 2    0.490759
# Name: pc_HLs-lrg, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -1.1175   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-fweng, anova result p-value is nan; groups are significantly different = False
# For pc_HL-fweng, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    13.174598
# 1    15.241799
# 2    14.124288
# Name: pc_HL-fweng, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   2.3667   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-reeng, anova result p-value is nan; groups are significantly different = False
# For pc_HL-reeng, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    27.254570
# 1    25.486629
# 2    27.853289
# Name: pc_HL-reeng, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.9097   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-corr, anova result p-value is nan; groups are significantly different = False
# For pc_HL-corr, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    12.413151
# 1    14.338577
# 2    13.428867
# Name: pc_HL-corr, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.0659   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-mgmt, anova result p-value is nan; groups are significantly different = False
# For pc_HL-mgmt, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    26.165005
# 1    20.603909
# 2    20.537962
# Name: pc_HL-mgmt, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.0727   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-empty, anova result p-value is nan; groups are significantly different = False
# For pc_HL-empty, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.005772
# 1    0.000000
# 2    0.072673
# Name: pc_HL-empty, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.3462   nan   nan   nan  False
# -----------------------------------------------
# For pc_HL-nocat, anova result p-value is nan; groups are significantly different = False
# For pc_HL-nocat, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    20.986902
# 1    24.329086
# 2    23.982921
# Name: pc_HL-nocat, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   1.9044   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-doc, anova result p-value is nan; groups are significantly different = False
# For pc_V-doc, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    28.207550
# 1    22.478296
# 2    24.382724
# Name: pc_V-doc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -4.0007   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-code, anova result p-value is nan; groups are significantly different = False
# For pc_V-code, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    62.165051
# 1    68.293424
# 2    64.292768
# Name: pc_V-code, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   -1.289   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-confg, anova result p-value is nan; groups are significantly different = False
# For pc_V-confg, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    1.179108
# 1    1.417130
# 2    0.128113
# Name: pc_V-confg, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.5199   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-build, anova result p-value is nan; groups are significantly different = False
# For pc_V-build, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.878011
# 1    0.590498
# 2    1.110364
# Name: pc_V-build, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.2766   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-dvdoc, anova result p-value is nan; groups are significantly different = False
# For pc_V-dvdoc, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.613358
# 1    0.248642
# 2    0.525281
# Name: pc_V-dvdoc, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   0.4817   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-test, anova result p-value is nan; groups are significantly different = False
# For pc_V-test, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.460003
# 1    0.598267
# 2    1.079969
# Name: pc_V-test, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.0008   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-meta, anova result p-value is nan; groups are significantly different = False
# For pc_V-meta, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.000000
# 1    0.000783
# 2    0.000000
# Name: pc_V-meta, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.0873   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-img, anova result p-value is nan; groups are significantly different = False
# For pc_V-img, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.224557
# 1    0.162959
# 2    0.075680
# Name: pc_V-img, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.1244   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-l10n, anova result p-value is nan; groups are significantly different = False
# For pc_V-l10n, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.323046
# 1    0.163665
# 2    0.039263
# Name: pc_V-l10n, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.1384   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-ui, anova result p-value is nan; groups are significantly different = False
# For pc_V-ui, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.282943
# 1    0.177177
# 2    0.038753
# Name: pc_V-ui, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2  -0.0408   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-media, anova result p-value is nan; groups are significantly different = False
# For pc_V-media, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    0.064275
# 1    0.077662
# 2    0.036880
# Name: pc_V-media, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1      nan   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2   2.5808   nan   nan   nan  False
# -----------------------------------------------
# For pc_V-nocat, anova result p-value is nan; groups are significantly different = False
# For pc_V-nocat, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    5.460732
# 1    5.646142
# 2    8.226936
# Name: pc_V-nocat, dtype: float64
#
#
# F_onewayResult(statistic=29.75392669554714, pvalue=3.9823463999931407e-13)
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#      0      1  876.3055    0.0   602.972 1149.6391   True
#      0      2  574.9669 0.0001  248.6458   901.288   True
#      1      2 -301.3387 0.1037 -648.4371   45.7597  False
# ---------------------------------------------------------
# For commit_created, anova result p-value is 3.9823463999931407e-13; groups are significantly different = True
# For commit_created, Tukey HSD test result p-value is [9.52127266e-13 1.16155834e-04 1.03730780e-01]; groups are significantly different = [ True  True False]
# >>>>>> commit_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0     569.898810
# 1    1446.204348
# 2    1144.865672
# Name: commit_created, dtype: float64
#
#
# F_onewayResult(statistic=3.031221888113969, pvalue=0.04889328635821297)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj    lower   upper  reject
# -----------------------------------------------------
#      0      1 -32.6481 0.2437  -80.3942 15.098  False
#      0      2 -55.8565 0.0562 -112.8585 1.1455  False
# ...
#
# cluster_labels
# 0    106.821429
# 1     90.813043
# 2     27.567164
# Name: issue_created, dtype: float64
#
#
# F_onewayResult(statistic=0.7878189522437286, pvalue=0.45524032148648397)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1 group2 meandiff p-adj    lower    upper  reject
# ------------------------------------------------------
#      0      1   2.6872  0.994  -57.6773 63.0518  False
#      0      2 -34.9974 0.4894  -107.064 37.0692  False
#      1      2 -37.6846 0.4808 -114.3398 38.9705  False
# ------------------------------------------------------
# For pull_request_closed, anova result p-value is 0.45524032148648397; groups are significantly different = False
# For pull_request_closed, Tukey HSD test result p-value is [0.99399098 0.48939309 0.48082617]; groups are significantly different = [False False False]
# cluster_labels
# 0    198.377976
# 1    201.065217
# 2    163.380597
# Name: pull_request_closed, dtype: float64
#
#
# F_onewayResult(statistic=4.132543859684288, pvalue=0.016436779283259508)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1 group2 meandiff p-adj    lower    upper  reject
# ------------------------------------------------------
#      0      1  38.6349 0.0951   -5.0265 82.2962  False
#      0      2 -25.7514 0.4774  -77.8768  26.374  False
#      1      2 -64.3863 0.0179 -119.8306  -8.942   True
# ------------------------------------------------------
# For pull_request_created, anova result p-value is 0.016436779283259508; groups are significantly different = True
# For pull_request_created, Tukey HSD test result p-value is [0.09508149 0.47738263 0.01794507]; groups are significantly different = [False False  True]
# >>>>>> pull_request_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    113.273810
# 1    151.908696
# 2     87.522388
# Name: pull_request_created, dtype: float64
#
#
# F_onewayResult(statistic=7.044337630839656, pvalue=0.0009358194236953625)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1 110.8328 0.0006   40.8853 180.7803   True
#      0      2  61.3623 0.1962   -22.145 144.8695  False
#      1      2 -49.4705 0.3911 -138.2948  39.3537  False
# -------------------------------------------------------
# For interaction_days, anova result p-value is 0.0009358194236953625; groups are significantly different = True
# For interaction_days, Tukey HSD test result p-value is [0.00062586 0.19622874 0.39109034]; groups are significantly different = [ True False False]
# >>>>>> interaction_days ^^^ is significant <<<<<<
#
# cluster_labels
# 0    286.354167
# 1    397.186957
# 2    347.716418
# Name: interaction_days, dtype: float64
#
#
# F_onewayResult(statistic=2.044850458070998, pvalue=0.13017511924339212)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1 161.3092 0.2564  -78.9669 401.5853  False
#      0      2 210.9636 0.1957  -75.8916 497.8189  False
#      1      2  49.6544 0.9226 -255.4653 354.7741  False
# -------------------------------------------------------
# For interaction_period_days, anova result p-value is 0.13017511924339212; groups are significantly different = False
# For interaction_period_days, Tukey HSD test result p-value is [0.25636168 0.19569229 0.92264292]; groups are significantly different = [False False False]
# cluster_labels
# 0    2362.312500
# 1    2523.621739
# 2    2573.276119
# Name: interaction_period_days, dtype: float64
#
#
# F_onewayResult(statistic=3.3451073072639295, pvalue=0.03582335749698601)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1  16.6397 0.3616 -12.0566  45.336  False
#      0      2 -23.3977 0.2446 -57.6571 10.8616  False
#      1      2 -40.0374 0.0272 -76.4781 -3.5968   True
# -----------------------------------------------------
# For created-closed_issues, anova result p-value is 0.03582335749698601; groups are significantly different = True
# For created-closed_issues, Tukey HSD test result p-value is [0.36159959 0.24455467 0.02716563]; groups are significantly different = [False False  True]
# >>>>>> created-closed_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0   -47.744048
# 1   -31.104348
# 2   -71.141791
# Name: created-closed_issues, dtype: float64
#
#
# F_onewayResult(statistic=27.474334014644175, pvalue=3.2736890546110063e-12)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1    -7.63    0.0 -10.4337 -4.8264   True
#      0      2   1.9294 0.3659  -1.4177  5.2766  False
#      1      2   9.5595    0.0   5.9992 13.1197   True
# -----------------------------------------------------
# For pc_created-closed_issues, anova result p-value is 3.2736890546110063e-12; groups are significantly different = True
# For pc_created-closed_issues, Tukey HSD test result p-value is [8.99101793e-10 3.65921709e-01 1.52062396e-09]; groups are significantly different = [ True False  True]
# >>>>>> pc_created-closed_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0   -74.444781
# 1   -82.074829
# 2   -72.515360
# Name: pc_created-closed_issues, dtype: float64
#
#
# F_onewayResult(statistic=15.171687737058773, pvalue=3.5514990420430495e-07)
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#      0      1  868.9712    0.0  498.3246 1239.6178   True
#      0      2  379.1073   0.11  -63.3917  821.6063  False
#      1      2 -489.8639 0.0391 -960.5375  -19.1904   True
# ---------------------------------------------------------
# For sum_n_interactions, anova result p-value is 3.5514990420430495e-07; groups are significantly different = True
# For sum_n_interactions, Tukey HSD test result p-value is [1.54267707e-07 1.09991095e-01 3.91175543e-02]; groups are significantly different = [ True False  True]
# >>>>>> sum_n_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    1142.937500
# 1    2011.908696
# 2    1522.044776
# Name: sum_n_interactions, dtype: float64
#
#
# F_onewayResult(statistic=0.08298942867908225, pvalue=0.9203699695347531)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1  -0.1971 0.9926 -4.1889 3.7946  False
#      0      2  -0.8252 0.9129 -5.5908 3.9404  False
#      1      2  -0.6281 0.9544 -5.6971 4.4409  False
# ---------------------------------------------------
# For mean_n_interactions_per_interaction_day, anova result p-value is 0.9203699695347531; groups are significantly different = False
# For mean_n_interactions_per_interaction_day, Tukey HSD test result p-value is [0.99261077 0.9128799  0.95439009]; groups are significantly different = [False False False]
# cluster_labels
# 0    5.148085
# 1    4.950962
# 2    4.322882
# Name: mean_n_interactions_per_interaction_day, dtype: float64
#
#
# F_onewayResult(statistic=57.949618563307006, pvalue=5.233926822276401e-24)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.4467    0.0   0.314  0.5795   True
#      0      2  -0.2823 0.0001 -0.4408 -0.1238   True
#      1      2   -0.729    0.0 -0.8976 -0.5604   True
# ----------------------------------------------------
# For breadth_interactions, anova result p-value is 5.233926822276401e-24; groups are significantly different = True
# For breadth_interactions, Tukey HSD test result p-value is [5.11257703e-13 9.59076922e-05 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> breadth_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    5.431548
# 1    5.878261
# 2    5.149254
# Name: breadth_interactions, dtype: float64
#
#
# F_onewayResult(statistic=26.486015510735637, pvalue=8.192513787235383e-12)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1  14.1805    0.0   9.3417 19.0193   True
#      0      2   0.2922 0.9922  -5.4846   6.069  False
#      1      2 -13.8883    0.0 -20.0329 -7.7436   True
# -----------------------------------------------------
# For pc_pull_request_created, anova result p-value is 8.192513787235383e-12; groups are significantly different = True
# For pc_pull_request_created, Tukey HSD test result p-value is [3.96837008e-11 9.92248180e-01 4.44985230e-07]; groups are significantly different = [ True False  True]
# >>>>>> pc_pull_request_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    36.744507
# 1    50.924988
# 2    37.036725
# Name: pc_pull_request_created, dtype: float64
#
#
# F_onewayResult(statistic=47.88728521079649, pvalue=3.2579835908222064e-20)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  14.5926   0.0 10.8202 18.3651   True
#      0      2  12.4882   0.0  7.9844  16.992   True
#      1      2  -2.1044 0.557 -6.8949  2.6861  False
# ---------------------------------------------------
# For pc_pull_request_closed, anova result p-value is 3.2579835908222064e-20; groups are significantly different = True
# For pc_pull_request_closed, Tukey HSD test result p-value is [4.79505324e-13 4.24493551e-10 5.57041097e-01]; groups are significantly different = [ True  True False]
# >>>>>> pc_pull_request_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0    71.644907
# 1    86.237526
# 2    84.133111
# Name: pc_pull_request_closed, dtype: float64
#
#
# F_onewayResult(statistic=377.46652254267457, pvalue=8.476892617879201e-112)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1  50.3103    0.0  45.7052 54.9154   True
#      0      2  42.0684    0.0  36.5706 47.5663   True
#      1      2  -8.2419 0.0028 -14.0898  -2.394   True
# -----------------------------------------------------
# For pc_commit_created, anova result p-value is 8.476892617879201e-112; groups are significantly different = True
# For pc_commit_created, Tukey HSD test result p-value is [4.79505324e-13 4.79505324e-13 2.81502767e-03]; groups are significantly different = [ True  True  True]
# >>>>>> pc_commit_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    32.876974
# 1    83.187279
# 2    74.945404
# Name: pc_commit_created, dtype: float64
#
#
# F_onewayResult(statistic=89.30980010377682, pvalue=2.9490377486847743e-35)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1  11.2526   0.0   6.3118  16.1935   True
#      0      2 -24.3501   0.0 -30.2488 -18.4514   True
#      1      2 -35.6028   0.0  -41.877 -29.3285   True
# -----------------------------------------------------
# For pc_issue_created, anova result p-value is 2.9490377486847743e-35; groups are significantly different = True
# For pc_issue_created, Tukey HSD test result p-value is [3.59254268e-07 4.79505324e-13 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_issue_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    40.469839
# 1    51.722466
# 2    16.119713
# Name: pc_issue_created, dtype: float64
#
#
# F_onewayResult(statistic=28.570570476304024, pvalue=1.1868076403927408e-12)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1   7.7426    0.0   4.9221  10.563   True
#      0      2  -2.1729 0.2841  -5.5402  1.1943  False
#      1      2  -9.9155    0.0 -13.4971 -6.3339   True
# -----------------------------------------------------
# For pc_issue_closed, anova result p-value is 1.1868076403927408e-12; groups are significantly different = True
# For pc_issue_closed, Tukey HSD test result p-value is [6.37287112e-10 2.84138628e-01 4.52966886e-10]; groups are significantly different = [ True False  True]
# >>>>>> pc_issue_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0    74.849480
# 1    82.592054
# 2    72.676557
# Name: pc_issue_closed, dtype: float64
#
#
# F_onewayResult(statistic=261.06554534263995, pvalue=2.388121132229802e-85)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj  lower    upper  reject
# ----------------------------------------------------
#      0      1   24.996   0.0  22.4017 27.5903   True
#      0      2  14.0831   0.0  10.9859 17.1804   True
#      1      2 -10.9129   0.0 -14.2073 -7.6184   True
# ----------------------------------------------------
# For pc_sum_n_interactions, anova result p-value is 2.388121132229802e-85; groups are significantly different = True
# For pc_sum_n_interactions, Tukey HSD test result p-value is [4.79505324e-13 4.79505324e-13 5.57887070e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_sum_n_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    54.098498
# 1    79.094465
# 2    68.181613
# Name: pc_sum_n_interactions, dtype: float64
#
#
# F_onewayResult(statistic=195.16702057514132, pvalue=4.944507053979312e-68)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj  lower    upper  reject
# ----------------------------------------------------
#      0      1  23.1046   0.0  20.3522  25.857   True
#      0      2  11.0569   0.0    7.771 14.3429   True
#      1      2 -12.0477   0.0 -15.5428 -8.5525   True
# ----------------------------------------------------
# For pc_interaction_days, anova result p-value is 4.944507053979312e-68; groups are significantly different = True
# For pc_interaction_days, Tukey HSD test result p-value is [4.79505324e-13 5.11257703e-13 4.87054841e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_interaction_days ^^^ is significant <<<<<<
#
# cluster_labels
# 0    42.466966
# 1    65.571584
# 2    53.523913
# Name: pc_interaction_days, dtype: float64
#
#
# F_onewayResult(statistic=455.61428746056083, pvalue=2.8472381828036806e-127)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1  19.0198   0.0  17.2004  20.8393   True
#      0      2  -7.5422   0.0  -9.7144  -5.3701   True
#      1      2 -26.5621   0.0 -28.8725 -24.2516   True
# -----------------------------------------------------
# For pc_DC, anova result p-value is 2.8472381828036806e-127; groups are significantly different = True
# For pc_DC, Tukey HSD test result p-value is [4.79505324e-13 4.84390306e-13 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_DC ^^^ is significant <<<<<<
#
# cluster_labels
# 0    50.084185
# 1    69.104012
# 2    42.541936
# Name: pc_DC, dtype: float64

# %%
run_anova("issue_created", analysis_dataset)
# Out:
# F_onewayResult(statistic=9.99197131649576, pvalue=5.267287292786861e-05)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1 -16.0084 0.5318  -51.0809  19.0642  False
#      0      2 -79.2543    0.0 -121.1259 -37.3827   True
#      1      2 -63.2459 0.0026 -107.7835 -18.7082   True
# -------------------------------------------------------
# For issue_created, anova result p-value is 5.267287292786861e-05; groups are significantly different = True
# For issue_created, Tukey HSD test result p-value is [5.31772512e-01 3.03173224e-05 2.58007095e-03]; groups are significantly different = [False  True  True]
# >>>>>> issue_created ^^^ is significant <<<<<<
# cluster_labels
# 0    106.821429
# 1     90.813043
# 2     27.567164
# Name: issue_created, dtype: float64

# %%
for var in ['n_commits','n_issues',
       'n_of_issues_creators', 'n_issues_assigned',
       'pc_issues_assigned_of_assigned', 'pc_n_commits', 'commit_created', 'issue_closed', 'issue_created',
       'pull_request_closed', 'pull_request_created', 'interaction_days',
       'interaction_period_days', 'created-closed_issues',
       'pc_created-closed_issues', 'sum_n_interactions',
       'mean_n_interactions_per_interaction_day', 
       'breadth_interactions', 'pc_pull_request_created',
       'pc_pull_request_closed', 'pc_commit_created', 'pc_issue_created',
       'pc_issue_closed', 'pc_sum_n_interactions', 'pc_interaction_days',
       'pc_DC']:
    print(run_anova(variable=var, data=analysis_dataset))
# Out:
# F_onewayResult(statistic=29.853933603251537, pvalue=3.6318535302770933e-13)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj   lower     upper   reject
# -------------------------------------------------------
#      0      1 872.2019    0.0 600.4941 1143.9097   True
#      0      2 574.1429 0.0001 249.7627  898.5231   True
#      1      2 -298.059 0.1061 -643.093    46.975  False
# -------------------------------------------------------
# For n_commits, anova result p-value is 3.6318535302770933e-13; groups are significantly different = True
# For n_commits, Tukey HSD test result p-value is [9.21152044e-13 1.07256962e-04 1.06059536e-01]; groups are significantly different = [ True  True False]
# >>>>>> n_commits ^^^ is significant <<<<<<
#
# cluster_labels
# 0     566.372024
# 1    1438.573913
# 2    1140.514925
# Name: n_commits, dtype: float64
#
#
# F_onewayResult(statistic=7.133900973649808, pvalue=0.0008571772726924131)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      0      1   22.6265 0.6907   -42.176   87.429  False
#      0      2 -105.0057 0.0043 -182.3706 -27.6408   True
#      1      2 -127.6322 0.0008  -209.923 -45.3413   True
# --------------------------------------------------------
# For n_issues, anova result p-value is 0.0008571772726924131; groups are significantly different = True
# For n_issues, Tukey HSD test result p-value is [0.69068663 0.00426811 0.00084494]; groups are significantly different = [False  True  True]
# >>>>>> n_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0    220.095238
# 1    242.721739
# 2    115.089552
# Name: n_issues, dtype: float64
#
#
# F_onewayResult(statistic=nan, pvalue=nan)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      0      1 -30.2508   nan   nan   nan  False
#      0      2      nan   nan   nan   nan  False
#      1      2      nan   nan   nan   nan  False
# -----------------------------------------------
# For n_of_issues_creators, anova result p-value is nan; groups are significantly different = False
# For n_of_issues_creators, Tukey HSD test result p-value is [nan nan nan]; groups are significantly different = [False False False]
# cluster_labels
# 0    73.946429
# 1    43.695652
# 2    95.608000
# Name: n_of_issues_creators, dtype: float64
#
#
# F_onewayResult(statistic=7.88658323637939, pvalue=0.0004102802573122354)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1  -6.9915 0.8702  -39.6798  25.6969  False
#      0      2 -64.3915 0.0003 -103.4167 -25.3663   True
#      1      2 -57.4001 0.0035  -98.9101 -15.8901   True
# -------------------------------------------------------
# For n_issues_assigned, anova result p-value is 0.0004102802573122354; groups are significantly different = True
# For n_issues_assigned, Tukey HSD test result p-value is [8.70202233e-01 3.42500200e-04 3.48697684e-03]; groups are significantly different = [False  True  True]
# >>>>>> n_issues_assigned ^^^ is significant <<<<<<
#
# cluster_labels
# 0    69.839286
# 1    62.847826
# 2     5.447761
# Name: n_issues_assigned, dtype: float64
#
#
# F_onewayResult(statistic=250.46044087858814, pvalue=1.0824752132301662e-82)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1  11.6131   0.0   6.0314  17.1949   True
#      0      2 -53.5488   0.0 -60.2127  -46.885   True
#      1      2  -65.162   0.0 -72.2501 -58.0739   True
# -----------------------------------------------------
# For pc_issues_assigned_of_assigned, anova result p-value is 1.0824752132301662e-82; groups are significantly different = True
# For pc_issues_assigned_of_assigned, Tukey HSD test result p-value is [3.80471231e-06 4.79505324e-13 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_issues_assigned_of_assigned ^^^ is significant <<<<<<
#
# cluster_labels
# 0    65.480128
# 1    77.093274
# 2    11.931279
# Name: pc_issues_assigned_of_assigned, dtype: float64
#
#
# F_onewayResult(statistic=29.85393360325154, pvalue=3.6318535302770933e-13)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1   0.1294    0.0  0.0891 0.1697   True
#      0      2   0.0852 0.0001  0.0371 0.1333   True
#      1      2  -0.0442 0.1061 -0.0954  0.007  False
# ---------------------------------------------------
# For pc_n_commits, anova result p-value is 3.6318535302770933e-13; groups are significantly different = True
# For pc_n_commits, Tukey HSD test result p-value is [9.21152044e-13 1.07256962e-04 1.06059536e-01]; groups are significantly different = [ True  True False]
# >>>>>> pc_n_commits ^^^ is significant <<<<<<
#
# cluster_labels
# 0    0.084031
# 1    0.213438
# 2    0.169215
# Name: pc_n_commits, dtype: float64
#
#
# F_onewayResult(statistic=29.75392669554714, pvalue=3.9823463999931407e-13)
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#      0      1  876.3055    0.0   602.972 1149.6391   True
#      0      2  574.9669 0.0001  248.6458   901.288   True
#      1      2 -301.3387 0.1037 -648.4371   45.7597  False
# ---------------------------------------------------------
# For commit_created, anova result p-value is 3.9823463999931407e-13; groups are significantly different = True
# For commit_created, Tukey HSD test result p-value is [9.52127266e-13 1.16155834e-04 1.03730780e-01]; groups are significantly different = [ True  True False]
# >>>>>> commit_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0     569.898810
# 1    1446.204348
# 2    1144.865672
# Name: commit_created, dtype: float64
#
#
# F_onewayResult(statistic=3.031221888113969, pvalue=0.04889328635821297)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj    lower   upper  reject
# -----------------------------------------------------
#      0      1 -32.6481 0.2437  -80.3942 15.098  False
#      0      2 -55.8565 0.0562 -112.8585 1.1455  False
#      1      2 -23.2084 0.6411  -83.8398 37.423  False
# -----------------------------------------------------
# For issue_closed, anova result p-value is 0.04889328635821297; groups are significantly different = True
# For issue_closed, Tukey HSD test result p-value is [0.24372896 0.05623754 0.6410875 ]; groups are significantly different = [False False False]
# >>>>>> issue_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0    154.565476
# 1    121.917391
# 2     98.708955
# Name: issue_closed, dtype: float64
#
#
# F_onewayResult(statistic=9.99197131649576, pvalue=5.267287292786861e-05)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1 -16.0084 0.5318  -51.0809  19.0642  False
#      0      2 -79.2543    0.0 -121.1259 -37.3827   True
#      1      2 -63.2459 0.0026 -107.7835 -18.7082   True
# -------------------------------------------------------
# For issue_created, anova result p-value is 5.267287292786861e-05; groups are significantly different = True
# For issue_created, Tukey HSD test result p-value is [5.31772512e-01 3.03173224e-05 2.58007095e-03]; groups are significantly different = [False  True  True]
# >>>>>> issue_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    106.821429
# 1     90.813043
# 2     27.567164
# Name: issue_created, dtype: float64
#
#
# F_onewayResult(statistic=0.7878189522437286, pvalue=0.45524032148648397)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1 group2 meandiff p-adj    lower    upper  reject
# ------------------------------------------------------
#      0      1   2.6872  0.994  -57.6773 63.0518  False
#      0      2 -34.9974 0.4894  -107.064 37.0692  False
#      1      2 -37.6846 0.4808 -114.3398 38.9705  False
# ------------------------------------------------------
# For pull_request_closed, anova result p-value is 0.45524032148648397; groups are significantly different = False
# For pull_request_closed, Tukey HSD test result p-value is [0.99399098 0.48939309 0.48082617]; groups are significantly different = [False False False]
# cluster_labels
# 0    198.377976
# 1    201.065217
# 2    163.380597
# Name: pull_request_closed, dtype: float64
#
#
# F_onewayResult(statistic=4.132543859684288, pvalue=0.016436779283259508)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1 group2 meandiff p-adj    lower    upper  reject
# ------------------------------------------------------
#      0      1  38.6349 0.0951   -5.0265 82.2962  False
#      0      2 -25.7514 0.4774  -77.8768  26.374  False
#      1      2 -64.3863 0.0179 -119.8306  -8.942   True
# ------------------------------------------------------
# For pull_request_created, anova result p-value is 0.016436779283259508; groups are significantly different = True
# For pull_request_created, Tukey HSD test result p-value is [0.09508149 0.47738263 0.01794507]; groups are significantly different = [False False  True]
# >>>>>> pull_request_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    113.273810
# 1    151.908696
# 2     87.522388
# Name: pull_request_created, dtype: float64
#
#
# F_onewayResult(statistic=7.044337630839656, pvalue=0.0009358194236953625)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1 110.8328 0.0006   40.8853 180.7803   True
#      0      2  61.3623 0.1962   -22.145 144.8695  False
#      1      2 -49.4705 0.3911 -138.2948  39.3537  False
# -------------------------------------------------------
# For interaction_days, anova result p-value is 0.0009358194236953625; groups are significantly different = True
# For interaction_days, Tukey HSD test result p-value is [0.00062586 0.19622874 0.39109034]; groups are significantly different = [ True False False]
# >>>>>> interaction_days ^^^ is significant <<<<<<
#
# cluster_labels
# 0    286.354167
# 1    397.186957
# 2    347.716418
# Name: interaction_days, dtype: float64
#
#
# F_onewayResult(statistic=2.044850458070998, pvalue=0.13017511924339212)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      0      1 161.3092 0.2564  -78.9669 401.5853  False
#      0      2 210.9636 0.1957  -75.8916 497.8189  False
#      1      2  49.6544 0.9226 -255.4653 354.7741  False
# -------------------------------------------------------
# For interaction_period_days, anova result p-value is 0.13017511924339212; groups are significantly different = False
# For interaction_period_days, Tukey HSD test result p-value is [0.25636168 0.19569229 0.92264292]; groups are significantly different = [False False False]
# cluster_labels
# 0    2362.312500
# 1    2523.621739
# 2    2573.276119
# Name: interaction_period_days, dtype: float64
#
#
# F_onewayResult(statistic=3.3451073072639295, pvalue=0.03582335749698601)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1  16.6397 0.3616 -12.0566  45.336  False
#      0      2 -23.3977 0.2446 -57.6571 10.8616  False
#      1      2 -40.0374 0.0272 -76.4781 -3.5968   True
# -----------------------------------------------------
# For created-closed_issues, anova result p-value is 0.03582335749698601; groups are significantly different = True
# For created-closed_issues, Tukey HSD test result p-value is [0.36159959 0.24455467 0.02716563]; groups are significantly different = [False False  True]
# >>>>>> created-closed_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0   -47.744048
# 1   -31.104348
# 2   -71.141791
# Name: created-closed_issues, dtype: float64
#
#
# F_onewayResult(statistic=27.474334014644175, pvalue=3.2736890546110063e-12)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1    -7.63    0.0 -10.4337 -4.8264   True
#      0      2   1.9294 0.3659  -1.4177  5.2766  False
#      1      2   9.5595    0.0   5.9992 13.1197   True
# -----------------------------------------------------
# For pc_created-closed_issues, anova result p-value is 3.2736890546110063e-12; groups are significantly different = True
# For pc_created-closed_issues, Tukey HSD test result p-value is [8.99101793e-10 3.65921709e-01 1.52062396e-09]; groups are significantly different = [ True False  True]
# >>>>>> pc_created-closed_issues ^^^ is significant <<<<<<
#
# cluster_labels
# 0   -74.444781
# 1   -82.074829
# 2   -72.515360
# Name: pc_created-closed_issues, dtype: float64
#
#
# F_onewayResult(statistic=15.171687737058773, pvalue=3.5514990420430495e-07)
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#      0      1  868.9712    0.0  498.3246 1239.6178   True
#      0      2  379.1073   0.11  -63.3917  821.6063  False
#      1      2 -489.8639 0.0391 -960.5375  -19.1904   True
# ---------------------------------------------------------
# For sum_n_interactions, anova result p-value is 3.5514990420430495e-07; groups are significantly different = True
# For sum_n_interactions, Tukey HSD test result p-value is [1.54267707e-07 1.09991095e-01 3.91175543e-02]; groups are significantly different = [ True False  True]
# >>>>>> sum_n_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    1142.937500
# 1    2011.908696
# 2    1522.044776
# Name: sum_n_interactions, dtype: float64
#
#
# F_onewayResult(statistic=0.08298942867908225, pvalue=0.9203699695347531)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1  -0.1971 0.9926 -4.1889 3.7946  False
#      0      2  -0.8252 0.9129 -5.5908 3.9404  False
#      1      2  -0.6281 0.9544 -5.6971 4.4409  False
# ---------------------------------------------------
# For mean_n_interactions_per_interaction_day, anova result p-value is 0.9203699695347531; groups are significantly different = False
# For mean_n_interactions_per_interaction_day, Tukey HSD test result p-value is [0.99261077 0.9128799  0.95439009]; groups are significantly different = [False False False]
# cluster_labels
# 0    5.148085
# 1    4.950962
# 2    4.322882
# Name: mean_n_interactions_per_interaction_day, dtype: float64
#
#
# F_onewayResult(statistic=57.949618563307006, pvalue=5.233926822276401e-24)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.4467    0.0   0.314  0.5795   True
#      0      2  -0.2823 0.0001 -0.4408 -0.1238   True
#      1      2   -0.729    0.0 -0.8976 -0.5604   True
# ----------------------------------------------------
# For breadth_interactions, anova result p-value is 5.233926822276401e-24; groups are significantly different = True
# For breadth_interactions, Tukey HSD test result p-value is [5.11257703e-13 9.59076922e-05 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> breadth_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    5.431548
# 1    5.878261
# 2    5.149254
# Name: breadth_interactions, dtype: float64
#
#
# F_onewayResult(statistic=26.486015510735637, pvalue=8.192513787235383e-12)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1  14.1805    0.0   9.3417 19.0193   True
#      0      2   0.2922 0.9922  -5.4846   6.069  False
#      1      2 -13.8883    0.0 -20.0329 -7.7436   True
# -----------------------------------------------------
# For pc_pull_request_created, anova result p-value is 8.192513787235383e-12; groups are significantly different = True
# For pc_pull_request_created, Tukey HSD test result p-value is [3.96837008e-11 9.92248180e-01 4.44985230e-07]; groups are significantly different = [ True False  True]
# >>>>>> pc_pull_request_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    36.744507
# 1    50.924988
# 2    37.036725
# Name: pc_pull_request_created, dtype: float64
#
#
# F_onewayResult(statistic=47.88728521079649, pvalue=3.2579835908222064e-20)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  14.5926   0.0 10.8202 18.3651   True
#      0      2  12.4882   0.0  7.9844  16.992   True
#      1      2  -2.1044 0.557 -6.8949  2.6861  False
# ---------------------------------------------------
# For pc_pull_request_closed, anova result p-value is 3.2579835908222064e-20; groups are significantly different = True
# For pc_pull_request_closed, Tukey HSD test result p-value is [4.79505324e-13 4.24493551e-10 5.57041097e-01]; groups are significantly different = [ True  True False]
# >>>>>> pc_pull_request_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0    71.644907
# 1    86.237526
# 2    84.133111
# Name: pc_pull_request_closed, dtype: float64
#
#
# F_onewayResult(statistic=377.46652254267457, pvalue=8.476892617879201e-112)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1  50.3103    0.0  45.7052 54.9154   True
#      0      2  42.0684    0.0  36.5706 47.5663   True
#      1      2  -8.2419 0.0028 -14.0898  -2.394   True
# -----------------------------------------------------
# For pc_commit_created, anova result p-value is 8.476892617879201e-112; groups are significantly different = True
# For pc_commit_created, Tukey HSD test result p-value is [4.79505324e-13 4.79505324e-13 2.81502767e-03]; groups are significantly different = [ True  True  True]
# >>>>>> pc_commit_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    32.876974
# 1    83.187279
# 2    74.945404
# Name: pc_commit_created, dtype: float64
#
#
# F_onewayResult(statistic=89.30980010377682, pvalue=2.9490377486847743e-35)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1  11.2526   0.0   6.3118  16.1935   True
#      0      2 -24.3501   0.0 -30.2488 -18.4514   True
#      1      2 -35.6028   0.0  -41.877 -29.3285   True
# -----------------------------------------------------
# For pc_issue_created, anova result p-value is 2.9490377486847743e-35; groups are significantly different = True
# For pc_issue_created, Tukey HSD test result p-value is [3.59254268e-07 4.79505324e-13 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_issue_created ^^^ is significant <<<<<<
#
# cluster_labels
# 0    40.469839
# 1    51.722466
# 2    16.119713
# Name: pc_issue_created, dtype: float64
#
#
# F_onewayResult(statistic=28.570570476304024, pvalue=1.1868076403927408e-12)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1   7.7426    0.0   4.9221  10.563   True
#      0      2  -2.1729 0.2841  -5.5402  1.1943  False
#      1      2  -9.9155    0.0 -13.4971 -6.3339   True
# -----------------------------------------------------
# For pc_issue_closed, anova result p-value is 1.1868076403927408e-12; groups are significantly different = True
# For pc_issue_closed, Tukey HSD test result p-value is [6.37287112e-10 2.84138628e-01 4.52966886e-10]; groups are significantly different = [ True False  True]
# >>>>>> pc_issue_closed ^^^ is significant <<<<<<
#
# cluster_labels
# 0    74.849480
# 1    82.592054
# 2    72.676557
# Name: pc_issue_closed, dtype: float64
#
#
# F_onewayResult(statistic=261.06554534263995, pvalue=2.388121132229802e-85)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj  lower    upper  reject
# ----------------------------------------------------
#      0      1   24.996   0.0  22.4017 27.5903   True
#      0      2  14.0831   0.0  10.9859 17.1804   True
#      1      2 -10.9129   0.0 -14.2073 -7.6184   True
# ----------------------------------------------------
# For pc_sum_n_interactions, anova result p-value is 2.388121132229802e-85; groups are significantly different = True
# For pc_sum_n_interactions, Tukey HSD test result p-value is [4.79505324e-13 4.79505324e-13 5.57887070e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_sum_n_interactions ^^^ is significant <<<<<<
#
# cluster_labels
# 0    54.098498
# 1    79.094465
# 2    68.181613
# Name: pc_sum_n_interactions, dtype: float64
#
#
# F_onewayResult(statistic=195.16702057514132, pvalue=4.944507053979312e-68)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj  lower    upper  reject
# ----------------------------------------------------
#      0      1  23.1046   0.0  20.3522  25.857   True
#      0      2  11.0569   0.0    7.771 14.3429   True
#      1      2 -12.0477   0.0 -15.5428 -8.5525   True
# ----------------------------------------------------
# For pc_interaction_days, anova result p-value is 4.944507053979312e-68; groups are significantly different = True
# For pc_interaction_days, Tukey HSD test result p-value is [4.79505324e-13 5.11257703e-13 4.87054841e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_interaction_days ^^^ is significant <<<<<<
#
# cluster_labels
# 0    42.466966
# 1    65.571584
# 2    53.523913
# Name: pc_interaction_days, dtype: float64
#
#
# F_onewayResult(statistic=455.61428746056083, pvalue=2.8472381828036806e-127)
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj  lower    upper   reject
# -----------------------------------------------------
#      0      1  19.0198   0.0  17.2004  20.8393   True
#      0      2  -7.5422   0.0  -9.7144  -5.3701   True
#      1      2 -26.5621   0.0 -28.8725 -24.2516   True
# -----------------------------------------------------
# For pc_DC, anova result p-value is 2.8472381828036806e-127; groups are significantly different = True
# For pc_DC, Tukey HSD test result p-value is [4.79505324e-13 4.84390306e-13 4.79505324e-13]; groups are significantly different = [ True  True  True]
# >>>>>> pc_DC ^^^ is significant <<<<<<
#
# cluster_labels
# 0    50.084185
# 1    69.104012
# 2    42.541936
# Name: pc_DC, dtype: float64

# %%
analysis_dataset.groupby("cluster_labels")["pc_interaction_days"].describe()

# %%
(analysis_dataset.cluster_labels.value_counts()/115174)*100
# Out:
# cluster_labels
# 0    0.291733
# 1    0.199698
# 2    0.116346
# Name: count, dtype: float64

# %%
from githubanalysis.visualization.plot_repoindividual_upset_plot import UpsetPlotter

upsetplotter = UpsetPlotter(
    dataset_name="sample_45pc_cluster1",
    image_write_location = dataanalyser.image_write_location,
    #image_write_location="../../data/analysis_run_sample_45pc_2025-05-12/",
    in_notebook=True,
    logger=None,
)

def upset_plot(
    cluster: int | None,
    data: pd.DataFrame,
    show_min: float = 0.005,
    show_counts: bool = False,
    sort_combos_by: str = "cardinality",
    data_set_name: str = "dataset",  # manual naming, goes into title of plots
    file_name: str = "upset_plot_",
    save_type: str = "pdf",  # one of: ['png', 'pdf', 'svg']
):
    assert (
        isinstance(cluster, int) or cluster is None
    ), f"give valid input for 'cluster': should be a number or None. You supplied {cluster}."
    assert save_type in [
        "svg",
        "pdf",
        "png",
    ], "save_type is not valid; check you have entered one of: 'svg', 'pdf', 'png'."
    assert (
        sort_combos_by
        in ["cardinality", "-cardinality", "degree", "-degree", "input", "-input"]
    ), "sort_combos_by is not valid, check you've entered one of: 'cardinality', 'degree', 'input' or '-cardinality', '-degree', '-input'."

    # what type is data?
    if isinstance(data, pd.DataFrame):
        assert data.empty is False, "Dataframe data is empty; check inputs."
        print(f"data is df, with shape: {data.shape}.")

    # colours = list(sns.color_palette("colorblind").as_hex())

    data_by_interaction = from_memberships(  # format data to upsetplot requirements
        data.which_interactions.apply(lambda x: [x.strip() for x in x.split(",")]),
        data=data,
    )
    assert isinstance(
        data_by_interaction, pd.DataFrame
    ), "data_by_interaction needs to be a dataframe, check this was generated correctly."

    if cluster is not None:
        cluster_query = f"cluster_labels == {cluster}"
        data = data_by_interaction.query("@cluster_query", engine="python")
        # plot_colour = colours[cluster]
        cluster_name = f"cluster{cluster}"
    else:  # if no clusters supplied:
        data = data_by_interaction
        # plot_colour = "auto"
        cluster_name = data_set_name


    smallest_n_to_show = round(len(data) * show_min)

    print(
        f"Attempting to plot cluster {cluster_name} and showing as far as {show_min}%, which is {smallest_n_to_show} repo-individuals from the data"  # {plot_colour}."
    )

    if show_counts:
        format = "{:,}"
    else:
        format = ""
        
    upset = UpSet(
        data=data,
        how_counts=format,
        sort_by=sort_combos_by,
        # facecolor=plot_colour,
        orientation="horizontal",
        min_subset_size=smallest_n_to_show,
    )
    upset.plot()
    plt.suptitle(
        f"{data_set_name} Interaction-Combinations (showing >{smallest_n_to_show} ({show_min}%) Repo-Individuals),  N={len(data)}"
    )
    plot_file = Path(
        image_write_location,
        f"{file_name}_{cluster_name}_{current_date_info}.{save_type}",
    )
    plt.savefig(fname=plot_file, format=save_type, bbox_inches="tight")
    plt.close()
    print(f"Plot saved out to file {plot_file}.")
    
    
    
def plot_upset_plot_interaction_combinations(
    
    data: pd.DataFrame,
    # colours: list | dict = sns.color_palette("colorblind"),
    separate_by_clusters: bool = False,
    show_min: float = 0.005,
    show_counts: bool = False,
    sort_combos_by: str = "cardinality",
    data_set_name: str = "dataset",
    file_name: str = "upset_plot_",
    save_type: str = "pdf",  # one of: ['png', 'pdf', 'svg']
    # min_repo_individs_per_combo: int = 2,
    # show_counts_per_combo: boolean = True,
    # show_pc: boolean = False,
):
    """
    This generates UpSet plots from GH interaction data from a dataframe or csv file.
    Data must be in a per-repo-individual format, and cluster labels must be in column titled "cluster_labels".

    """
    assert isinstance(
        data, (pd.DataFrame, Path)
    ), "Data is not of type pandas dataframe or Path; check your inputs."
    if isinstance(data, Path):
        print(f"data is a path: {data}")
        data = pd.read_csv(filepath_or_buffer=data, header=0)
        assert isinstance(data, pd.DataFrame), "data could not be read in properly."
        print(f"data is df, with shape: {data.shape}.")
    # if colours is a list and separate_by_clusters is true, does len(colours) match nunique('cluster_labels')?

    assert isinstance(
        data, pd.DataFrame
    ), "data should be dataframe format by now, check why this isn't correct"

    if separate_by_clusters:
        assert (
            "cluster_labels" in data.columns
        ), "df has no column 'cluster_labels - please check this is present in the data."
        n_clusters = data.cluster_labels.nunique()
        print(
                f"Plotting upset plot for {data_set_name}, separating by {n_clusters} clusters from data labels."
        )

        for cluster in range(0, n_clusters - 1, 1):
            # range: start at 0 because this is how they're named by clustering
            # end on n_clusters - 1 because we're starting at 0 and off-by-one; increases by 1
            upset_plot(
                    cluster=cluster,
                    data=data,
                    show_min=show_min,
                    data_set_name=data_set_name,
                    show_counts=show_counts,
                    file_name=f"{file_name}_cluster-{cluster}_",
                )
        print(
            f"Completed UpSet plotting for {n_clusters} clusters from data labels."
        )
    else:
        print("Plotting upset plot without separating by clusters")
        upset_plot(
                cluster=None,
                data=data,
                show_min=show_min,
                show_counts=show_counts,
                sort_combos_by="cardinality",
                data_set_name=data_set_name,
                file_name=file_name,
                save_type="pdf",  # one of: ['png', 'pdf', 'svg']
        )
        print("Completed UpSet plotting.")

# %%
print("{Plotting single combined sample UpSet Plot")
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=analysis_dataset,
    show_min = 0.005,
    show_counts=True,  ##### SHOW COUNTS VERSION 
    sort_combos_by="cardinality",
    data_set_name="Sample",
    file_name="sample_upset_plot_45pc_counts_cluster1",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
plt.show()

print("{Plotting single combined sample UpSet Plot")
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=analysis_dataset,
    show_min = 0.005,
    sort_combos_by="cardinality",  ### NO COUNTS
    data_set_name="Sample",
    file_name="sample_upset_plot_45pc_cluster1",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
plt.show()



tmp0 = analysis_dataset.query("cluster_labels == 0")
tmp1 = analysis_dataset.query("cluster_labels == 1")
tmp2 = analysis_dataset.query("cluster_labels == 2")

# plot cluster 0
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp0,
    show_min = 0.01,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 1:0",
    file_name="sample_upset_plot_45pc_subcluster0_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)

# plot cluster 0 WITH COUNTS
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp0,
    show_min = 0.01,
    show_counts=True,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 1:0",
    file_name="sample_upset_plot_45pc_subcluster0_counts",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)



# plot cluster 1
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    show_min = 0.01,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 1:1",
    file_name="sample_upset_plot_45pc_subcluster1_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)

# plot cluster 1 WITH COUNTS
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    show_min = 0.01,
    show_counts=True,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 1:1",
    file_name="sample_upset_plot_45pc_subcluster1_counts",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)

# plot cluster 2
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    show_min = 0.01,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 1:2",
    file_name="sample_upset_plot_45pc_subcluster2_",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)

# plot cluster 1 WITH COUNTS
upsetplotter.plot_upset_plot_interaction_combinations(
    separate_by_clusters=False,
    data=tmp1,
    show_min = 0.01,
    show_counts=True,
    sort_combos_by="cardinality",
    data_set_name="Sub-Cluster 1:2",
    file_name="sample_upset_plot_45pc_subcluster2_counts",
    save_type="pdf",  # one of: ['png', 'pdf', 'svg']
)
# Out:
# INFO:Plotting upset plot for Sample without separating by clusters
# INFO:data is df, with shape: (700, 86).
# INFO:Attempting to plot cluster Sample and showing as far as 0.005%, which is 4 repo-individuals from the data
# {Plotting single combined sample UpSet Plot
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_counts_cluster1_Sample_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sample without separating by clusters
# INFO:data is df, with shape: (700, 86).
# INFO:Attempting to plot cluster Sample and showing as far as 0.005%, which is 4 repo-individuals from the data
# {Plotting single combined sample UpSet Plot
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_cluster1_Sample_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 1:0 without separating by clusters
# INFO:data is df, with shape: (336, 86).
# INFO:Attempting to plot cluster Sub-Cluster 1:0 and showing as far as 0.01%, which is 3 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_subcluster0__Sub-Cluster 1:0_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 1:0 without separating by clusters
# INFO:data is df, with shape: (336, 86).
# INFO:Attempting to plot cluster Sub-Cluster 1:0 and showing as far as 0.01%, which is 3 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_subcluster0_counts_Sub-Cluster 1:0_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 1:1 without separating by clusters
# INFO:data is df, with shape: (230, 86).
# INFO:Attempting to plot cluster Sub-Cluster 1:1 and showing as far as 0.01%, which is 2 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_subcluster1__Sub-Cluster 1:1_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 1:1 without separating by clusters
# INFO:data is df, with shape: (230, 86).
# INFO:Attempting to plot cluster Sub-Cluster 1:1 and showing as far as 0.01%, which is 2 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_subcluster1_counts_Sub-Cluster 1:1_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 1:2 without separating by clusters
# INFO:data is df, with shape: (230, 86).
# INFO:Attempting to plot cluster Sub-Cluster 1:2 and showing as far as 0.01%, which is 2 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_subcluster2__Sub-Cluster 1:2_2025-05-18.pdf.
# INFO:Completed UpSet plotting.
# INFO:Plotting upset plot for Sub-Cluster 1:2 without separating by clusters
# INFO:data is df, with shape: (230, 86).
# INFO:Attempting to plot cluster Sub-Cluster 1:2 and showing as far as 0.01%, which is 2 repo-individuals from the data
# INFO:Plot saved out to file ../../images/analysis_run_sample_45pc_cluster1_2025-05-18/sample_upset_plot_45pc_subcluster2_counts_Sub-Cluster 1:2_2025-05-18.pdf.
# INFO:Completed UpSet plotting.

# %%
analysis_dataset['RSE_persona'] = analysis_dataset['cluster_labels']

# %%
analysis_dataset[["repo_name", "gh_username", "cluster_labels", "RSE_persona"]]
# Out:
#                       repo_name  gh_username  cluster_labels  RSE_persona
# 0             WIPACrepo/iceprod     dsschult               1            1
# 1        feelpp/book.feelpp.org     prudhomm               0            0
# 2                   dswah/pyGAM        dswah               1            1
# 3    JuliaMath/MeasureTheory.jl    cscherrer               1            1
# 4           sintefmath/Jutul.jl       moyner               1            1
# ..                          ...          ...             ...          ...
# 695          cohenlabUNC/clpipe    wasciutto               0            0
# 696         ncihtan/data-models  adamjtaylor               0            0
# 697             desy-ml/cheetah      jank324               0            0
# 698      cytoscape/cytoscape.js    maxkfranz               0            0
# 699  OpenChemistry/avogadrolibs     ghutchis               0            0
#
# [700 rows x 4 columns]

# %%
analysis_dataset.replace(to_replace={'RSE_persona': {0: "low-coding_closer", 1: "active_contributor", 2: "low-process_closer"}}, inplace=True)

# %%
analysis_dataset[["repo_name", "gh_username", "cluster_labels", "RSE_persona"]]
# Out:
#                       repo_name  gh_username  cluster_labels  \
# 0             WIPACrepo/iceprod     dsschult               1
# 1        feelpp/book.feelpp.org     prudhomm               0
# 2                   dswah/pyGAM        dswah               1
# 3    JuliaMath/MeasureTheory.jl    cscherrer               1
# 4           sintefmath/Jutul.jl       moyner               1
# ..                          ...          ...             ...
# 695          cohenlabUNC/clpipe    wasciutto               0
# 696         ncihtan/data-models  adamjtaylor               0
# 697             desy-ml/cheetah      jank324               0
# 698      cytoscape/cytoscape.js    maxkfranz               0
# 699  OpenChemistry/avogadrolibs     ghutchis               0
#
#             RSE_persona
# 0    active_contributor
# 1     low-coding_closer
# 2    active_contributor
# 3    active_contributor
# 4    active_contributor
# ..                  ...
# 695   low-coding_closer
# 696   low-coding_closer
# 697   low-coding_closer
# 698   low-coding_closer
# 699   low-coding_closer
#
# [700 rows x 4 columns]

# %%
analysis_dataset.to_csv("../../data/analysis_run_sample_45pc_cluster1_2025-05-13/sample_45pc_cluster1_personas_named_dataset_2025-05-30.csv", header=True, index=False)
